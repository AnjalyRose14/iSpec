# %% [markdown]
# # iMCSpec (iSpec+emcee)

# %% [markdown]
# iMCSpec is a tool which combines iSpec(https://www.blancocuaresma.com/s/iSpec) and emcee(https://emcee.readthedocs.io/en/stable/) into a single unit to perform Bayesian analysis of spectroscopic data to estimate stellar parameters. For more details on the individual code please refer to the links above. This code have been tested on Syntehtic dataset as well as GAIA BENCHMARK stars (https://www.blancocuaresma.com/s/benchmarkstars). The example shown here is for the grid genarated MARCS.GES_atom_hfs. If you want to use any other grid, just download it from the https://www.cfa.harvard.edu/~sblancoc/iSpec/grid/ and make the necessary changes in the line_regions.

# %% [raw]
# Dependencies :
# iSpec : iSpec v2020.10.01
# python = 3+ Branch
# numpy>=1.18.5
# scipy>=1.5.0
# matplotlib>=3.2.2
# astropy>=4.0.1.post1
# lockfile>=0.12.2
# Cython>=0.29.21
# pandas>=1.0.5
# statsmodels>=0.11.1
# dill>=0.3.2
# emcee>=3.0.2
# corner>=2.1.1

# %% [markdown]
# Let us import all the necessary packages that are required for this analysis.

# %%
import sys
sys.path.append('/home/anjalyrose/iSpec')
import ispec
# Out:
# *********************************************************************
# Not optimized version loaded!
# *********************************************************************
# *********************************************************************
# Not optimized version loaded!
# *********************************************************************
# *********************************************************************
# Not optimized version loaded!
# *********************************************************************

# %%
import os
import sys
import numpy as np
import pandas as pd
import emcee
from multiprocessing import Pool
import matplotlib.pyplot as plt

os.environ["OMP_NUM_THREADS"] = "1"
os.environ['QT_QPA_PLATFORM']='offscreen'
os.environ["NUMEXPR_MAX_THREADS"] = "8"      #CHECK NUMBER OF CORES ON YOUR MACHINE AND CHOOSE APPROPRIATELY 

ispec_dir = '/home/anjalyrose/iSpec'            #MENTION YOUR DIRECTORY WHERE iSPEC is present     
sys.path.insert(0, os.path.abspath(ispec_dir))

import ispec
#np.seterr(all="ignore")                     #FOR MCMC THE WARNING COMES FOR RED BLUE MOVES WHEN ANY PARTICULAR WALKER VALUE DONOT LIE IN THE PARAMETER SPACE

# %% [markdown]
# Let us read the input spectra. Here I have the input spectrum in .txt format for reading the spectra. You can use the .fits format also for reading the spectra using Astropy (https://docs.astropy.org/en/stable/io/fits/). Please note that my input spectra is normalized and radial velocity (RV) corrected. For normalization and RV correction you can used iSpec or iraf.

# %%
df = pd.read_csv('/home/anjalyrose/iSpec/ispec_sample.txt', sep=r'\s+')  #ENTER YOUR INPUT SPECTRA
df = df[df.flux != 0]                                                   #FOR SOME SPECTROGRAPH PARTS OF SPECTRA ARE MISSING AND THE CORRESPONDING FLUX VALUES ARE LABELLED AS ZEROS. WE WANT TO IGNORE SUCH POINTS

x = df['waveobs'].values
y = df['flux'].values
yerr = df['err'].values
df = np.array(df,dtype=[('waveobs', '<f8'), ('flux', '<f8'), ('err', '<f8')])

# %% [markdown]
# You can perform the analysis on the entire spectrum or choose specific regions/segments for which you want to perform the analysis for.

# %%
#--- Read lines with atomic data ------------------------------------------------

# line_regions = ispec.read_line_regions(ispec_dir + "/input/regions/47000_GES/grid_synth_good_for_params_all.txt") #CHANGE THIS ACCORDINGLY FOR THE INPUT GRID          
# line_regions = ispec.adjust_linemasks(df, line_regions, max_margin=0.5)
# segments = ispec.create_segments_around_lines(line_regions, margin=0.5)   


#  ### Add also regions from the wings of strong lines:
# ## H beta
# hbeta_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/wings_Hbeta_segments.txt")
# #segments = hbeta_segments
# segments = np.hstack((segments, hbeta_segments))
# ## H ALPHA
# halpha_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/wings_Halpha_segments.txt")
# segments = np.hstack((segments, halpha_segments))
# ## MG TRIPLET
# mgtriplet_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/wings_MgTriplet_segments.txt")
# segments = np.hstack((segments, mgtriplet_segments))
##IRON
# fe_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/fe_lines_segments.txt")
# segments = np.hstack((segments, fe_segments))
##CALCIUM TRIPLET
# catriplet_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/Calcium_Triplet_segments.txt")
# segments = np.hstack((segments, catriplet_segments))
##Na doublet
# NaDoublet_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/Calcium_Triplet_segments.txt")
# segments = np.hstack((segments, NaDoublet_segments_segments))

# %%
# for j in range(len(segments)):
#     segments[j][0] = segments[j][0]+0.05
#     segments[j][1] = segments[j][1]-0.05
#YOU CAN CHANGE THE STARTING AND ENDING POINTS OF THE SEGEMENT

# %% [markdown]
# I will create a mask all false values with the same dimension as my original spectra in 1D. I will keep only those values of wavelength and flux for which the value falls in the segments (i.e, Mask is True).

# %%
# mask =np.zeros(x.shape,dtype =bool)
# for i in range(len(segments)):
#     mask|= (x>segments[i][0])&(x<segments[i][1])

# %%
# x = x[mask]                         #SELECTING THOSE VALUES ONLY FOR WHICH MASK VALUE IS TRUE
# y = y[mask]
# #yerr = yerr[mask]
yerr = y*0.0015                     #IF ERROR IS NOT SPECIFIED YOU CAN CHOOSE ACCORDINGLY

# %% [markdown]
# Now let us interpolate the spectrum using iSpec. Here for simplicity I have considered only Teff, log g and [M/H] as free parameters. Vmic and Vmac are obtained from emperical relations by Jofre et al.2013 and Maria Bergemann

# %%
def synthesize_spectrum(theta):
    teff ,logg ,MH = theta
#    alpha = ispec.determine_abundance_enchancements(MH)
    alpha =0.0
    microturbulence_vel = ispec.estimate_vmic(teff, logg, MH) 
    macroturbulence = ispec.estimate_vmac(teff, logg, MH) 
    limb_darkening_coeff = 0.6
    resolution = 47000
    vsini = 1.6                                                                                                                             #CHANGE HERE
    code = "grid"
    precomputed_grid_dir = ispec_dir + "/input/grid/SPECTRUM_MARCS.GES_GESv6_atom_hfs_iso.480_680nm_light/"

#    precomputed_grid_dir = ispec_dir + "/input/grid/SPECTRUM_MARCS.GES_GESv6_atom_hfs_iso.480_680nm_light/"
#    The light grid comes bundled with iSpec. It is just for testing purpose. Donot use it for Scientific purpose.
    grid = ispec.load_spectral_grid(precomputed_grid_dir)

    atomic_linelist = None
    isotopes = None
    modeled_layers_pack = None
    solar_abundances = None
    fixed_abundances = None
    abundances = None
    atmosphere_layers = None
    regions = None
        
    if not ispec.valid_interpolated_spectrum_target(grid, {'teff':teff, 'logg':logg, 'MH':MH, 'alpha':alpha, 'vmic': microturbulence_vel}):
        msg = "The specified effective temperature, gravity (log g) and metallicity [M/H] \
                fall out of the spectral grid limits."
        print(msg)

    # Interpolation
    synth_spectrum = ispec.create_spectrum_structure(x)
    synth_spectrum['flux'] = ispec.generate_spectrum(synth_spectrum['waveobs'], \
            atmosphere_layers, teff, logg, MH, alpha, atomic_linelist, isotopes, abundances, \
            fixed_abundances, microturbulence_vel = microturbulence_vel, \
            macroturbulence=macroturbulence, vsini=vsini, limb_darkening_coeff=limb_darkening_coeff, \
            R=resolution, regions=regions, verbose=1,
            code=code, grid=grid)
    return synth_spectrum

# %% [markdown]
# You can also synthesize the spectrum directly from various atmospheric models. A skeleton of the code taken from iSpec is shown below. For more details check example.py in iSpec.

# %%
# def synthesize_spectrum(theta,code="spectrum"):
#     teff ,logg ,MH = theta
#     resolution = 47000
#     alpha = ispec.determine_abundance_enchancements(MH)
#     microturbulence_vel = ispec.estimate_vmic(teff, logg, MH)
#     macroturbulence = ispec.estimate_vmac(teff, logg, MH)

#     limb_darkening_coeff = 0.6
#     regions = None

#     # Selected model amtosphere, linelist and solar abundances
    
#     #model = ispec_dir + "/input/atmospheres/MARCS/"
#     #model = ispec_dir + "/input/atmospheres/MARCS.GES/"
#     #model = ispec_dir + "/input/atmospheres/MARCS.APOGEE/"
#     #model = ispec_dir + "/input/atmospheres/ATLAS9.APOGEE/"
#     model = ispec_dir + "/input/atmospheres/ATLAS9.Castelli/"
#     #model = ispec_dir + "/input/atmospheres/ATLAS9.Kurucz/"
#     #model = ispec_dir + "/input/atmospheres/ATLAS9.Kirby/" 

#     #atomic_linelist_file = ispec_dir + "/input/linelists/transitions/VALD.300_1100nm/atomic_lines.tsv"
#     #atomic_linelist_file = ispec_dir + "/input/linelists/transitions/VALD.1100_2400nm/atomic_lines.tsv"
#     atomic_linelist_file = ispec_dir + "/input/linelists/transitions/GESv6_atom_hfs_iso.420_920nm/atomic_lines.tsv"
#     #atomic_linelist_file = ispec_dir + "/input/linelists/transitions/GESv6_atom_nohfs_noiso.420_920nm/atomic_lines.tsv"
    
#     isotope_file = ispec_dir + "/input/isotopes/SPECTRUM.lst"
    

#     atomic_linelist = ispec.read_atomic_linelist(atomic_linelist_file, wave_base=wave_base, wave_top=wave_top)
#     atomic_linelist = atomic_linelist[atomic_linelist['theoretical_depth'] >= 0.01]

#     isotopes = ispec.read_isotope_data(isotope_file)

#     if "ATLAS" in model:
#         solar_abundances_file = ispec_dir + "/input/abundances/Grevesse.1998/stdatom.dat"
#     else:
#         # MARCS
#         solar_abundances_file = ispec_dir + "/input/abundances/Grevesse.2007/stdatom.dat"
#     #solar_abundances_file = ispec_dir + "/input/abundances/Asplund.2005/stdatom.dat"
#     #solar_abundances_file = ispec_dir + "/input/abundances/Asplund.2009/stdatom.dat"
#     #solar_abundances_file = ispec_dir + "/input/abundances/Anders.1989/stdatom.dat"

#     modeled_layers_pack = ispec.load_modeled_layers_pack(model)
#     solar_abundances = ispec.read_solar_abundances(solar_abundances_file)
    
#     ## Custom fixed abundances
#     #fixed_abundances = ispec.create_free_abundances_structure(["C", "N", "O"], chemical_elements, solar_abundances)
#     #fixed_abundances['Abund'] = [-3.49, -3.71, -3.54] # Abundances in SPECTRUM scale (i.e., x - 12.0 - 0.036) and in the same order ["C", "N", "O"]
#     ## No fixed abundances
#     fixed_abundances = None

#     atmosphere_layers = ispec.interpolate_atmosphere_layers(modeled_layers_pack, {'teff':teff, 'logg':logg, 'MH':MH, 'alpha':alpha}, code=code)
#     synth_spectrum = ispec.create_spectrum_structure(x)
#     synth_spectrum['flux'] = ispec.generate_spectrum(synth_spectrum['waveobs'],
#             atmosphere_layers, teff, logg, MH, alpha, atomic_linelist, isotopes, solar_abundances,
#             fixed_abundances, microturbulence_vel = microturbulence_vel,
#             macroturbulence=macroturbulence, vsini=vsini, limb_darkening_coeff=limb_darkening_coeff,
#             R=resolution, regions=regions, verbose=0,
#             code=code)

#     return synth_spectrum

# %% [markdown]
# So far we have discussed about reading the input original spectra and interpolating the synthetic spectra from iSpec. Now the important part that comes into picture is to compare the original spectra and the interpolated spectra. For this we will use Montecarlo Markhov chain method to compare both the spectrums. For this we have used the emcee package by
# Dan Foreman-Mackey.

# %%
walkers = eval(input("Enter Walkers: "))    #WALKER IMPLIES THE INDEPENDENT RANDOMLY SELECTED PARAMETER SETS. NOTE IT SHOULD HAVE ATLEAST TWICE THE VALUE OF AVAILABLE FREE PARAMETERS
Iter = eval(input("Enter Iterations: "))    #ITERATION IMPLIES NUMBER OF RUNS THE PARAMETERS WILL BE CHECKED FOR CONVERGENCE. FOR MOST CASES 250-300 SHOULD DO.
# Out:
# Enter Walkers:  20
# Enter Iterations:  100

# %% [markdown]
# We will be creating four functions for this MCMC run. The first is straightforward, and is known as the model. The model function should take as an argument a list representing our θ vector, and return the model evaluated at that θ. For completion, your model function should also have your parameter array as an input. The form of this function comes from the Gaussian probability distribution P(x)dx.

# %%
def log_likelihood(theta):
    model = synthesize_spectrum(theta)    #GENARATING THE SPECTRUM FOR A GIVEN VALUE OF THETA
    sigma2 = yerr ** 2                    # FINDING THE Variance
    return -0.5 * np.sum((y - (model['flux'])) ** 2/ sigma2)     # returns the -chi^2/2 value

# %% [markdown]
# There is no unique way to set up your prior function. For the simplistic case we have choosen the log prior function returns zero if the input values genarated randomly lies wittin the specified ranges and -infinity if it doesnt(atleast one vale should satisty this criterion). You can choose your own prior function as well.

# %%
def log_prior(theta):
    teff, logg, MH = theta
    if 3200 < teff < 6900 and 1.1 < logg < 4.8 and -2.49 < MH <= 0.49 :                                                       #CHANGE HERE
        return 0.0
    return -np.inf

# %% [markdown]
# The last function we need to define is lnprob(). This function combines the steps above by running the lnprior function, and if the function returned -np.inf, passing that through as a return, and if not (if all priors are good), returning the lnlike for that model (by convention we say it’s the lnprior output + lnlike output, since lnprior’s output should be zero if the priors are good). lnprob needs to take as arguments theta,x,y,and yerr, since these get passed through to lnlike.

# %%
def log_probability(theta):
    lp = log_prior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood(theta)

# %% [markdown]
# Select input guess values and create intial set of stellar parameters RANDOMLY

# %%
initial = np.array([5500,4.0,-0.1])         #INPUT GUESS VALUES                                                         
pos = initial + np.array([100,0.1,0.1])*np.random.randn(walkers, 3)      # YOU CAN CHOOSE UNIFORM RANDOM FUNCTION OR GAUSSIAUN RANDOM NUMBER GENARATOR
nwalkers, ndim = pos.shape

# %% [markdown]
# Now we will run the EMCEE sampler to run the code. This will take some time depending on the your system. But don't worry :)

# %%
sampler = emcee.EnsembleSampler(nwalkers, ndim, log_probability)
sampler.run_mcmc(pos,Iter, progress=True)
# Out:
# [2025-10-23 11:04:18,030] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:18,440] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:18,843] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:19,321] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:19,802] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:20,241] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:20,707] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:21,146] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:21,548] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:21,946] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:22,365] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:22,835] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:23,225] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:23,640] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:24,119] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:24,517] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:24,926] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:25,428] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:25,834] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:26,232] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   0%|                                                   | 0/100 [00:00<?, ?it/s][2025-10-23 11:04:26,661] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:27,079] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:27,499] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:27,933] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:28,431] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:28,837] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:29,253] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:29,668] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:30,077] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:30,476] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:30,876] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:31,275] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:31,686] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:32,087] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:32,488] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:32,892] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:33,311] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:33,718] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:34,122] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:34,531] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   1%|▍                                          | 1/100 [00:08<13:40,  8.29s/it][2025-10-23 11:04:34,949] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:35,362] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:35,765] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:36,179] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:36,580] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:36,982] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:37,383] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:37,813] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:38,228] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:38,651] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:39,072] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:39,526] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:39,939] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:40,349] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:40,760] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:41,180] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:41,595] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:42,019] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:42,634] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:43,235] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   2%|▊                                          | 2/100 [00:16<13:56,  8.53s/it][2025-10-23 11:04:43,638] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:44,059] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:44,475] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:44,874] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:45,274] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:45,675] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:46,079] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:46,485] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:46,892] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:47,509] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:48,124] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:48,791] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:49,428] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:50,072] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:50,725] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:51,379] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:52,023] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:52,665] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:53,542] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:54,154] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   3%|█▎                                         | 3/100 [00:27<15:33,  9.62s/it][2025-10-23 11:04:54,787] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:55,406] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:56,052] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:56,727] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:57,380] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:58,000] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:58,617] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:59,234] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:04:59,875] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:00,669] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:01,276] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:01,897] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:02,522] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:03,160] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:03,784] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:04,467] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:05,264] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:05,871] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:06,732] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:07,550] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   4%|█▋                                         | 4/100 [00:41<17:46, 11.11s/it][2025-10-23 11:05:08,374] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:09,132] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:09,732] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:10,352] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:10,971] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:11,592] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:12,228] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:12,853] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:13,483] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:14,103] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:14,714] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:15,333] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:15,949] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:16,573] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:17,191] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:17,801] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:18,419] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:19,032] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:19,648] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:20,264] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   5%|██▏                                        | 5/100 [00:54<18:30, 11.69s/it][2025-10-23 11:05:20,880] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:21,495] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:22,106] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:22,717] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:23,325] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:23,937] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:24,552] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:25,170] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:25,782] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:26,396] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:27,002] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:27,606] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:28,219] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:28,832] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:29,446] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:30,072] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:30,682] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:31,301] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:31,920] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:32,542] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   6%|██▌                                        | 6/100 [01:06<18:37, 11.89s/it][2025-10-23 11:05:33,159] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:33,767] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:34,388] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:35,008] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:35,619] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:36,222] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:36,834] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:37,449] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:38,069] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:38,685] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:39,299] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:39,912] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:40,531] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:41,146] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:41,758] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:42,375] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:43,012] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:43,632] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:44,261] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:44,874] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   7%|███                                        | 7/100 [01:18<18:39, 12.03s/it][2025-10-23 11:05:45,491] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:46,108] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:46,753] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:47,398] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:48,011] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:48,626] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:49,235] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:49,862] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:50,470] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:51,087] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:51,695] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:52,312] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:52,925] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:53,543] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:54,388] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:55,144] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:55,885] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:56,500] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:57,129] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:57,741] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   8%|███▍                                       | 8/100 [01:31<18:51, 12.30s/it][2025-10-23 11:05:58,362] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:58,972] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:05:59,584] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:00,222] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:00,831] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:01,440] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:02,055] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:02,693] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:03,341] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:03,973] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:04,616] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:05,255] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:05,865] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:06,504] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:07,143] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:07,780] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:08,419] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:09,045] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:09,660] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:10,277] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   9%|███▊                                       | 9/100 [01:44<18:45, 12.37s/it][2025-10-23 11:06:10,880] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:11,492] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:12,103] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:12,718] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:13,352] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:13,957] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:14,573] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:15,193] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:15,842] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:16,500] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:17,122] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:17,740] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:18,355] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:18,963] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:19,592] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:20,379] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:20,988] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:21,594] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:22,206] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:22,827] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  10%|████▏                                     | 10/100 [01:56<18:38, 12.43s/it][2025-10-23 11:06:23,666] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:24,286] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:24,922] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:25,703] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:26,312] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:26,948] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:27,567] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:28,205] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:28,835] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:29,474] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:30,253] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:30,857] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:31,465] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:32,113] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:32,763] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:33,372] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:33,977] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:34,588] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:35,192] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:35,795] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  11%|████▌                                     | 11/100 [02:09<18:40, 12.59s/it][2025-10-23 11:06:36,409] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:37,024] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:37,630] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:38,242] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:38,854] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:39,463] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:40,073] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:40,687] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:41,296] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:41,899] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:42,514] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:43,127] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:43,742] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:44,593] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:45,337] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:45,973] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:46,605] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:47,246] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:47,858] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:48,473] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  12%|█████                                     | 12/100 [02:22<18:30, 12.62s/it][2025-10-23 11:06:49,263] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:50,040] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:50,641] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:51,261] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:51,902] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:52,544] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:53,144] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:53,776] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:54,413] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:55,049] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:55,651] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:56,275] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:56,882] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:57,481] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:58,075] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:58,680] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:59,281] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:06:59,881] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:00,493] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:01,097] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  13%|█████▍                                    | 13/100 [02:34<18:17, 12.62s/it][2025-10-23 11:07:01,754] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:02,393] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:03,011] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:03,622] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:04,234] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:04,855] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:05,464] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:06,073] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:06,692] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:07,302] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:07,918] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:08,532] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:09,146] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:09,760] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:10,374] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:10,990] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:11,605] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:12,215] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:12,841] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:13,451] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  14%|█████▉                                    | 14/100 [02:47<17:58, 12.54s/it][2025-10-23 11:07:14,064] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:14,682] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:15,295] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:15,911] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:16,529] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:17,141] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:17,754] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:18,367] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:18,981] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:19,601] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:20,213] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:20,835] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:21,455] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:22,071] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:22,690] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:23,298] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:23,915] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:24,530] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:25,156] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:25,771] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  15%|██████▎                                   | 15/100 [02:59<17:40, 12.47s/it][2025-10-23 11:07:26,393] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:27,015] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:27,643] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:28,260] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:28,881] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:29,495] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:30,109] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:30,725] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:31,341] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:31,952] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:32,572] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:33,188] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:33,803] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:34,414] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:35,034] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:35,814] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:36,441] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:37,229] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:37,870] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:38,484] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  16%|██████▋                                   | 16/100 [03:12<17:33, 12.55s/it][2025-10-23 11:07:39,132] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:39,775] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:40,554] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:41,172] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:41,800] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:42,425] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:43,056] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:43,699] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:44,323] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:44,948] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:45,564] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:46,174] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:46,791] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:47,406] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:48,019] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:48,638] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:49,253] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:49,873] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:50,491] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:51,105] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  17%|███████▏                                  | 17/100 [03:24<17:23, 12.57s/it][2025-10-23 11:07:51,724] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:52,343] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:52,964] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:53,581] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:54,196] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:54,815] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:55,436] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:56,056] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:56,674] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:57,294] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:57,911] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:58,526] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:59,133] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:07:59,745] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:00,351] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:00,960] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:01,568] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:02,174] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:02,789] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:03,397] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  18%|███████▌                                  | 18/100 [03:37<17:03, 12.49s/it][2025-10-23 11:08:04,011] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:04,622] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:05,227] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:05,834] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:06,443] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:07,053] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:07,668] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:08,312] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:08,946] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:09,590] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:10,231] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:11,013] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:11,619] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:12,276] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:12,898] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:13,518] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:14,140] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:14,757] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:15,374] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:15,988] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  19%|███████▉                                  | 19/100 [03:49<16:53, 12.52s/it][2025-10-23 11:08:16,612] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:17,226] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:17,844] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:18,460] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:19,079] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:19,692] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:20,474] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:21,089] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:21,706] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:22,553] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:23,365] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:24,114] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:24,736] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:25,364] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:25,989] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:26,614] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:27,237] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:27,858] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:28,475] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:29,096] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  20%|████████▍                                 | 20/100 [04:02<16:55, 12.69s/it][2025-10-23 11:08:29,726] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:30,344] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:30,969] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:31,590] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:32,202] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:32,839] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:33,450] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:34,067] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:34,683] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:35,306] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:35,927] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:36,539] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:37,161] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:37,776] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:38,390] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:39,014] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:39,633] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:40,248] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:40,877] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:41,493] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  21%|████████▊                                 | 21/100 [04:15<16:35, 12.61s/it][2025-10-23 11:08:42,111] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:42,733] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:43,354] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:43,985] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:44,604] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:45,228] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:45,849] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:46,462] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:47,082] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:47,698] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:48,316] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:48,939] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:49,555] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:50,168] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:50,785] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:51,406] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:52,025] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:52,643] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:53,254] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:53,863] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  22%|█████████▏                                | 22/100 [04:27<16:17, 12.53s/it][2025-10-23 11:08:54,475] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:55,091] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:55,731] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:56,332] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:56,941] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:57,542] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:58,144] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:58,753] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:59,374] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:08:59,986] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:00,593] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:01,215] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:01,827] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:02,691] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:03,436] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:04,077] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:04,719] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:05,334] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:06,130] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:06,734] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  23%|█████████▋                                | 23/100 [04:40<16:12, 12.64s/it][2025-10-23 11:09:07,349] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:07,962] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:08,574] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:09,187] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:09,798] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:10,583] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:11,228] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:12,015] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:12,615] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:13,233] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:13,873] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:14,507] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:15,150] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:15,932] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:16,560] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:17,205] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:17,840] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:18,620] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:19,256] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:20,031] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  24%|██████████                                | 24/100 [04:53<16:15, 12.83s/it][2025-10-23 11:09:20,672] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:21,319] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:21,975] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:22,849] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:23,622] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:24,236] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:24,934] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:25,540] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:26,161] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:26,811] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:27,449] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:28,093] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:28,731] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:29,380] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:30,050] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:30,716] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:31,495] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:32,118] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:32,754] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:09:33,387] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  25%|██████████▌                               | 25/100 [05:07<16:14, 12.99s/it][2025-10-23 11:09:34,040] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# ...
# [2025-10-23 11:25:14,111] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:14,730] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:15,348] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:15,967] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:16,589] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:17,211] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  97%|████████████████████████████████████████▋ | 97/100 [20:50<00:37, 12.54s/it][2025-10-23 11:25:17,848] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:18,473] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:19,092] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:19,718] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:20,335] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:20,954] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:21,576] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:22,191] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:22,814] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:23,430] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:24,052] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:24,675] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:25,293] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:25,917] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:26,539] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:27,160] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:27,805] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:28,482] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:29,130] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:29,752] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  98%|█████████████████████████████████████████▏| 98/100 [21:03<00:25, 12.54s/it][2025-10-23 11:25:30,381] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:31,008] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:31,631] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:32,249] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:32,870] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:33,602] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:34,211] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:34,826] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:35,435] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:36,048] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:36,660] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:37,453] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:38,276] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:38,866] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:39,480] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:40,102] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:40,748] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:41,376] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:42,249] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:43,083] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  99%|█████████████████████████████████████████▌| 99/100 [21:16<00:12, 12.78s/it][2025-10-23 11:25:43,677] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:44,290] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:44,911] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:45,527] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:46,143] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:46,770] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:47,390] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:48,258] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:49,104] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:49,744] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:50,537] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:51,334] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:51,965] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:52,753] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:53,533] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:54,148] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:54,804] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:55,459] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:56,112] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:25:56,734] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# 100%|█████████████████████████████████████████| 100/100 [21:30<00:00, 12.90s/it]
# State([[ 5.49918988e+03  3.93591688e+00 -1.26861813e-01]
#  [ 5.49764242e+03  3.93488871e+00 -1.29209671e-01]
#  [ 5.49910447e+03  3.98600084e+00 -1.38685314e-01]
#  [ 5.49638361e+03  3.92487745e+00 -1.27681804e-01]
#  [ 5.49852920e+03  3.91729686e+00 -1.28132569e-01]
#  [ 5.49863047e+03  3.98659075e+00 -1.38918702e-01]
#  [ 5.49955363e+03  3.92204634e+00 -1.20101439e-01]
#  [ 5.49963665e+03  3.92495905e+00 -1.23448644e-01]
#  [ 5.49706675e+03  3.94566260e+00 -1.28081856e-01]
#  [ 5.49945455e+03  3.93840372e+00 -1.20161809e-01]
#  [ 5.49648040e+03  3.92536305e+00 -1.30248484e-01]
#  [ 5.49786759e+03  3.92726002e+00 -1.18730915e-01]
#  [ 5.49805099e+03  3.91980059e+00 -1.27318957e-01]
#  [ 5.49997713e+03  3.92714502e+00 -1.30615624e-01]
#  [ 5.49833344e+03  3.98450451e+00 -1.40473579e-01]
#  [ 5.49930943e+03  3.92331946e+00 -1.23436594e-01]
#  [ 5.49938332e+03  3.94320376e+00 -1.31534029e-01]
#  [ 5.49880936e+03  3.92617329e+00 -1.25123049e-01]
#  [ 5.49964821e+03  3.94396131e+00 -1.22251142e-01]
#  [ 5.49800829e+03  3.93450542e+00 -1.21645629e-01]], log_prob=[-4029481.30657926 -4032080.62570678 -4036983.99068134 -4032912.32764223
#  -4029237.00407404 -4038645.54332809 -4027834.16557072 -4026157.25648698
#  -4035486.88798452 -4031955.31698034 -4031577.73619196 -4033023.59736823
#  -4031255.91050518 -4027443.49460173 -4037078.65486575 -4026528.48947021
#  -4029404.33734388 -4027905.2134347  -4032097.42685876 -4032961.07591244], blobs=None, random_state=('MT19937', array([3838428464,  563559996, 1726601153,  152734736, 3778057304,
#        1597484976, 2955282214, 1683260798,  323496934, 3596497718,
#        3525859802, 2202616601, 1254311031,  259313173, 1967597203,
#        2998085312,  325806286, 1921693899, 3047065502, 4108922613,
#         259399093, 2580592839, 2544416800, 3235235142, 4232157922,
#        1981754589, 3029034430, 2359552759, 2192185401, 2355622318,
#        2586199307,  342246668,  794033805, 4009061987, 2844539734,
#        1013771727, 1149011055, 2605779661, 2320325371,  837174834,
#        2672001892,  355846537, 3034454035, 3323786590, 4119592826,
#        3611200797, 2317705009, 1728587426, 2146878215, 3334573738,
#        1367362864, 4194085227, 3378081416, 3784776411, 2847128504,
#        1166486906, 1667430080, 2855791101, 2166696791, 2268100771,
#        2650498276, 1591841137,   75696902,  674277592, 3756275423,
#        3676378805, 1090230890, 1530622670, 2100680419,  820893374,
#        2905822019, 2794601437, 3568594598, 3604086230,  633118134,
#        3857691656, 3971628165, 1062863963, 1448276158, 2661288859,
#        1663611414, 1212491559, 2279989782, 4195822105,  357238257,
#        2263074837, 2348385376, 3246084064, 1078374540, 4273752466,
#         181571953, 3421625324,  665177364, 2600980686, 1914683240,
#        2134604151, 3524771358, 4148912916,  247231864,  698000330,
#        2755722401, 3827879248, 3575649498,  783968170, 4166509313,
#         888034193, 3133640738, 1919423666,  473550322, 1637005279,
#        2959758256, 2938964475, 3417328926, 2321073175, 2446507393,
#        2253381147,  308487580,  571577226,  530427421, 3094613361,
#         327839387, 3261541370, 1378205304, 3836644131, 1621479440,
#         712333923,  319521142, 1779145327, 3119606233,  103137068,
#        2925197156, 2614784289, 1905807207, 2854633939,  264647434,
#        3323302704, 1670416475, 3201105709,  769085764,  948516165,
#        1753805257, 3918900249, 1365265723, 1858048637, 3663403181,
#         567371399,  597855514,  966602311, 1937552099, 3612161450,
#        3502594223, 1386196414, 1159995299, 2045363870, 1829240312,
#        2922866654, 1528629077, 2164174519, 2796408401, 1375000471,
#        3613361808, 2593211134, 4054665803, 2576632611, 3095787926,
#        1088664854, 1521093389,  935292639, 3478608903, 4280379122,
#        2489896649, 3491045669,  177778666, 3722739833,   40853039,
#        3790146773, 2595102466,  787216087, 1442273752, 2791448121,
#        2347036402, 1651397597,  567018320,  854359222, 3847626607,
#        1484202625, 2261564655, 2290359132, 3928954148, 1618979207,
#        3403307012, 2598624638, 2993366346, 3180651110, 1682075732,
#        1141290222, 2163500988, 2244848019, 3630871321, 1390451604,
#        3748680041,  698022921, 1893908703,  710391168, 4202598885,
#        2557987274, 2070869714, 2602037297, 4085519165, 2929267701,
#        1585475637, 2918548758,  407892631, 3268853135, 2119906741,
#        3349269289, 3292971158, 1675139592,  729511365, 2209392441,
#        3855466000, 1723233245, 1682347793, 1813463624, 2434283347,
#         940001366, 3704733657, 2397557847, 3150686858, 2371984216,
#        2399054159, 1019607272, 3326711646, 1265354049,  438947674,
#        3878258665,   91739050, 2687977334, 3824233353,  260469240,
#        1321204452, 3290150485, 4096636115, 2473026018, 1428101614,
#        3271755028,   59269647, 3527833880, 1330303047, 3887442131,
#        4282324502, 3984771435, 1191051780, 3732857872, 2673964439,
#         266220654, 4075940558, 1827783058, 1071365301, 2613083837,
#        1634016337, 3154351104,   98699817, 2144735538,  464927184,
#        1457756255, 3448059523, 2340130761, 3492193315,  317801514,
#        3460802789,  214430064, 3125171100, 1133285094,  336569212,
#        1217613115, 1179156255, 3947867228, 3506515799, 1099053753,
#        3729153948, 1196727334, 1941887573, 1267395426,   79989671,
#         629447878, 1663027293, 3044429285, 1357697466,  264388409,
#        1903751540, 2840034382, 2300592582,  953912079, 3185330344,
#        1065483766, 4011586605, 2810821165,  412548816, 2325563819,
#        3156296662, 3677243674,  521862401, 2853622897, 4226538280,
#        1421079812,   68311783,  389646311, 1350812777, 4244442460,
#         347230825, 1681121075, 1351761945, 2834836556, 3622396814,
#        2168590213, 2448206231, 3710791327, 3354515529, 2861141010,
#         194249070, 2429600941, 1843475720, 3763809888, 3172421245,
#         786637146, 4148200997, 3067746458, 1060091917, 3237658288,
#         902286811,  651469928,  602722361, 3007008965, 4109367076,
#        3196401980, 2010647198, 1042889156, 3795020169, 2249635690,
#        3408449084, 1141051675,  628962126, 1490290193, 4251266992,
#        1135046049, 2929951880, 3799786408,  201451100, 2931803592,
#        1026116735,  217141910,  681265376, 2750626592, 2779551442,
#         906738926, 2720472536, 2395334579, 1444826513, 2513026083,
#         489815684, 2631561381, 1772208344, 3995829144, 3488167841,
#        1905242710, 3294800083, 2923182908,  897747156, 2178046847,
#          30889798,  786933437,  761749903,  704598484, 1850124388,
#        3064454645, 3532065914,  573706140, 1948903552,  300814101,
#        3429359479,   84348802, 2763434050,  417602988, 3030136962,
#        2031393441, 3301919760, 4000521412, 3688754017, 1792861286,
#        3663880995, 2983818326,  666214142,  805844377, 1299118471,
#        2726940728, 1668561039, 2270092032,  567127558,   25839129,
#        2181050060, 2507621782, 1468900646,  345657539, 4100057197,
#        1703293334, 1758131153, 1090647829, 4250827285, 1703382451,
#        1742693420,  470403139, 3071525600,  761390435, 3004165191,
#        1769893444, 3101489001, 1335971978, 3711409087, 3398006765,
#        3770373423, 4214247523, 1149822690, 3516099178,  328190853,
#        2495033354,  617352779, 2757667114,  311541769, 2755785684,
#        2404083434, 1466497301, 1107026973, 2556081271, 1554460541,
#        1103487356,  550467137, 4121386587,  726206331, 2789381520,
#        1664284931, 2968034993, 1131601416, 4045976341, 2451797426,
#        3418610432, 1805049880,  670547608, 2809357496,  600120692,
#         294485710,  798059203, 2619019882, 1576622789, 2529450188,
#        3800093467, 3859297356, 3547562990, 1476278579, 1167123617,
#         967246445, 3757401823, 3914691684, 1676981046, 4121518427,
#        4237047515,   14944380, 3743467662, 2916195932, 1898733750,
#        2675707720,  101662313, 1896071336, 2849961808,  996604388,
#        2755227670, 2615314220, 2516503044, 2931093855, 3314967368,
#        3469418297,  481224695, 2806218598, 4112045067,  988849610,
#        3319520799, 3612902124, 3786174990,  596562829,  237012574,
#        2440471169,  586950038, 1243542893, 2117423585, 4170648399,
#         682419111,  643692075, 3014447027, 1548637428, 2427589832,
#        2671572955, 2670966020, 3197946336,  465156728,  379839385,
#        1700778341, 4253930170, 3581460659,  590378802, 2953020579,
#        1608940869, 1544702566, 2446557664, 1861114253, 3505418948,
#        3941887469, 3376707907, 1120385789, 3836213971, 2102237579,
#        3367985380, 1680784919, 2689141657,  342181844, 2963091867,
#        1194748579, 3108206771, 3243283455, 2623236899, 3318355676,
#        1692964850, 1035215863, 1093016704, 1582262200,  714431107,
#        3601551936, 1564329159, 1137503248,  402856134, 2811588380,
#        4169228589, 1514762509,  469437658,  688117513,  615509548,
#        3225167368, 1404214780, 3165794464, 2942872524, 3904538534,
#        4203327467,  835843265, 3465082045,  875143813, 1891471579,
#        3156357927, 1172078419, 1089256598, 1365794467, 3722436288,
#        2799081672,  416280047, 2443524569,  671288606, 2375064134,
#         454930392,  210374515, 2823021433, 2421161758, 3232413966,
#        2918487194, 1983693687, 3175420653, 1629472092,  461034369,
#         864065302, 3892218972, 2743351319,  992575724, 1334781224,
#        3256448250, 2333384043, 1642662480,  630193626, 3394943693,
#        1991371226, 2507796678, 1195812943, 2136022081, 3498678374,
#        2507999772, 3021149373,  913736156, 1791171051, 1960018965,
#        4139783810, 3049790284, 1332542193, 1199942099, 1733097300,
#          68276906, 4009123804,  344696462, 1749084138, 1342809713,
#        1684386813, 1521796380, 2809626082, 1490845495, 3122472521,
#        3881782810, 1584002031, 3597575941, 2892406459, 2729228287,
#        1817817133, 3839929662,  462372504, 1498964933, 2396813664,
#         461285742, 2750050597, 3720389197,  286317079], dtype=uint32), 440, 0, 0.0))

# %% [markdown]
# Let us plot the Walkers and Iterations. Check out for convergence in this plot. If you see the convergence you are good to go.

# %%
fig, axes = plt.subplots(3, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
accepted = sampler.backend.accepted.astype(bool)   #Here accepted indicated that the lines for each parameter below have converged/moved at least one time.

labels = ["teff","logg","MH"]
for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)
axes[-1].set_xlabel("step number");

# %% [markdown]
# Let us check how good is the fitting.....

# %%
fig, ax = plt.subplots(1, figsize=(10, 7), sharex=True)
samples = sampler.flatchain
theta_max  = samples[np.argmax(sampler.flatlnprobability)]
best_fit_model = synthesize_spectrum(theta_max)
ax.plot(x,y,alpha=0.3)
ax.plot(x,best_fit_model['flux'],alpha =0.3)
ax.plot(x,y-best_fit_model['flux'],alpha =0.3)
plt.savefig('t2.pdf')                                                                                                #CHANGE HERE
print(('Theta max: ',theta_max))             # Genarating the spectrum for the Maximum likelyhood function.
#NOTE THE SPIKES IN THE PLOT BELOW. THESE ARE DUE TO THE FACT THAT END POINTS OF THE SPECTRUMS ARE EXTRAPOLATED
# Out:
# [2025-10-23 11:25:57,694] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# ('Theta max: ', array([ 5.49963665e+03,  3.92495905e+00, -1.23448644e-01]))

# %% [markdown]
# Since the first few runs the walkers are exploring the parameter space and convergence have not yet been achived. We will ignore such runs. This is also known as "BURN-IN".

# %%
new_samples = sampler.get_chain(discard=10, thin=1, flat=False)
flat_samples = sampler.get_chain(discard=10, thin=1, flat=True)
                     # WE ARE ONLY CHOOSING THE VALUES FOR WHICH THE WALKER HAVE MOVED ATLEAST ONCE DURING THE ENTIRE ITERATION. Stagnent walkers indicates that the prior function might have returned -inf.

# %%
print(new_samples.shape)
# Out:
# (90, 20, 3)

# %% [markdown]
# Checking the Convergence after the BURN-IN... If it seems to be converged then it is DONE.

# %%
fig, axes = plt.subplots(3, figsize=(10, 7), sharex=True)
for i in range(ndim):
    ax = axes[i]
    ax.plot(new_samples[:, :, i], "k", alpha=0.3)
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)
axes[-1].set_xlabel("step number")
plt.savefig('t3.pdf')                                                                                                  #CHANGE HERE
flat_samples = new_samples.reshape(-1,new_samples.shape[2])
np.savetxt("ispec_sample1.txt",flat_samples,delimiter='\t')                                                                                   #CHANGE HERE

# %% [markdown]
# # Data Visualization!

# %%
import corner
from pandas.plotting import scatter_matrix

# %%
df = pd.read_csv('/home/anjalyrose/iSpec/ispec_sample.txt', delimiter='\t')

# Verify column names and types
print(df.head())
print(df.dtypes)

# Plot histogram for numeric columns
df.hist()
# Out:
#       waveobs      flux       err
# 0  515.002041  0.996187  0.011115
# 1  515.005141  0.978510  0.010948
# 2  515.008241  0.968782  0.010833
# 3  515.011240  0.938253  0.010563
# 4  515.014340  0.899014  0.010186
# waveobs    float64
# flux       float64
# err        float64
# dtype: object
# array([[<Axes: title={'center': 'waveobs'}>,
#         <Axes: title={'center': 'flux'}>],
#        [<Axes: title={'center': 'err'}>, <Axes: >]], dtype=object)

# %%
#df = df[df.logg < 4.451 ] #REMOVE ANY OUTLIER DISTRIBUTION

# %%
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde') #PLOTTING THE SCATTER MATRIX. I HAVE USED A VERY LIGHT DATASET FOR TEST PURPOSE> YOU CAN USE A MORE WALKER X ITERATION FOR A BETTER RESULT
# Out:
# array([[<Axes: xlabel='waveobs', ylabel='waveobs'>,
#         <Axes: xlabel='flux', ylabel='waveobs'>,
#         <Axes: xlabel='err', ylabel='waveobs'>],
#        [<Axes: xlabel='waveobs', ylabel='flux'>,
#         <Axes: xlabel='flux', ylabel='flux'>,
#         <Axes: xlabel='err', ylabel='flux'>],
#        [<Axes: xlabel='waveobs', ylabel='err'>,
#         <Axes: xlabel='flux', ylabel='err'>,
#         <Axes: xlabel='err', ylabel='err'>]], dtype=object)

# %%
samples = np.vstack([df]) #IT IS NECESSARY TO STACK THE DATA VERTICALLY TO OBTAIN THE DISTRIBUTION FROM THE DATA FRAME

# %%
value2 = np.mean(samples, axis=0) 
plt.rcParams["font.size"] = "10"     #THIS CHANGES THE FONT SIZE OF THE LABELS(NOT LEGEND)

# %%
#FINALLY... MAKING THE CORNER PLOT>>>>


#fig = corner.corner(df,show_titles=True,plot_datapoints=True,quantiles=[0.16, 0.5, 0.84],color ='black',levels=(1-np.exp(-0.5),),label_kwargs=dict(fontsize=20,color = 'black'),hist_kwargs=dict(fill = True,color = 'dodgerblue'),alpha =0.2)
fig = corner.corner(df,show_titles=True,plot_datapoints=True,quantiles=[0.16, 0.5, 0.84],color ='black',label_kwargs=dict(fontsize=20,color = 'black'),hist_kwargs=dict(fill = True,color = 'dodgerblue'),alpha =0.2)
axes = np.array(fig.axes).reshape((3, 3))
for i in range(3):
    ax = axes[i, i]
    ax.axvline(value2[i], color="r",alpha =0.8)
for yi in range(3):
    for xi in range(yi):
        ax = axes[yi, xi]
        ax.axvline(value2[xi], color="r",alpha =0.8,linestyle = 'dashed')
        ax.axhline(value2[yi], color="r",alpha =0.8,linestyle = 'dashed')
        ax.plot(value2[xi], value2[yi], "r")
#         plt.tight_layout()
#THE CORNER PLOT DONOT LOOK GREAT>> THE REASON IS FEW NUMBER OF DATA POINTS AND SHARP CONVERGENCE
