# %% [markdown]
# # iMCSpec (iSpec+emcee)

# %% [markdown]
# iMCSpec is a tool which combines iSpec(https://www.blancocuaresma.com/s/iSpec) and emcee(https://emcee.readthedocs.io/en/stable/) into a single unit to perform Bayesian analysis of spectroscopic data to estimate stellar parameters. For more details on the individual code please refer to the links above. This code have been tested on Syntehtic dataset as well as GAIA BENCHMARK stars (https://www.blancocuaresma.com/s/benchmarkstars). The example shown here is for the grid genarated MARCS.GES_atom_hfs. If you want to use any other grid, just download it from the https://www.cfa.harvard.edu/~sblancoc/iSpec/grid/ and make the necessary changes in the line_regions.

# %% [raw]
# Dependencies :
# iSpec : iSpec v2020.10.01
# python = 3+ Branch
# numpy>=1.18.5
# scipy>=1.5.0
# matplotlib>=3.2.2
# astropy>=4.0.1.post1
# lockfile>=0.12.2
# Cython>=0.29.21
# pandas>=1.0.5
# statsmodels>=0.11.1
# dill>=0.3.2
# emcee>=3.0.2
# corner>=2.1.1

# %% [markdown]
# Let us import all the necessary packages that are required for this analysis.

# %%
import sys
sys.path.append('/home/anjalyrose/iSpec')
import ispec
# Out:
# *********************************************************************
# Not optimized version loaded!
# *********************************************************************
# *********************************************************************
# Not optimized version loaded!
# *********************************************************************
# *********************************************************************
# Not optimized version loaded!
# *********************************************************************

# %%
import os
import sys
import numpy as np
import pandas as pd
import emcee
from multiprocessing import Pool
import matplotlib.pyplot as plt

os.environ["OMP_NUM_THREADS"] = "1"
os.environ['QT_QPA_PLATFORM']='offscreen'
os.environ["NUMEXPR_MAX_THREADS"] = "8"      #CHECK NUMBER OF CORES ON YOUR MACHINE AND CHOOSE APPROPRIATELY 

ispec_dir = '/home/anjalyrose/iSpec'            #MENTION YOUR DIRECTORY WHERE iSPEC is present     
sys.path.insert(0, os.path.abspath(ispec_dir))

import ispec
#np.seterr(all="ignore")                     #FOR MCMC THE WARNING COMES FOR RED BLUE MOVES WHEN ANY PARTICULAR WALKER VALUE DONOT LIE IN THE PARAMETER SPACE

# %% [markdown]
# Let us read the input spectra. Here I have the input spectrum in .txt format for reading the spectra. You can use the .fits format also for reading the spectra using Astropy (https://docs.astropy.org/en/stable/io/fits/). Please note that my input spectra is normalized and radial velocity (RV) corrected. For normalization and RV correction you can used iSpec or iraf.

# %%
df = pd.read_csv('/home/anjalyrose/iSpec/ispec_sample.txt', sep=r'\s+')  #ENTER YOUR INPUT SPECTRA
df = df[df.flux != 0]                                                   #FOR SOME SPECTROGRAPH PARTS OF SPECTRA ARE MISSING AND THE CORRESPONDING FLUX VALUES ARE LABELLED AS ZEROS. WE WANT TO IGNORE SUCH POINTS

x = df['waveobs'].values
y = df['flux'].values
yerr = df['err'].values
df = np.array(df,dtype=[('waveobs', '<f8'), ('flux', '<f8'), ('err', '<f8')])

# %% [markdown]
# You can perform the analysis on the entire spectrum or choose specific regions/segments for which you want to perform the analysis for.

# %%
#--- Read lines with atomic data ------------------------------------------------

# line_regions = ispec.read_line_regions(ispec_dir + "/input/regions/47000_GES/grid_synth_good_for_params_all.txt") #CHANGE THIS ACCORDINGLY FOR THE INPUT GRID          
# line_regions = ispec.adjust_linemasks(df, line_regions, max_margin=0.5)
# segments = ispec.create_segments_around_lines(line_regions, margin=0.5)   


#  ### Add also regions from the wings of strong lines:
# ## H beta
# hbeta_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/wings_Hbeta_segments.txt")
# #segments = hbeta_segments
# segments = np.hstack((segments, hbeta_segments))
# ## H ALPHA
# halpha_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/wings_Halpha_segments.txt")
# segments = np.hstack((segments, halpha_segments))
# ## MG TRIPLET
# mgtriplet_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/wings_MgTriplet_segments.txt")
# segments = np.hstack((segments, mgtriplet_segments))
##IRON
# fe_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/fe_lines_segments.txt")
# segments = np.hstack((segments, fe_segments))
##CALCIUM TRIPLET
# catriplet_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/Calcium_Triplet_segments.txt")
# segments = np.hstack((segments, catriplet_segments))
##Na doublet
# NaDoublet_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/Calcium_Triplet_segments.txt")
# segments = np.hstack((segments, NaDoublet_segments_segments))

# %%
# for j in range(len(segments)):
#     segments[j][0] = segments[j][0]+0.05
#     segments[j][1] = segments[j][1]-0.05
#YOU CAN CHANGE THE STARTING AND ENDING POINTS OF THE SEGEMENT

# %% [markdown]
# I will create a mask all false values with the same dimension as my original spectra in 1D. I will keep only those values of wavelength and flux for which the value falls in the segments (i.e, Mask is True).

# %%
# mask =np.zeros(x.shape,dtype =bool)
# for i in range(len(segments)):
#     mask|= (x>segments[i][0])&(x<segments[i][1])

# %%
# x = x[mask]                         #SELECTING THOSE VALUES ONLY FOR WHICH MASK VALUE IS TRUE
# y = y[mask]
# #yerr = yerr[mask]
yerr = y*0.0015                     #IF ERROR IS NOT SPECIFIED YOU CAN CHOOSE ACCORDINGLY

# %% [markdown]
# Now let us interpolate the spectrum using iSpec. Here for simplicity I have considered only Teff, log g and [M/H] as free parameters. Vmic and Vmac are obtained from emperical relations by Jofre et al.2013 and Maria Bergemann

# %%
def synthesize_spectrum(theta):
    teff ,logg ,MH = theta
#    alpha = ispec.determine_abundance_enchancements(MH)
    alpha =0.0
    microturbulence_vel = ispec.estimate_vmic(teff, logg, MH) 
    macroturbulence = ispec.estimate_vmac(teff, logg, MH) 
    limb_darkening_coeff = 0.6
    resolution = 47000
    vsini = 1.6                                                                                                                             #CHANGE HERE
    code = "grid"
    precomputed_grid_dir = ispec_dir + "/input/grid/SPECTRUM_MARCS.GES_GESv6_atom_hfs_iso.480_680nm_light/"

#    precomputed_grid_dir = ispec_dir + "/input/grid/SPECTRUM_MARCS.GES_GESv6_atom_hfs_iso.480_680nm_light/"
#    The light grid comes bundled with iSpec. It is just for testing purpose. Donot use it for Scientific purpose.
    grid = ispec.load_spectral_grid(precomputed_grid_dir)

    atomic_linelist = None
    isotopes = None
    modeled_layers_pack = None
    solar_abundances = None
    fixed_abundances = None
    abundances = None
    atmosphere_layers = None
    regions = None
        
    if not ispec.valid_interpolated_spectrum_target(grid, {'teff':teff, 'logg':logg, 'MH':MH, 'alpha':alpha, 'vmic': microturbulence_vel}):
        msg = "The specified effective temperature, gravity (log g) and metallicity [M/H] \
                fall out of the spectral grid limits."
        print(msg)

    # Interpolation
    synth_spectrum = ispec.create_spectrum_structure(x)
    synth_spectrum['flux'] = ispec.generate_spectrum(synth_spectrum['waveobs'], \
            atmosphere_layers, teff, logg, MH, alpha, atomic_linelist, isotopes, abundances, \
            fixed_abundances, microturbulence_vel = microturbulence_vel, \
            macroturbulence=macroturbulence, vsini=vsini, limb_darkening_coeff=limb_darkening_coeff, \
            R=resolution, regions=regions, verbose=1,
            code=code, grid=grid)
    return synth_spectrum

# %% [markdown]
# You can also synthesize the spectrum directly from various atmospheric models. A skeleton of the code taken from iSpec is shown below. For more details check example.py in iSpec.

# %%
# def synthesize_spectrum(theta,code="spectrum"):
#     teff ,logg ,MH = theta
#     resolution = 47000
#     alpha = ispec.determine_abundance_enchancements(MH)
#     microturbulence_vel = ispec.estimate_vmic(teff, logg, MH)
#     macroturbulence = ispec.estimate_vmac(teff, logg, MH)

#     limb_darkening_coeff = 0.6
#     regions = None

#     # Selected model amtosphere, linelist and solar abundances
    
#     #model = ispec_dir + "/input/atmospheres/MARCS/"
#     #model = ispec_dir + "/input/atmospheres/MARCS.GES/"
#     #model = ispec_dir + "/input/atmospheres/MARCS.APOGEE/"
#     #model = ispec_dir + "/input/atmospheres/ATLAS9.APOGEE/"
#     model = ispec_dir + "/input/atmospheres/ATLAS9.Castelli/"
#     #model = ispec_dir + "/input/atmospheres/ATLAS9.Kurucz/"
#     #model = ispec_dir + "/input/atmospheres/ATLAS9.Kirby/" 

#     #atomic_linelist_file = ispec_dir + "/input/linelists/transitions/VALD.300_1100nm/atomic_lines.tsv"
#     #atomic_linelist_file = ispec_dir + "/input/linelists/transitions/VALD.1100_2400nm/atomic_lines.tsv"
#     atomic_linelist_file = ispec_dir + "/input/linelists/transitions/GESv6_atom_hfs_iso.420_920nm/atomic_lines.tsv"
#     #atomic_linelist_file = ispec_dir + "/input/linelists/transitions/GESv6_atom_nohfs_noiso.420_920nm/atomic_lines.tsv"
    
#     isotope_file = ispec_dir + "/input/isotopes/SPECTRUM.lst"
    

#     atomic_linelist = ispec.read_atomic_linelist(atomic_linelist_file, wave_base=wave_base, wave_top=wave_top)
#     atomic_linelist = atomic_linelist[atomic_linelist['theoretical_depth'] >= 0.01]

#     isotopes = ispec.read_isotope_data(isotope_file)

#     if "ATLAS" in model:
#         solar_abundances_file = ispec_dir + "/input/abundances/Grevesse.1998/stdatom.dat"
#     else:
#         # MARCS
#         solar_abundances_file = ispec_dir + "/input/abundances/Grevesse.2007/stdatom.dat"
#     #solar_abundances_file = ispec_dir + "/input/abundances/Asplund.2005/stdatom.dat"
#     #solar_abundances_file = ispec_dir + "/input/abundances/Asplund.2009/stdatom.dat"
#     #solar_abundances_file = ispec_dir + "/input/abundances/Anders.1989/stdatom.dat"

#     modeled_layers_pack = ispec.load_modeled_layers_pack(model)
#     solar_abundances = ispec.read_solar_abundances(solar_abundances_file)
    
#     ## Custom fixed abundances
#     #fixed_abundances = ispec.create_free_abundances_structure(["C", "N", "O"], chemical_elements, solar_abundances)
#     #fixed_abundances['Abund'] = [-3.49, -3.71, -3.54] # Abundances in SPECTRUM scale (i.e., x - 12.0 - 0.036) and in the same order ["C", "N", "O"]
#     ## No fixed abundances
#     fixed_abundances = None

#     atmosphere_layers = ispec.interpolate_atmosphere_layers(modeled_layers_pack, {'teff':teff, 'logg':logg, 'MH':MH, 'alpha':alpha}, code=code)
#     synth_spectrum = ispec.create_spectrum_structure(x)
#     synth_spectrum['flux'] = ispec.generate_spectrum(synth_spectrum['waveobs'],
#             atmosphere_layers, teff, logg, MH, alpha, atomic_linelist, isotopes, solar_abundances,
#             fixed_abundances, microturbulence_vel = microturbulence_vel,
#             macroturbulence=macroturbulence, vsini=vsini, limb_darkening_coeff=limb_darkening_coeff,
#             R=resolution, regions=regions, verbose=0,
#             code=code)

#     return synth_spectrum

# %% [markdown]
# So far we have discussed about reading the input original spectra and interpolating the synthetic spectra from iSpec. Now the important part that comes into picture is to compare the original spectra and the interpolated spectra. For this we will use Montecarlo Markhov chain method to compare both the spectrums. For this we have used the emcee package by
# Dan Foreman-Mackey.

# %%
walkers = eval(input("Enter Walkers: "))    #WALKER IMPLIES THE INDEPENDENT RANDOMLY SELECTED PARAMETER SETS. NOTE IT SHOULD HAVE ATLEAST TWICE THE VALUE OF AVAILABLE FREE PARAMETERS
Iter = eval(input("Enter Iterations: "))    #ITERATION IMPLIES NUMBER OF RUNS THE PARAMETERS WILL BE CHECKED FOR CONVERGENCE. FOR MOST CASES 250-300 SHOULD DO.
# Out:
# Enter Walkers:  20
# Enter Iterations:  200

# %% [markdown]
# We will be creating four functions for this MCMC run. The first is straightforward, and is known as the model. The model function should take as an argument a list representing our θ vector, and return the model evaluated at that θ. For completion, your model function should also have your parameter array as an input. The form of this function comes from the Gaussian probability distribution P(x)dx.

# %%
def log_likelihood(theta):
    model = synthesize_spectrum(theta)    #GENARATING THE SPECTRUM FOR A GIVEN VALUE OF THETA
    sigma2 = yerr ** 2                    # FINDING THE Variance
    return -0.5 * np.sum((y - (model['flux'])) ** 2/ sigma2)     # returns the -chi^2/2 value

# %% [markdown]
# There is no unique way to set up your prior function. For the simplistic case we have choosen the log prior function returns zero if the input values genarated randomly lies wittin the specified ranges and -infinity if it doesnt(atleast one vale should satisty this criterion). You can choose your own prior function as well.

# %%
def log_prior(theta):
    teff, logg, MH = theta
    if 3200 < teff < 6900 and 1.1 < logg < 4.8 and -2.49 < MH <= 0.49 :                                                       #CHANGE HERE
        return 0.0
    return -np.inf

# %% [markdown]
# The last function we need to define is lnprob(). This function combines the steps above by running the lnprior function, and if the function returned -np.inf, passing that through as a return, and if not (if all priors are good), returning the lnlike for that model (by convention we say it’s the lnprior output + lnlike output, since lnprior’s output should be zero if the priors are good). lnprob needs to take as arguments theta,x,y,and yerr, since these get passed through to lnlike.

# %%
def log_probability(theta):
    lp = log_prior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood(theta)

# %% [markdown]
# Select input guess values and create intial set of stellar parameters RANDOMLY

# %%
initial = np.array([4800,3.8,-0.5])         #INPUT GUESS VALUES                                                         
pos = initial + np.array([100,0.1,0.1])*np.random.randn(walkers, 3)      # YOU CAN CHOOSE UNIFORM RANDOM FUNCTION OR GAUSSIAUN RANDOM NUMBER GENARATOR
nwalkers, ndim = pos.shape

# %% [markdown]
# Now we will run the EMCEE sampler to run the code. This will take some time depending on the your system. But don't worry :)

# %%
sampler = emcee.EnsembleSampler(nwalkers, ndim, log_probability)
sampler.run_mcmc(pos,Iter, progress=True)
# Out:
# [2025-10-24 09:36:02,103] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:02,506] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:02,999] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:03,489] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:03,884] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:04,281] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:04,677] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:05,287] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:05,888] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:06,391] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:06,810] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:07,228] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:07,620] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:08,011] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:08,403] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:08,800] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:09,223] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:09,837] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:10,345] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:10,741] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   0%|                                                   | 0/200 [00:00<?, ?it/s][2025-10-24 09:36:11,137] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:11,530] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:11,921] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:12,311] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:12,702] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:13,096] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:13,494] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:13,886] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:14,379] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:14,782] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:15,175] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:15,684] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:16,287] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:16,698] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:17,139] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:17,551] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:17,942] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:18,330] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:18,753] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:19,153] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   0%|▏                                          | 1/200 [00:08<27:53,  8.41s/it][2025-10-24 09:36:19,554] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:19,952] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:20,347] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:20,743] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:21,140] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:21,540] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:21,938] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:22,332] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:22,728] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:23,132] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:23,530] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:23,927] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:24,359] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:24,804] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:25,260] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:25,720] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:26,179] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:26,630] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:27,031] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:27,435] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   1%|▍                                          | 2/200 [00:16<27:30,  8.33s/it][2025-10-24 09:36:27,842] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:28,249] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:28,655] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:29,065] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:29,478] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:29,892] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:30,507] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:31,103] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:31,724] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:32,328] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:32,938] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:33,556] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:34,159] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:34,601] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:35,225] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:35,643] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:36,063] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:36,477] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:36,895] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:37,313] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   2%|▋                                          | 3/200 [00:26<29:40,  9.04s/it][2025-10-24 09:36:37,763] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:38,205] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:38,625] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:39,051] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:39,466] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:39,893] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:40,319] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:40,736] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:41,149] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:41,562] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:42,000] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:42,413] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:42,823] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:43,238] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:43,662] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:44,079] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:44,491] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:44,907] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:45,317] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:45,730] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   2%|▊                                          | 4/200 [00:34<28:43,  8.79s/it][2025-10-24 09:36:46,145] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:46,726] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:47,377] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:48,025] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:48,907] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:49,548] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:50,222] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:50,867] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:51,496] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:52,157] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:52,783] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:53,413] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:54,054] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:54,684] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:55,312] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:55,937] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:56,561] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:57,181] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:57,824] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:58,447] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   2%|█                                          | 5/200 [00:47<33:10, 10.21s/it][2025-10-24 09:36:59,303] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:36:59,905] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:00,525] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:01,165] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:01,831] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:02,498] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:03,203] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:03,902] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:04,585] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:05,254] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:05,949] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:06,648] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:07,332] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:08,031] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:08,736] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:09,390] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:10,238] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:10,923] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:11,576] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:12,248] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   3%|█▎                                         | 6/200 [01:01<36:57, 11.43s/it][2025-10-24 09:37:12,923] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:13,590] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:14,237] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:14,920] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:15,574] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:16,221] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:16,877] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:17,530] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:18,196] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:18,858] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:19,506] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:20,162] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:20,817] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:21,476] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:22,144] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:22,807] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:23,474] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:24,169] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:24,828] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:25,485] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   4%|█▌                                         | 7/200 [01:14<38:39, 12.02s/it][2025-10-24 09:37:26,337] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:27,189] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:27,986] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:28,659] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:29,490] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:30,137] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:30,986] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:31,638] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:32,296] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:32,960] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:33,613] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:34,282] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:34,945] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:35,596] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:36,250] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:36,925] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:37,571] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:38,224] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:38,858] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:39,477] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   4%|█▋                                         | 8/200 [01:28<40:28, 12.65s/it][2025-10-24 09:37:40,101] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:40,727] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:41,370] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:41,977] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:42,578] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:43,357] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:43,961] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:44,560] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:45,172] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:45,958] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:46,560] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:47,182] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:47,843] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:48,664] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:49,256] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:50,044] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:50,643] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:51,293] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:51,902] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:52,532] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   4%|█▉                                         | 9/200 [01:41<40:40, 12.78s/it][2025-10-24 09:37:53,162] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:53,780] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:54,394] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:55,004] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:55,633] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:56,490] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:57,292] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:58,124] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:58,923] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:37:59,738] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:00,342] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:00,957] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:01,573] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:02,217] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:02,837] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:03,493] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:04,141] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:04,773] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:05,425] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:06,077] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   5%|██                                        | 10/200 [01:55<41:12, 13.01s/it][2025-10-24 09:38:06,705] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:07,352] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:07,967] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:08,617] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:09,263] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:09,872] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:10,488] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:11,103] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:11,722] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:12,359] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:13,041] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:13,659] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:14,279] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:15,057] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:15,666] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:16,294] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:16,934] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:17,581] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:18,241] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:18,890] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   6%|██▎                                       | 11/200 [02:08<40:47, 12.95s/it][2025-10-24 09:38:19,549] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:20,325] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:21,093] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:21,857] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:22,649] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:23,295] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:23,917] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:24,540] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:25,165] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:25,778] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:26,394] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:27,016] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:27,630] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:28,248] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:28,873] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:29,493] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:30,288] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:30,893] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:31,510] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:32,130] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   6%|██▌                                       | 12/200 [02:21<40:51, 13.04s/it][2025-10-24 09:38:32,761] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:33,375] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:33,995] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:34,613] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:35,239] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:35,864] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:36,493] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:37,286] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:38,127] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:38,727] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:39,343] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:39,957] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:40,576] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:41,433] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:42,173] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:42,805] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:43,416] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:44,200] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:44,823] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:45,466] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   6%|██▋                                       | 13/200 [02:34<40:55, 13.13s/it][2025-10-24 09:38:46,090] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:46,704] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:47,309] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:47,919] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:48,534] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:49,140] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:49,752] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:50,361] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:50,973] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:51,590] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:52,214] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:52,827] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:53,442] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:54,048] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:54,664] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:55,274] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:55,909] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:56,530] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:57,148] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:57,774] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   7%|██▉                                       | 14/200 [02:47<39:55, 12.88s/it][2025-10-24 09:38:58,404] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:59,182] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:38:59,801] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:00,628] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:01,440] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:02,260] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:03,085] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:03,900] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:04,712] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:05,526] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:06,327] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:07,126] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:07,713] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:08,330] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:09,179] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:09,992] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:10,819] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:11,560] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:12,169] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:12,791] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   8%|███▏                                      | 15/200 [03:02<41:42, 13.52s/it][2025-10-24 09:39:13,413] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:14,203] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:14,811] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:15,431] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:16,048] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:16,823] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:17,661] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:18,453] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:19,267] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:20,083] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:20,667] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:21,289] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:21,906] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:22,525] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:23,146] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:23,772] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:24,386] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:25,002] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:25,626] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:26,245] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   8%|███▎                                      | 16/200 [03:15<41:24, 13.50s/it][2025-10-24 09:39:26,876] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:27,506] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:28,112] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:28,725] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:29,346] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:29,966] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:30,586] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:31,236] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:31,860] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:32,479] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:33,115] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:33,741] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:34,359] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:34,984] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:35,603] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:36,214] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:36,831] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:37,481] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:38,092] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:38,712] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   8%|███▌                                      | 17/200 [03:27<40:14, 13.19s/it][2025-10-24 09:39:39,354] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:39,958] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:40,564] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:41,174] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:41,786] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:42,421] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:43,025] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:43,649] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:44,292] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:44,917] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:45,580] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:46,207] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:46,977] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:47,579] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:48,220] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:48,854] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:49,462] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:50,091] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:50,733] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:51,519] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   9%|███▊                                      | 18/200 [03:40<39:39, 13.08s/it][2025-10-24 09:39:52,160] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:52,783] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:53,401] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:54,029] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:54,652] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:55,300] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:55,924] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:56,710] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:57,353] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:57,973] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:58,585] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:59,198] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:39:59,994] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:00,626] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:01,249] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:01,874] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:02,494] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:03,127] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:03,747] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:04,373] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  10%|███▉                                      | 19/200 [03:53<39:14, 13.01s/it][2025-10-24 09:40:04,994] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:05,604] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:06,215] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:06,832] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:07,444] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:08,062] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:08,786] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:09,393] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:09,999] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:10,609] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:11,218] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:11,832] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:12,441] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:13,052] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:13,660] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:14,272] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:14,906] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:15,554] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:16,204] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:17,069] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  10%|████▏                                     | 20/200 [04:06<38:44, 12.92s/it][2025-10-24 09:40:17,774] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:18,461] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:19,103] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:19,726] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:20,340] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:20,963] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:21,585] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:22,211] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:22,837] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:23,482] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:24,126] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:24,762] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:25,378] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:26,024] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:26,663] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:27,269] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:28,033] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:28,647] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:29,290] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:29,926] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  10%|████▍                                     | 21/200 [04:19<38:28, 12.90s/it][2025-10-24 09:40:30,566] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:31,225] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:31,855] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:32,490] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:33,103] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:33,883] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:34,721] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:35,535] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:36,287] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:36,971] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:37,720] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:38,338] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:38,956] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:39,558] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:40,165] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:40,769] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:41,393] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:42,008] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:42,621] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:43,237] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  11%|████▌                                     | 22/200 [04:32<38:37, 13.02s/it][2025-10-24 09:40:44,023] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:44,641] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:45,284] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:45,945] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:46,588] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:47,231] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:47,849] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:48,464] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:49,076] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:49,721] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:50,356] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:50,990] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:51,597] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:52,381] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:52,986] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:53,639] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:54,264] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:55,050] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:55,676] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:56,303] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  12%|████▊                                     | 23/200 [04:45<38:27, 13.04s/it][2025-10-24 09:40:56,933] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:57,554] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:58,343] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:58,953] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:40:59,595] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:00,211] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:00,879] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:01,492] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:02,116] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:02,772] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:03,426] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:04,057] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:04,677] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:05,315] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:06,094] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:06,851] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:07,456] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:08,106] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:08,723] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:09,337] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  12%|█████                                     | 24/200 [04:58<38:14, 13.03s/it][2025-10-24 09:41:09,955] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:10,569] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:11,189] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:11,812] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:12,668] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:13,243] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:13,857] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:14,477] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:15,098] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:15,703] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:16,308] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:16,929] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:17,576] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:18,215] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:18,826] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:19,454] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:20,070] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:20,678] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:21,292] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 09:41:21,903] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  12%|█████▎                                    | 25/200 [05:11<37:36, 12.89s/it][2025-10-24 09:41:22,560] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# ...
# [2025-10-24 10:17:52,080] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:17:52,859] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:17:53,510] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:17:54,169] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:17:54,818] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:17:55,472] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  98%|████████████████████████████████████████▍| 197/200 [41:44<00:40, 13.39s/it][2025-10-24 10:17:56,099] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:17:56,721] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:17:57,342] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:17:57,997] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:17:58,666] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:17:59,283] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:17:59,904] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:00,521] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:01,140] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:01,764] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:02,391] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:03,015] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:03,657] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:04,274] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:04,894] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:05,514] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:06,130] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:06,767] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:07,393] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:08,013] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  99%|████████████████████████████████████████▌| 198/200 [41:57<00:26, 13.13s/it][2025-10-24 10:18:08,662] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:09,286] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:09,910] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:10,559] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:11,184] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:11,807] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:12,424] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:13,047] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:13,666] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:14,294] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:14,914] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:15,538] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:16,155] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:16,775] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:17,397] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:18,017] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:18,750] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:19,364] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:19,986] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:20,693] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# 100%|████████████████████████████████████████▊| 199/200 [42:09<00:12, 13.00s/it][2025-10-24 10:18:21,343] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:22,006] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:22,630] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:23,287] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:23,911] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:24,622] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:25,393] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:25,986] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:26,601] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:27,220] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:27,844] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:28,463] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:29,081] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:29,699] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:30,558] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:31,149] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:31,764] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:32,383] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:33,011] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-24 10:18:33,638] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# 100%|█████████████████████████████████████████| 200/200 [42:22<00:00, 12.71s/it]
# State([[ 5.49624986e+03  3.98362658e+00 -1.42034307e-01]
#  [ 5.18616014e+03  3.78246122e+00 -4.70711183e-01]
#  [ 5.18805514e+03  3.75843635e+00 -4.67126675e-01]
#  [ 5.49812676e+03  3.94639026e+00 -1.16536312e-01]
#  [ 5.49609307e+03  3.94186238e+00 -1.18654359e-01]
#  [ 5.18778774e+03  3.77398691e+00 -4.65528705e-01]
#  [ 5.17979247e+03  3.77465139e+00 -4.75660250e-01]
#  [ 5.18956396e+03  3.79487189e+00 -4.68048532e-01]
#  [ 5.18671420e+03  3.78301414e+00 -4.70772668e-01]
#  [ 5.49995848e+03  3.93854754e+00 -1.13956445e-01]
#  [ 5.18232587e+03  3.75174889e+00 -4.72675932e-01]
#  [ 5.18708902e+03  3.78338838e+00 -4.71679523e-01]
#  [ 5.49521192e+03  3.94553401e+00 -1.26272408e-01]
#  [ 5.49473164e+03  3.94169351e+00 -1.21211976e-01]
#  [ 5.49978579e+03  3.92630767e+00 -1.13562107e-01]
#  [ 5.19150834e+03  3.79343079e+00 -4.66779564e-01]
#  [ 5.19237269e+03  3.77521086e+00 -4.67110005e-01]
#  [ 5.19862794e+03  3.80012711e+00 -4.61211424e-01]
#  [ 5.18240105e+03  3.74640938e+00 -4.69338159e-01]
#  [ 5.49499663e+03  3.93383540e+00 -1.17508938e-01]], log_prob=[-4041605.92326808 -4418756.35790815 -4419214.04706501 -4043610.11814204
#  -4044666.04503655 -4421575.59525859 -4420174.29911876 -4420732.11714171
#  -4418719.14800237 -4039077.45493152 -4419162.88313627 -4418168.50873501
#  -4043576.11016416 -4045742.53945224 -4032557.41255978 -4419697.44624321
#  -4419503.96219336 -4419609.27827143 -4419600.55684994 -4045308.67449042], blobs=None, random_state=('MT19937', array([1273483168, 2708838031, 2189550462, 2086888682,  105727344,
#        1674625251, 1670617022, 1792022039,  204802641, 3861476667,
#         686687121, 1734475420, 1462622841,   60308128, 2133143947,
#         131976725, 2748333579, 3976716799, 1636607527, 2389299535,
#        3590038057, 1071969448, 3898254623, 1499345455, 2895594649,
#        3203897865, 3888945009, 3418395297, 3769115062, 3662289756,
#        1813374027, 2494286082, 3789565433, 2747714644, 1942824998,
#        3737361577, 1689429114, 3591793873,   56729023,  693911631,
#        3169178463, 2808242026, 1027213814, 1871843053,  459971978,
#        4285126058, 4216253336, 2542478802, 4028469987, 3523386681,
#        2219126864, 2723717167, 4052162944, 3167056819, 2684708328,
#        3345493967, 3413004559, 1470670625, 3649806218, 1177549135,
#        2901075840,  260467293,  531560177, 3482802128, 2518060413,
#        3338999991, 4213650913, 3404515978,  812167268, 1273271204,
#        1539053192, 4019766403, 4064415123, 4223165336, 1000236877,
#        1775944910, 1744837426, 2111689906, 1559966783, 3789373601,
#         763725999, 1278433592, 2462253308, 2698017865, 1723056974,
#         875869054, 3532543766, 2124572026, 4077924034, 1516801951,
#        2789165499, 3528043331, 1328940628, 3945354450, 2281557214,
#         919033385, 2392799196, 3098171907, 2592456954, 1057110995,
#         169852942,  882586710, 4287496987, 2191298815, 1556874260,
#        2525970611, 3934899661, 2833440127, 4032253462, 3732950288,
#         717107919, 2606198327, 3242079824, 3731976349, 2335982778,
#        1172412282, 2302824072,  502498301,  508554469, 2489919128,
#        2435080123, 3267586772,  413739567, 3321398808, 2617687751,
#        3963107751,  703946865, 2827345724,  714537152, 2947543516,
#        3397952941, 3247427044, 2536493334, 4040978785,  670233119,
#        1626072615,  955294341, 3570760089, 2947492542, 2208199269,
#         861046154, 1078672351, 3193726704, 2005939255, 4259337100,
#        1448852280, 2585480606, 3928984334, 3410700508,  632913027,
#        1353657747, 1957841442, 3263286151,  427149279, 2909855179,
#        3839271362, 1156809903, 3711557167, 2323489202, 2109432732,
#        1113987393, 1066409203, 3074509665, 1166809715, 1293197678,
#         290070754,  546385657, 2482542759, 1361773644, 3585909608,
#        4233411403, 1535454899, 2735610568, 3288502024, 1011508376,
#        2250320254, 3414119780, 3658071462, 2880063421, 1886663268,
#        1915171572,  787123272, 1268389716, 2848954444, 2131363527,
#        1973747209, 2761851626, 2112311360, 2737977467, 2018241613,
#        1416499610, 1288402822, 1723692757,  731704432, 3480964246,
#          18900283, 3282825911,  708419225, 2229753276,  304521596,
#        2040985284, 3152236521, 2145468549,  512935922, 1273235222,
#        3348135651,  449539171, 3431269624,  322640684, 2126228625,
#         983808903,  815642287, 1906349631, 1202903066, 2146441561,
#        1999602375, 1966220557, 3695929009, 1476974488,  562075868,
#           6087878, 2160564848, 3595959304, 3062541038,  472799377,
#         167044874, 2090558102, 3525633736, 2340520492, 2131700960,
#         149310483, 3143961026,  268225032,  777614759, 4074086917,
#        3675870823, 2306784960,  947775405,  656204967, 3359461499,
#        3759217216, 3487303838, 2646206940, 2398658557, 3762069024,
#        3977796113, 2073917188,  566145693, 1467783959, 1348057683,
#        2516500662, 1941990624, 2390509405, 2979764772, 1105661530,
#         650360134, 2428417192,  265317811, 3597706635, 1119808750,
#        2191168554, 1897984473, 2899917489, 1533052335, 3980364668,
#        3356218035, 2968332738, 2754037682, 1421845372, 1597978449,
#         570894398, 3804530768, 1392314855, 2946420700, 3397777759,
#        2174300990, 3888201877, 1689247610, 1681301983,  509492325,
#        2967277218, 1740701020, 4153591098, 2990041009, 1720717047,
#        2266008017, 2444257530, 3965015951,  694956494, 1926813968,
#         911105320,  664914924,  139041880,  441395668, 4152723823,
#        3413413068, 1260444851, 2135838599,  637589231,  958539457,
#        1822769855,  893920597,  612239169, 1721359217, 1299191886,
#        1588786928, 2624369377, 3099401482, 1154532087, 3095014625,
#        3903848246,  899436685,  819026600, 1730883573,  373875727,
#        2042783306, 2844436054,  486630375, 1093449552, 1454686308,
#        1692486822, 1353654480, 3000184695,  174686582, 1532900319,
#        2837798081,  870255671, 4034833178,   36196254,  469192694,
#         751708527, 2402208198, 3050341340, 1714292691, 4093035682,
#        1944538937, 3822297145, 1629269964, 1044200331, 3833019053,
#        1394870787, 2150650261,  734237554, 2673613081, 2860586862,
#        2527021617, 3439778361,  947623660, 1292872986, 2972144348,
#        2056938701, 2545827945, 2061439914, 3260623771, 2202045825,
#        1451682054, 1435645244,  192005299, 2536853048, 3114689808,
#        4148376277, 1399213006, 3811495094, 2041930567, 2049736932,
#         232666275, 2521322488, 1460560919, 2079586280, 3910980986,
#        4142119640, 3930238141, 3821094603,  848296840, 1841324940,
#        2421595347, 2064344598,  686676116,  805934592, 1004619163,
#        1867241559, 1580377973, 1305127776, 2161380577,  786079014,
#        1281378697, 3777922770,  629747887, 3569712752,  101205682,
#         589886949, 2595708425, 1180214254,   20587521,  876209715,
#        2026992401,  940483693, 2738625431, 1679852703, 1562217443,
#        1421653405, 3225404821, 2413263515,  818083534, 1351474804,
#        3782250820, 4212521662, 2288051474,  631911999, 1119940051,
#         841320557, 3495994239, 1872643236, 2311579721, 1285010035,
#        2120166647, 3632639195, 3159280238,  265908977, 1539471659,
#         116488903, 3966602945, 3167088328, 4248614727, 1759813301,
#        1734340812, 2602221214,  941226432, 3415053100, 2493354547,
#        2101659692, 1825246049,  677032023, 3893306250, 4231935549,
#        1005998588,  897939494, 2465491771, 4159512703, 3600229550,
#        4275138346,  408294779,  181183299, 3058002592,  372473883,
#        2382630612, 3067765781, 4131685814, 2518870880, 2463663676,
#        1438361944, 4249556974, 3203594309, 3921493256, 4168641439,
#        4294619206, 3220007408, 1866880833, 1802648103, 2888475687,
#        3986491300,   54863257, 2184095582,  377287495, 3800433259,
#         602826869,  318415318,  220114389, 3618777777, 2441727900,
#        3260926478,  832382956, 2072995719, 4165316103, 3952585873,
#        3361987509, 2927054719, 2496885973, 2112671944,  573624143,
#        2337628298, 3204130598,  958221192, 2360904011, 1678853609,
#        1655602846,  681108543,  717005952, 3206621612, 2797272308,
#         121377547, 2580427147,  916265396, 1267605510,  279984941,
#         603780175, 2273793347, 2198787350, 2226530747, 2797159849,
#        2578611939, 2157782998, 1368921684,  974759195, 2957722635,
#         632786534, 1139854435, 1173627013, 2226070598, 1639535403,
#          88833829, 3930569699, 3770483035, 4043975223, 1558493233,
#        3146916440, 1845736535, 2544218304,  554734449,  839293283,
#        1970067996, 4104470423, 3877692331, 1390895486,  276558135,
#        3678359249, 3633123561, 3174705647, 3370122112,   65106058,
#        3304923828, 1732732424,  493487578, 1089578233, 3449030705,
#        4158877550,  255422140,  948076082, 2988512382, 3371396743,
#        3323898947, 2252004645, 3288481795, 3306897669, 2586226922,
#        2077533044, 1619847142,  725778567, 3971989386,  706530170,
#        3799936656, 1115215665, 1243044481, 2036534241, 1042474717,
#        2534820331, 1644619247,  899941958, 2097618681, 1156630915,
#        1684685441, 2315357522,  235893013, 4159178174, 3910372948,
#        3504305609,  569273625, 2724274198, 2874070350, 2232175565,
#        1588653254, 1724107641, 2097500838, 4109505971, 2625269953,
#        2644905893, 3645588614, 4047904128,  687858882,  530999217,
#         696841546, 1830126246, 2186798456, 1100064331, 2224359412,
#        3240916106,  814477784, 4188521704, 2074318214, 1591161458,
#        1279924770, 2596337959, 1927563892, 3348206291, 4100884038,
#        1719349457, 3081182151,  533980164,  338522267,  921711384,
#        3612681202, 1478612430,  256710663, 1420859753, 2164126242,
#        1857799479,  298698449, 1985155156, 1597375440, 1436457091,
#        1679953145,  566689193, 3307980972, 1374347080,  406916413,
#         469632770,  776690752, 2885107706, 3650869416, 2231225530,
#        2035083089, 1581818322,  194710030,  503137213], dtype=uint32), 64, 0, 0.0))

# %% [markdown]
# Let us plot the Walkers and Iterations. Check out for convergence in this plot. If you see the convergence you are good to go.

# %%
fig, axes = plt.subplots(3, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
accepted = sampler.backend.accepted.astype(bool)   #Here accepted indicated that the lines for each parameter below have converged/moved at least one time.

labels = ["teff","logg","MH"]
for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)
axes[-1].set_xlabel("step number");

# %% [markdown]
# Let us check how good is the fitting.....

# %%
fig, ax = plt.subplots(1, figsize=(10, 7), sharex=True)
samples = sampler.flatchain
theta_max  = samples[np.argmax(sampler.flatlnprobability)]
best_fit_model = synthesize_spectrum(theta_max)
ax.plot(x,y,alpha=0.3)
ax.plot(x,best_fit_model['flux'],alpha =0.3)
ax.plot(x,y-best_fit_model['flux'],alpha =0.3)
plt.savefig('t2.pdf')                                                                                                #CHANGE HERE
print(('Theta max: ',theta_max))             # Genarating the spectrum for the Maximum likelyhood function.
#NOTE THE SPIKES IN THE PLOT BELOW. THESE ARE DUE TO THE FACT THAT END POINTS OF THE SPECTRUMS ARE EXTRAPOLATED
# Out:
# [2025-10-24 10:18:34,568] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# ('Theta max: ', array([ 5.49978579e+03,  3.92630767e+00, -1.13562107e-01]))

# %% [markdown]
# Since the first few runs the walkers are exploring the parameter space and convergence have not yet been achived. We will ignore such runs. This is also known as "BURN-IN".

# %%
new_samples = sampler.get_chain(discard=10, thin=1, flat=False)
flat_samples = sampler.get_chain(discard=10, thin=1, flat=True)
                     # WE ARE ONLY CHOOSING THE VALUES FOR WHICH THE WALKER HAVE MOVED ATLEAST ONCE DURING THE ENTIRE ITERATION. Stagnent walkers indicates that the prior function might have returned -inf.

# %%
print(new_samples.shape)
# Out:
# (190, 20, 3)

# %% [markdown]
# Checking the Convergence after the BURN-IN... If it seems to be converged then it is DONE.

# %%
fig, axes = plt.subplots(3, figsize=(10, 7), sharex=True)
for i in range(ndim):
    ax = axes[i]
    ax.plot(new_samples[:, :, i], "k", alpha=0.3)
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)
axes[-1].set_xlabel("step number")
plt.savefig('t3.pdf')                                                                                                  #CHANGE HERE
flat_samples = new_samples.reshape(-1,new_samples.shape[2])
np.savetxt("ispec_sample1.txt",flat_samples,delimiter='\t')                                                                                   #CHANGE HERE

# %% [markdown]
# # Data Visualization!

# %%
import corner
from pandas.plotting import scatter_matrix

# %%
df = pd.read_csv('/home/anjalyrose/iSpec/ispec_sample.txt', delimiter='\t')

# Verify column names and types
print(df.head())
print(df.dtypes)

# Plot histogram for numeric columns
df.hist()
# Out:
#       waveobs      flux       err
# 0  515.002041  0.996187  0.011115
# 1  515.005141  0.978510  0.010948
# 2  515.008241  0.968782  0.010833
# 3  515.011240  0.938253  0.010563
# 4  515.014340  0.899014  0.010186
# waveobs    float64
# flux       float64
# err        float64
# dtype: object
# array([[<Axes: title={'center': 'waveobs'}>,
#         <Axes: title={'center': 'flux'}>],
#        [<Axes: title={'center': 'err'}>, <Axes: >]], dtype=object)

# %%
#df = df[df.logg < 4.451 ] #REMOVE ANY OUTLIER DISTRIBUTION

# %%
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde') #PLOTTING THE SCATTER MATRIX. I HAVE USED A VERY LIGHT DATASET FOR TEST PURPOSE> YOU CAN USE A MORE WALKER X ITERATION FOR A BETTER RESULT
# Out:
# array([[<Axes: xlabel='waveobs', ylabel='waveobs'>,
#         <Axes: xlabel='flux', ylabel='waveobs'>,
#         <Axes: xlabel='err', ylabel='waveobs'>],
#        [<Axes: xlabel='waveobs', ylabel='flux'>,
#         <Axes: xlabel='flux', ylabel='flux'>,
#         <Axes: xlabel='err', ylabel='flux'>],
#        [<Axes: xlabel='waveobs', ylabel='err'>,
#         <Axes: xlabel='flux', ylabel='err'>,
#         <Axes: xlabel='err', ylabel='err'>]], dtype=object)

# %%
samples = np.vstack([df]) #IT IS NECESSARY TO STACK THE DATA VERTICALLY TO OBTAIN THE DISTRIBUTION FROM THE DATA FRAME

# %%
value2 = np.mean(samples, axis=0) 
plt.rcParams["font.size"] = "10"     #THIS CHANGES THE FONT SIZE OF THE LABELS(NOT LEGEND)

# %%
## FINALLY... MAKING THE CORNER PLOT>>>>


#fig = corner.corner(df,show_titles=True,plot_datapoints=True,quantiles=[0.16, 0.5, 0.84],color ='black',levels=(1-np.exp(-0.5),),label_kwargs=dict(fontsize=20,color = 'black'),hist_kwargs=dict(fill = True,color = 'dodgerblue'),alpha =0.2)
fig = corner.corner(df,show_titles=True,plot_datapoints=True,quantiles=[0.16, 0.5, 0.84],color ='black',label_kwargs=dict(fontsize=20,color = 'black'),hist_kwargs=dict(fill = True,color = 'dodgerblue'),alpha =0.2)
axes = np.array(fig.axes).reshape((3, 3))
for i in range(3):
    ax = axes[i, i]
    ax.axvline(value2[i], color="r",alpha =0.8)
for yi in range(3):
    for xi in range(yi):
        ax = axes[yi, xi]
        ax.axvline(value2[xi], color="r",alpha =0.8,linestyle = 'dashed')
        ax.axhline(value2[yi], color="r",alpha =0.8,linestyle = 'dashed')
        ax.plot(value2[xi], value2[yi], "r")
#         plt.tight_layout()
#THE CORNER PLOT DONOT LOOK GREAT>> THE REASON IS FEW NUMBER OF DATA POINTS AND SHARP CONVERGENCE
