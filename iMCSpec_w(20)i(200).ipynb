# %% [markdown]
# # iMCSpec (iSpec+emcee)

# %% [markdown]
# iMCSpec is a tool which combines iSpec(https://www.blancocuaresma.com/s/iSpec) and emcee(https://emcee.readthedocs.io/en/stable/) into a single unit to perform Bayesian analysis of spectroscopic data to estimate stellar parameters. For more details on the individual code please refer to the links above. This code have been tested on Syntehtic dataset as well as GAIA BENCHMARK stars (https://www.blancocuaresma.com/s/benchmarkstars). The example shown here is for the grid genarated MARCS.GES_atom_hfs. If you want to use any other grid, just download it from the https://www.cfa.harvard.edu/~sblancoc/iSpec/grid/ and make the necessary changes in the line_regions.

# %% [raw]
# Dependencies :
# iSpec : iSpec v2020.10.01
# python = 3+ Branch
# numpy>=1.18.5
# scipy>=1.5.0
# matplotlib>=3.2.2
# astropy>=4.0.1.post1
# lockfile>=0.12.2
# Cython>=0.29.21
# pandas>=1.0.5
# statsmodels>=0.11.1
# dill>=0.3.2
# emcee>=3.0.2
# corner>=2.1.1

# %% [markdown]
# Let us import all the necessary packages that are required for this analysis.

# %%
import sys
sys.path.append('/home/anjalyrose/iSpec')
import ispec
# Out:
# *********************************************************************
# Not optimized version loaded!
# *********************************************************************
# *********************************************************************
# Not optimized version loaded!
# *********************************************************************
# *********************************************************************
# Not optimized version loaded!
# *********************************************************************

# %%
import os
import sys
import numpy as np
import pandas as pd
import emcee
from multiprocessing import Pool
import matplotlib.pyplot as plt

os.environ["OMP_NUM_THREADS"] = "1"
os.environ['QT_QPA_PLATFORM']='offscreen'
os.environ["NUMEXPR_MAX_THREADS"] = "8"      #CHECK NUMBER OF CORES ON YOUR MACHINE AND CHOOSE APPROPRIATELY 

ispec_dir = '/home/anjalyrose/iSpec'            #MENTION YOUR DIRECTORY WHERE iSPEC is present     
sys.path.insert(0, os.path.abspath(ispec_dir))

import ispec
#np.seterr(all="ignore")                     #FOR MCMC THE WARNING COMES FOR RED BLUE MOVES WHEN ANY PARTICULAR WALKER VALUE DONOT LIE IN THE PARAMETER SPACE

# %% [markdown]
# Let us read the input spectra. Here I have the input spectrum in .txt format for reading the spectra. You can use the .fits format also for reading the spectra using Astropy (https://docs.astropy.org/en/stable/io/fits/). Please note that my input spectra is normalized and radial velocity (RV) corrected. For normalization and RV correction you can used iSpec or iraf.

# %%
df = pd.read_csv('/home/anjalyrose/iSpec/ispec_sample.txt', sep=r'\s+')  #ENTER YOUR INPUT SPECTRA
df = df[df.flux != 0]                                                   #FOR SOME SPECTROGRAPH PARTS OF SPECTRA ARE MISSING AND THE CORRESPONDING FLUX VALUES ARE LABELLED AS ZEROS. WE WANT TO IGNORE SUCH POINTS

x = df['waveobs'].values
y = df['flux'].values
yerr = df['err'].values
df = np.array(df,dtype=[('waveobs', '<f8'), ('flux', '<f8'), ('err', '<f8')])

# %% [markdown]
# You can perform the analysis on the entire spectrum or choose specific regions/segments for which you want to perform the analysis for.

# %%
#--- Read lines with atomic data ------------------------------------------------

# line_regions = ispec.read_line_regions(ispec_dir + "/input/regions/47000_GES/grid_synth_good_for_params_all.txt") #CHANGE THIS ACCORDINGLY FOR THE INPUT GRID          
# line_regions = ispec.adjust_linemasks(df, line_regions, max_margin=0.5)
# segments = ispec.create_segments_around_lines(line_regions, margin=0.5)   


#  ### Add also regions from the wings of strong lines:
# ## H beta
# hbeta_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/wings_Hbeta_segments.txt")
# #segments = hbeta_segments
# segments = np.hstack((segments, hbeta_segments))
# ## H ALPHA
# halpha_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/wings_Halpha_segments.txt")
# segments = np.hstack((segments, halpha_segments))
# ## MG TRIPLET
# mgtriplet_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/wings_MgTriplet_segments.txt")
# segments = np.hstack((segments, mgtriplet_segments))
##IRON
# fe_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/fe_lines_segments.txt")
# segments = np.hstack((segments, fe_segments))
##CALCIUM TRIPLET
# catriplet_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/Calcium_Triplet_segments.txt")
# segments = np.hstack((segments, catriplet_segments))
##Na doublet
# NaDoublet_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/Calcium_Triplet_segments.txt")
# segments = np.hstack((segments, NaDoublet_segments_segments))

# %%
# for j in range(len(segments)):
#     segments[j][0] = segments[j][0]+0.05
#     segments[j][1] = segments[j][1]-0.05
#YOU CAN CHANGE THE STARTING AND ENDING POINTS OF THE SEGEMENT

# %% [markdown]
# I will create a mask all false values with the same dimension as my original spectra in 1D. I will keep only those values of wavelength and flux for which the value falls in the segments (i.e, Mask is True).

# %%
# mask =np.zeros(x.shape,dtype =bool)
# for i in range(len(segments)):
#     mask|= (x>segments[i][0])&(x<segments[i][1])

# %%
# x = x[mask]                         #SELECTING THOSE VALUES ONLY FOR WHICH MASK VALUE IS TRUE
# y = y[mask]
# #yerr = yerr[mask]
yerr = y*0.0015                     #IF ERROR IS NOT SPECIFIED YOU CAN CHOOSE ACCORDINGLY

# %% [markdown]
# Now let us interpolate the spectrum using iSpec. Here for simplicity I have considered only Teff, log g and [M/H] as free parameters. Vmic and Vmac are obtained from emperical relations by Jofre et al.2013 and Maria Bergemann

# %%
def synthesize_spectrum(theta):
    teff ,logg ,MH = theta
#    alpha = ispec.determine_abundance_enchancements(MH)
    alpha =0.0
    microturbulence_vel = ispec.estimate_vmic(teff, logg, MH) 
    macroturbulence = ispec.estimate_vmac(teff, logg, MH) 
    limb_darkening_coeff = 0.6
    resolution = 47000
    vsini = 1.6                                                                                                                             #CHANGE HERE
    code = "grid"
    precomputed_grid_dir = ispec_dir + "/input/grid/SPECTRUM_MARCS.GES_GESv6_atom_hfs_iso.480_680nm_light/"

#    precomputed_grid_dir = ispec_dir + "/input/grid/SPECTRUM_MARCS.GES_GESv6_atom_hfs_iso.480_680nm_light/"
#    The light grid comes bundled with iSpec. It is just for testing purpose. Donot use it for Scientific purpose.
    grid = ispec.load_spectral_grid(precomputed_grid_dir)

    atomic_linelist = None
    isotopes = None
    modeled_layers_pack = None
    solar_abundances = None
    fixed_abundances = None
    abundances = None
    atmosphere_layers = None
    regions = None
        
    if not ispec.valid_interpolated_spectrum_target(grid, {'teff':teff, 'logg':logg, 'MH':MH, 'alpha':alpha, 'vmic': microturbulence_vel}):
        msg = "The specified effective temperature, gravity (log g) and metallicity [M/H] \
                fall out of the spectral grid limits."
        print(msg)

    # Interpolation
    synth_spectrum = ispec.create_spectrum_structure(x)
    synth_spectrum['flux'] = ispec.generate_spectrum(synth_spectrum['waveobs'], \
            atmosphere_layers, teff, logg, MH, alpha, atomic_linelist, isotopes, abundances, \
            fixed_abundances, microturbulence_vel = microturbulence_vel, \
            macroturbulence=macroturbulence, vsini=vsini, limb_darkening_coeff=limb_darkening_coeff, \
            R=resolution, regions=regions, verbose=1,
            code=code, grid=grid)
    return synth_spectrum

# %% [markdown]
# You can also synthesize the spectrum directly from various atmospheric models. A skeleton of the code taken from iSpec is shown below. For more details check example.py in iSpec.

# %%
# def synthesize_spectrum(theta,code="spectrum"):
#     teff ,logg ,MH = theta
#     resolution = 47000
#     alpha = ispec.determine_abundance_enchancements(MH)
#     microturbulence_vel = ispec.estimate_vmic(teff, logg, MH)
#     macroturbulence = ispec.estimate_vmac(teff, logg, MH)

#     limb_darkening_coeff = 0.6
#     regions = None

#     # Selected model amtosphere, linelist and solar abundances
    
#     #model = ispec_dir + "/input/atmospheres/MARCS/"
#     #model = ispec_dir + "/input/atmospheres/MARCS.GES/"
#     #model = ispec_dir + "/input/atmospheres/MARCS.APOGEE/"
#     #model = ispec_dir + "/input/atmospheres/ATLAS9.APOGEE/"
#     model = ispec_dir + "/input/atmospheres/ATLAS9.Castelli/"
#     #model = ispec_dir + "/input/atmospheres/ATLAS9.Kurucz/"
#     #model = ispec_dir + "/input/atmospheres/ATLAS9.Kirby/" 

#     #atomic_linelist_file = ispec_dir + "/input/linelists/transitions/VALD.300_1100nm/atomic_lines.tsv"
#     #atomic_linelist_file = ispec_dir + "/input/linelists/transitions/VALD.1100_2400nm/atomic_lines.tsv"
#     atomic_linelist_file = ispec_dir + "/input/linelists/transitions/GESv6_atom_hfs_iso.420_920nm/atomic_lines.tsv"
#     #atomic_linelist_file = ispec_dir + "/input/linelists/transitions/GESv6_atom_nohfs_noiso.420_920nm/atomic_lines.tsv"
    
#     isotope_file = ispec_dir + "/input/isotopes/SPECTRUM.lst"
    

#     atomic_linelist = ispec.read_atomic_linelist(atomic_linelist_file, wave_base=wave_base, wave_top=wave_top)
#     atomic_linelist = atomic_linelist[atomic_linelist['theoretical_depth'] >= 0.01]

#     isotopes = ispec.read_isotope_data(isotope_file)

#     if "ATLAS" in model:
#         solar_abundances_file = ispec_dir + "/input/abundances/Grevesse.1998/stdatom.dat"
#     else:
#         # MARCS
#         solar_abundances_file = ispec_dir + "/input/abundances/Grevesse.2007/stdatom.dat"
#     #solar_abundances_file = ispec_dir + "/input/abundances/Asplund.2005/stdatom.dat"
#     #solar_abundances_file = ispec_dir + "/input/abundances/Asplund.2009/stdatom.dat"
#     #solar_abundances_file = ispec_dir + "/input/abundances/Anders.1989/stdatom.dat"

#     modeled_layers_pack = ispec.load_modeled_layers_pack(model)
#     solar_abundances = ispec.read_solar_abundances(solar_abundances_file)
    
#     ## Custom fixed abundances
#     #fixed_abundances = ispec.create_free_abundances_structure(["C", "N", "O"], chemical_elements, solar_abundances)
#     #fixed_abundances['Abund'] = [-3.49, -3.71, -3.54] # Abundances in SPECTRUM scale (i.e., x - 12.0 - 0.036) and in the same order ["C", "N", "O"]
#     ## No fixed abundances
#     fixed_abundances = None

#     atmosphere_layers = ispec.interpolate_atmosphere_layers(modeled_layers_pack, {'teff':teff, 'logg':logg, 'MH':MH, 'alpha':alpha}, code=code)
#     synth_spectrum = ispec.create_spectrum_structure(x)
#     synth_spectrum['flux'] = ispec.generate_spectrum(synth_spectrum['waveobs'],
#             atmosphere_layers, teff, logg, MH, alpha, atomic_linelist, isotopes, solar_abundances,
#             fixed_abundances, microturbulence_vel = microturbulence_vel,
#             macroturbulence=macroturbulence, vsini=vsini, limb_darkening_coeff=limb_darkening_coeff,
#             R=resolution, regions=regions, verbose=0,
#             code=code)

#     return synth_spectrum

# %% [markdown]
# So far we have discussed about reading the input original spectra and interpolating the synthetic spectra from iSpec. Now the important part that comes into picture is to compare the original spectra and the interpolated spectra. For this we will use Montecarlo Markhov chain method to compare both the spectrums. For this we have used the emcee package by
# Dan Foreman-Mackey.

# %%
walkers = eval(input("Enter Walkers: "))    #WALKER IMPLIES THE INDEPENDENT RANDOMLY SELECTED PARAMETER SETS. NOTE IT SHOULD HAVE ATLEAST TWICE THE VALUE OF AVAILABLE FREE PARAMETERS
Iter = eval(input("Enter Iterations: "))    #ITERATION IMPLIES NUMBER OF RUNS THE PARAMETERS WILL BE CHECKED FOR CONVERGENCE. FOR MOST CASES 250-300 SHOULD DO.
# Out:
# Enter Walkers:  20
# Enter Iterations:  200

# %% [markdown]
# We will be creating four functions for this MCMC run. The first is straightforward, and is known as the model. The model function should take as an argument a list representing our θ vector, and return the model evaluated at that θ. For completion, your model function should also have your parameter array as an input. The form of this function comes from the Gaussian probability distribution P(x)dx.

# %%
def log_likelihood(theta):
    model = synthesize_spectrum(theta)    #GENARATING THE SPECTRUM FOR A GIVEN VALUE OF THETA
    sigma2 = yerr ** 2                    # FINDING THE Variance
    return -0.5 * np.sum((y - (model['flux'])) ** 2/ sigma2)     # returns the -chi^2/2 value

# %% [markdown]
# There is no unique way to set up your prior function. For the simplistic case we have choosen the log prior function returns zero if the input values genarated randomly lies wittin the specified ranges and -infinity if it doesnt(atleast one vale should satisty this criterion). You can choose your own prior function as well.

# %%
def log_prior(theta):
    teff, logg, MH = theta
    if 3200 < teff < 6900 and 1.1 < logg < 4.8 and -2.49 < MH <= 0.49 :                                                       #CHANGE HERE
        return 0.0
    return -np.inf

# %% [markdown]
# The last function we need to define is lnprob(). This function combines the steps above by running the lnprior function, and if the function returned -np.inf, passing that through as a return, and if not (if all priors are good), returning the lnlike for that model (by convention we say it’s the lnprior output + lnlike output, since lnprior’s output should be zero if the priors are good). lnprob needs to take as arguments theta,x,y,and yerr, since these get passed through to lnlike.

# %%
def log_probability(theta):
    lp = log_prior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood(theta)

# %% [markdown]
# Select input guess values and create intial set of stellar parameters RANDOMLY

# %%
initial = np.array([5500,4.0,-0.1])         #INPUT GUESS VALUES                                                         
pos = initial + np.array([100,0.1,0.1])*np.random.randn(walkers, 3)      # YOU CAN CHOOSE UNIFORM RANDOM FUNCTION OR GAUSSIAUN RANDOM NUMBER GENARATOR
nwalkers, ndim = pos.shape

# %% [markdown]
# Now we will run the EMCEE sampler to run the code. This will take some time depending on the your system. But don't worry :)

# %%
sampler = emcee.EnsembleSampler(nwalkers, ndim, log_probability)
sampler.run_mcmc(pos,Iter, progress=True)
# Out:
# [2025-10-23 12:21:34,274] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:35,133] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:35,852] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:36,574] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:37,323] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:38,119] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:38,817] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:39,957] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:40,721] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:41,440] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:42,201] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:42,900] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:43,639] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:44,456] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:45,158] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:46,059] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:46,858] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:47,866] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:48,625] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:49,381] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   0%|                                                   | 0/200 [00:00<?, ?it/s][2025-10-23 12:21:50,172] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:50,936] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:51,652] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:52,536] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:53,528] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:54,573] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:55,303] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:56,106] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:56,803] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:57,520] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:58,266] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:58,961] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:21:59,654] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:00,425] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:01,155] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:01,893] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:02,626] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:03,370] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:04,070] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:04,805] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   0%|▏                                          | 1/200 [00:15<51:08, 15.42s/it][2025-10-23 12:22:05,548] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:06,331] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:07,072] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:07,777] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:08,528] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:09,238] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:09,952] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:10,695] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:11,436] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:12,185] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:12,934] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:13,685] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:14,382] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:15,130] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:15,879] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:16,599] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:17,331] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:18,096] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:18,835] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:19,631] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   1%|▍                                          | 2/200 [00:30<49:43, 15.07s/it][2025-10-23 12:22:20,428] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:21,212] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:21,910] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:22,602] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:23,314] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:24,019] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:24,720] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:25,602] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:26,368] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:27,126] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:27,889] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:28,580] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:29,327] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:30,036] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:30,814] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:31,547] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:32,296] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:33,015] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:33,736] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:34,447] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   2%|▋                                          | 3/200 [00:45<49:06, 14.95s/it][2025-10-23 12:22:35,217] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:35,942] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:36,653] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:37,386] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:38,128] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:38,887] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:39,601] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:40,326] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:41,029] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:41,726] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:42,421] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:43,114] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:43,808] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:44,557] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:45,327] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:46,393] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:47,142] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:47,907] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:49,029] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:49,826] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   2%|▊                                          | 4/200 [01:00<49:24, 15.12s/it][2025-10-23 12:22:50,639] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:51,673] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:52,775] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:53,526] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:54,272] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:55,008] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:55,786] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:56,563] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:57,318] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:58,067] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:58,808] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:22:59,550] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:00,297] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:01,115] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:01,872] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:02,653] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:03,431] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:04,212] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:05,012] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:05,750] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   2%|█                                          | 5/200 [01:16<50:05, 15.41s/it][2025-10-23 12:23:06,486] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:07,206] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:07,927] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:08,639] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:09,391] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:10,164] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:10,910] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:11,658] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:12,438] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:13,174] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:13,947] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:14,757] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:15,492] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:16,328] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:17,163] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:18,000] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:18,714] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:19,496] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:20,266] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:21,097] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   3%|█▎                                         | 6/200 [01:31<49:45, 15.39s/it][2025-10-23 12:23:21,815] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:22,561] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:23,313] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:24,081] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:24,896] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:25,639] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:26,419] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:27,209] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:28,026] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:28,851] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:29,593] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:30,580] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:31,353] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:32,151] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:32,917] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:33,696] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:34,505] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:35,295] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:36,161] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:36,986] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   4%|█▌                                         | 7/200 [01:47<50:01, 15.55s/it][2025-10-23 12:23:37,749] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:38,461] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:39,207] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:39,940] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:40,727] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:41,456] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:42,224] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:42,963] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:43,743] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:44,499] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:45,216] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:45,955] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:46,675] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:47,433] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:48,193] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:48,981] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:49,736] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:50,481] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:51,176] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:51,893] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   4%|█▋                                         | 8/200 [02:02<49:06, 15.35s/it][2025-10-23 12:23:52,582] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:53,266] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:54,022] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:54,755] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:55,495] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:56,225] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:56,949] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:57,681] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:58,708] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:23:59,426] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:00,116] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:01,103] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:01,793] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:02,497] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:03,457] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:04,155] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:04,854] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:05,559] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:06,272] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:06,972] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   4%|█▉                                         | 9/200 [02:17<48:35, 15.26s/it][2025-10-23 12:24:07,670] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:08,369] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:09,069] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:09,763] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:10,762] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:11,686] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:12,404] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:13,114] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:13,826] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:14,552] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:15,302] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:16,011] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:16,728] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:17,471] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:18,440] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:19,140] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:20,159] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:21,202] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:22,050] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:22,745] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   5%|██                                        | 10/200 [02:33<48:49, 15.42s/it][2025-10-23 12:24:23,471] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:24,299] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:25,001] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:25,715] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:26,788] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:27,501] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:28,191] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:28,888] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:29,591] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:30,282] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:31,018] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:31,849] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:32,553] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:33,254] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:33,959] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:34,676] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:35,385] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:36,105] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:36,809] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:37,512] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   6%|██▎                                       | 11/200 [02:48<47:56, 15.22s/it][2025-10-23 12:24:38,219] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:38,908] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:39,596] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:40,297] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:40,995] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:41,680] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:42,374] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:43,076] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:43,770] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:44,473] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:45,170] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:45,864] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:46,562] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:47,268] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:47,965] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:48,668] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:49,380] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:50,077] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:50,772] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:51,468] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   6%|██▌                                       | 12/200 [03:02<46:29, 14.84s/it][2025-10-23 12:24:52,174] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:52,860] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:53,562] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:54,251] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:54,939] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:55,627] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:56,317] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:57,015] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:57,944] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:58,635] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:24:59,324] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:00,010] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:00,696] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:01,382] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:02,061] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:02,740] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:03,436] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:04,131] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:04,826] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:05,523] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   6%|██▋                                       | 13/200 [03:16<45:30, 14.60s/it][2025-10-23 12:25:06,218] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:06,914] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:07,607] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:08,305] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:09,001] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:09,698] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:10,393] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:11,094] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:11,789] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:12,482] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:13,189] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:13,886] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:14,586] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:15,282] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:16,021] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:16,721] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:17,418] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:18,111] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:18,805] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:19,502] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   7%|██▉                                       | 14/200 [03:30<44:40, 14.41s/it][2025-10-23 12:25:20,200] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:20,895] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:21,594] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:22,291] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:22,992] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:23,690] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:24,391] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:25,091] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:25,794] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:26,494] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:27,196] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:27,896] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:28,598] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:29,300] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:30,001] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:30,702] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:31,402] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:32,108] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:32,809] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:33,510] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   8%|███▏                                      | 15/200 [03:44<44:03, 14.29s/it][2025-10-23 12:25:34,214] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:34,893] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:35,586] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:36,268] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:36,946] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:37,667] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:38,390] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:39,108] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:39,789] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:40,465] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:41,145] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:41,825] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:42,548] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:43,273] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:43,993] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:44,672] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:45,354] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:46,034] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:46,713] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:47,433] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   8%|███▎                                      | 16/200 [03:58<43:28, 14.18s/it][2025-10-23 12:25:48,120] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:48,802] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:49,480] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:50,420] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:51,142] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:51,875] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:52,561] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:53,250] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:53,936] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:54,623] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:55,354] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:56,042] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:56,728] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:57,429] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:58,124] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:58,821] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:25:59,519] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:00,221] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:00,920] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:01,623] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   8%|███▌                                      | 17/200 [04:12<43:15, 14.18s/it][2025-10-23 12:26:02,320] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:03,013] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:03,706] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:04,399] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:05,095] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:05,789] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:06,501] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:07,197] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:07,894] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:08,588] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:09,280] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:09,976] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:10,670] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:11,368] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:12,066] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:12,890] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:13,627] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:14,325] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:15,277] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:15,977] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   9%|███▊                                      | 18/200 [04:26<43:10, 14.23s/it][2025-10-23 12:26:16,713] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:17,453] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:18,137] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:18,830] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:19,567] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:20,348] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:21,085] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:21,783] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:22,482] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:23,176] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:23,873] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:24,567] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:25,263] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:25,960] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:26,658] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:27,365] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:28,065] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:28,811] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:29,513] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:30,214] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  10%|███▉                                      | 19/200 [04:40<42:56, 14.24s/it][2025-10-23 12:26:30,965] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:31,648] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:32,332] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:33,016] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:33,700] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:34,384] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:35,068] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:35,757] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:36,443] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:37,128] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:37,815] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:38,500] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:39,185] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:39,882] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:40,578] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:41,339] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:42,237] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:42,920] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:43,601] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:44,533] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  10%|████▏                                     | 20/200 [04:55<42:46, 14.26s/it][2025-10-23 12:26:45,217] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:45,954] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:46,634] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:47,312] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:47,994] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:48,690] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:49,381] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:50,072] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:50,768] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:51,460] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:52,155] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:52,848] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:53,539] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:54,230] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:54,919] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:55,605] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:56,303] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:56,993] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:57,689] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:58,379] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  10%|████▍                                     | 21/200 [05:08<42:10, 14.14s/it][2025-10-23 12:26:59,069] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:26:59,757] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:00,441] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:01,374] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:02,066] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:02,747] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:03,433] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:04,119] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:04,813] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:05,498] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:06,512] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:07,451] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:08,136] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:08,818] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:09,504] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:10,193] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:11,056] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:11,793] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:12,529] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:13,219] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  11%|████▌                                     | 22/200 [05:23<42:33, 14.35s/it][2025-10-23 12:27:13,910] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:14,598] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:15,287] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:15,979] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:16,675] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:17,369] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:18,058] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:18,754] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:19,446] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:20,141] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:20,834] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:21,526] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:22,218] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:22,911] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:23,602] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:24,292] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:24,980] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:25,666] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:26,352] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:27,037] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  12%|████▊                                     | 23/200 [05:37<41:51, 14.19s/it][2025-10-23 12:27:27,726] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:28,419] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:29,107] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:29,940] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:30,830] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:31,753] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:32,443] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:33,180] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:33,967] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:34,844] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:35,796] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:36,485] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:37,431] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:38,125] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:38,817] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:39,507] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:40,198] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:40,887] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:41,579] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:42,271] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  12%|█████                                     | 24/200 [05:52<42:32, 14.50s/it][2025-10-23 12:27:42,992] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:43,820] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:44,575] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:45,330] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:46,101] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:46,814] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:47,596] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:48,355] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:49,095] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:49,792] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:50,517] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:51,220] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:51,967] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:52,763] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:53,544] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:54,275] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:55,018] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:55,715] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:56,409] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:27:57,090] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  12%|█████▎                                    | 25/200 [06:07<42:34, 14.60s/it][2025-10-23 12:27:57,772] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# ...
# [2025-10-23 13:31:15,553] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:16,228] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:16,906] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:17,584] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:18,265] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:18,943] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  98%|██████████████████████████████████████▍| 197/200 [1:09:29<00:41, 13.89s/it][2025-10-23 13:31:19,621] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:20,298] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:20,974] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:21,652] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:22,331] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:23,009] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:23,688] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:24,370] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:25,050] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:25,728] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:26,404] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:27,086] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:27,762] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:28,440] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:29,116] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:29,793] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:30,473] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:31,170] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:31,845] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:32,517] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  99%|██████████████████████████████████████▌| 198/200 [1:09:43<00:27, 13.80s/it][2025-10-23 13:31:33,193] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:33,868] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:34,539] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:35,216] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:35,895] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:36,596] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:37,273] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:37,948] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:38,626] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:39,298] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:39,970] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:40,645] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:41,316] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:41,990] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:42,661] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:43,336] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:44,016] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:44,694] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:45,371] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:46,042] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# 100%|██████████████████████████████████████▊| 199/200 [1:09:56<00:13, 13.71s/it][2025-10-23 13:31:46,721] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:47,400] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:48,076] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:48,753] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:49,430] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:50,374] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:51,053] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:51,736] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:52,413] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:53,091] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:53,769] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:54,447] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:55,124] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:55,803] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:56,484] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:57,162] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:57,839] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:58,518] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:59,198] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 13:31:59,874] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# 100%|███████████████████████████████████████| 200/200 [1:10:10<00:00, 21.05s/it]
# State([[ 5.49991684e+03  3.92204719e+00 -1.21761275e-01]
#  [ 5.49993386e+03  3.92512230e+00 -1.23229599e-01]
#  [ 5.49951147e+03  3.92009728e+00 -1.29480897e-01]
#  [ 5.49983520e+03  3.92655123e+00 -1.23993456e-01]
#  [ 5.49986311e+03  3.92233674e+00 -1.22108679e-01]
#  [ 5.49977187e+03  3.92368578e+00 -1.22724248e-01]
#  [ 5.49983916e+03  3.92150750e+00 -1.21766521e-01]
#  [ 5.49976445e+03  3.92512254e+00 -1.23415694e-01]
#  [ 5.50205119e+03  4.00276884e+00 -1.39680115e-01]
#  [ 5.49983341e+03  3.92190558e+00 -1.21714657e-01]
#  [ 5.49977408e+03  3.92161019e+00 -1.21910548e-01]
#  [ 5.49947025e+03  3.91792876e+00 -1.29858526e-01]
#  [ 5.50170127e+03  4.00690574e+00 -1.42612508e-01]
#  [ 5.50151148e+03  4.00757453e+00 -1.43248955e-01]
#  [ 5.49997491e+03  3.92192054e+00 -1.21560347e-01]
#  [ 5.63083923e+03  4.07005506e+00 -1.16088530e-02]
#  [ 5.50182298e+03  4.00240561e+00 -1.40501128e-01]
#  [ 5.50185838e+03  4.00292458e+00 -1.40428519e-01]
#  [ 5.49946529e+03  3.91825350e+00 -1.29579703e-01]
#  [ 5.49985094e+03  3.92176209e+00 -1.21813345e-01]], log_prob=[-4025450.18232073 -4025504.04231171 -4027201.42963067 -4025810.90868845
#  -4025467.62718672 -4025792.22479919 -4025482.38649557 -4025869.59627941
#  -4044617.40891892 -4025676.72574115 -4025607.92770447 -4026911.02757426
#  -4043458.80031769 -4043204.9867819  -4025377.49429638 -4168714.97535125
#  -4044005.48473573 -4044131.31769579 -4026983.18854348 -4025504.96055711], blobs=None, random_state=('MT19937', array([ 903626741, 2853832598, 2096683408, 3660495366,  642126001,
#        3767256131,  164856439,  802683235,  508383916, 3430547069,
#        1122790085, 2458020800,  158830981, 3880746147,  547529147,
#        1855341682,  494860535, 1310515061, 3826395412,  496595856,
#        2340761690, 1908537856,  246732379, 2544031680, 1461027939,
#        3954620673, 3710484078,   71049963, 2432900267, 3635935843,
#        3780368032, 3801270438,  466735215, 1967144248, 1174395555,
#         815235308, 3562357816, 3490091889, 3693059615, 1339696952,
#        2156531610, 1727172714, 2224161360, 2497965868, 1769578005,
#         875978084, 1748379766, 2940885140, 3475318311,  326210224,
#        4150903105, 3038285024, 3262209745,  911124363, 4163847733,
#        3950244524, 4028043743, 2524202350,   68136174, 2894574791,
#        3580256194, 3387302112, 4146015298, 3487649739,  513416086,
#        3231189707, 3303895077,  368347201, 3922990486, 2059365859,
#        1075216591, 4229404277, 2918421163,  324938782,  182561673,
#        1396432676, 3544585789,  564246865,  693611993,  675049299,
#         536879167, 3445758356,  789146298, 1669106829, 1237477386,
#        3716089190, 2170227460, 3418821502, 2003489313, 2578944881,
#         413238910, 3576680600, 1837031309, 4141256626, 3396126173,
#        2147451000, 3200971164, 3339232648, 3870737585,  177298195,
#        3409212319, 1503791090,  421889342, 2036460730,  248353519,
#         968354325, 1699918075, 1210666411, 2197872658, 1334872135,
#         845962231, 3388436492, 3385688445, 2860760513, 1309945470,
#        1951458828, 3458118240, 1050300702, 1259331886,   48847404,
#        2773023526,  105959547, 1132320836, 2647703797, 1518311753,
#        2927723673, 1045059632, 3229280532, 1366728338, 1205112279,
#        2838862872, 1598892911,  665598427, 2597950782, 1919199781,
#         954923167, 3131829092, 1347772315,  777714113, 1977772146,
#        2779228500, 2251400807, 2534972720,   37038075,  408702646,
#         210144584,  527878732, 3156407326,   88662835, 1098789461,
#        3074422521, 3308638844, 1659916609, 2214131998,   17817944,
#        4147623758, 3306755214,  242641536, 3218246009, 3115181939,
#        1207093057, 4282099548, 3261327335, 3421864836, 2744309206,
#        3282454544, 1890691185, 1342502794, 1094100215,  594167265,
#        1001680772, 1845954693, 3525456989, 3189610809,   39147359,
#         369988865,  976938776,  930008946, 4160222874, 3431245845,
#        2213247371,  546919286, 2500629994,  681536645, 2941817044,
#         659591336, 3735505108, 1885685812, 3910345523,  158843925,
#        2164598882, 2997896907, 4005445640, 3989812546, 3489857423,
#         798165103, 4210793976, 1730425715, 3884902864, 2164451431,
#         860948323, 1747091709,  720728001, 2294278395, 2679232437,
#        3689694764, 3052876011, 4209003662, 4013397193, 1955654279,
#        3382832343, 2659395711, 3597847052, 3489175506, 4030605344,
#         991781356, 3176797815, 3606688493, 2169094357, 3121295662,
#        2994755470, 1294692571,  924690577, 3610238848, 2051595428,
#        1120263379, 2426393641, 1612462177, 2966745157, 2039493889,
#         829161345, 1746177064,  850914926, 1668349992, 2517937651,
#        3891224308, 2520647827, 2370026220,  963111693,  502881015,
#        1401578128,  932960715, 1960686721, 1046385103, 2832227101,
#        1055927929,  216221787, 2309171503, 1213866148, 1722795066,
#        1589416025, 2328469265, 2955708977, 1238700502, 3702316720,
#        2196136662, 2895239448, 2322831819, 3897980372,  930605906,
#        2478233807, 1175722197,  326021902, 4119386172, 3051919538,
#         776736066,  432622151, 1940022969, 2032460167, 3344426188,
#        1112221909, 1205419171, 2728685857, 3612179707, 4101207243,
#        3329380309,  818706190,  823653647, 4094339292, 1551294795,
#        1260404400, 2979083333, 2586757391, 4142392393,  498388650,
#        3086739780, 2710493950, 1960904856, 2187594579,  755038220,
#        2354398839, 2119070788, 1226408379, 3303682489, 1044546470,
#        2243753320, 3066584826,  565553909, 2410846196, 3553289055,
#         625973860,  763884337, 2293325849, 1755744792, 1867276781,
#        2938486450, 2711399376, 3361141640, 3156306138, 3175622514,
#        4149366079,   87840424, 1099306724, 3701795123, 2919973284,
#         963652484, 3933798349, 1863582016, 4045461268,  876247757,
#         255349920, 4215942786,  502498902, 2527873131, 3366356853,
#        1543094779, 4113247286,  951717001, 1331978407,   90289635,
#        2866022118, 2911881193, 3108174245, 1726925817, 1420270966,
#          83664941, 1355222113,  355574408, 2514446150, 1712490395,
#        1965448988, 2871020719, 2840844037, 1479532196,  451726174,
#        3013265820, 1977295951, 1471618546, 1026352836, 3480782531,
#        2913383021, 1224610793, 1908903367, 3335157055, 3883496853,
#        2273812736,  240225532, 1608789850, 3466057156,  928410574,
#        3706137120,   22461750, 3222940594,  687293865, 3128982507,
#        1281366322, 4094808678, 3022432961, 2472985076, 1667266504,
#        4258924464, 1347882265,  247104950, 1357337301, 1930290572,
#        2921159563,  767822122,  454405527, 2349269333, 1891896792,
#        2820088885,  408327460, 2823904656, 3241689592, 2762391822,
#         532172645, 1522729297,  538463020, 2086218826,  131914861,
#        1467282173,  120367742,  610665490, 3893058922, 4018527345,
#        1361161357,  583397218,  993244791, 1659892253, 1843243704,
#        1370417983,  906647441,  511124900, 1307283773, 3064553649,
#        2302010156,  226913232, 1912913608, 3611266397, 4233263473,
#        3775237947, 1579997948,  287669213,  959956592,  290688153,
#        1110093710, 3115838515, 3530999316,  989922644,  564511919,
#         515812470, 3017638379, 3373580606, 3368238136, 1948451749,
#         449450138, 2393937415,  212169023, 2876209247, 4188621129,
#        3226204793, 3870207468, 1851164191, 2573517199, 2165574778,
#        2097668204,   51960936, 3669651948, 3176487136, 1986447750,
#         752465368, 1955688992, 1157397997, 2855296396, 3300543685,
#         836828804, 3053423407, 1106799524, 1798447184, 2885678900,
#        3845718151, 2729491086, 3610388234, 3492574591,  458166169,
#        1245773875, 3357474735, 1467626243,  629822515, 1582658063,
#         675869262, 1697720549, 3101182053, 3857404403,  928029118,
#        3442767566, 2409364148, 2265403513, 1470924413, 1138609586,
#        2218740293, 1070863413, 2614261240,   63886266,   15071913,
#        4167341956,  558793006, 1547665275, 3605052493, 3770357903,
#        2494970254, 1342364427, 3229656429, 3734826262, 4144401585,
#        2310753908, 2768060776, 3125303614, 4113120651, 4262632234,
#        1690316445, 3383992520, 2311097102,  675948101, 2010992072,
#        3956751179, 2516158053, 1961477534, 1071329803, 1016389371,
#        2061764253, 1540933226, 2326704861, 1654282928, 2280220421,
#         154769452, 4000919070, 2266032288,  754074423,  728610525,
#        3411334551,  849226604, 1134240124, 1736823669,  349694028,
#        1606607066, 1227696931, 1202482074, 2873542678,  259726689,
#         638623505,   92974489, 1444397426, 3858298831, 3409164957,
#         392350502, 2923035858, 4278525403, 3049122206,  889758174,
#        3979753621, 3198814463,  243540365, 3516817481,  129173053,
#        1688646353, 2880461682, 3104687737, 2577138170,  194274144,
#        2459003626, 3226621053, 4072717756, 2994754233, 3572058138,
#        2698623135, 1942268984, 1224412564, 3466074726, 2277938292,
#        3939999510, 2959503249, 2956935627, 3841436303, 4153947837,
#        1857094763, 1975489235, 2629235450,  726045791, 1664454061,
#        2235970457,  131769437, 2039267965, 1315276774,  399002021,
#        3210665732,   56310637,   57060357,  561230904, 3015533205,
#        1980794568, 1845780717, 1252784081, 2369176347, 1750196359,
#        1790740384, 3793621020, 1004979943,   72186246,  447918826,
#         172596744,  624283219,  541627521, 1428681639, 3645710416,
#        2569293617,  724493879, 3598350843, 2058591564, 4177537273,
#        1537692050,  214353663, 4084881349, 3917234369, 3479556108,
#        2842555140, 3858201580, 3563304801,  572113338,  188107315,
#          50521089,    5535023, 3230438012,  560594710, 1704703210,
#         498231328, 3022447421, 1625860302, 3763940262, 1326236481,
#        3688968789, 2457508294, 1700092684, 3134195392,  826361885,
#        2115194680,  810250435, 3367287942,  666243493,  637335089,
#        2346137475,  519827198,  540984695, 2703441991], dtype=uint32), 17, 0, 0.0))

# %% [markdown]
# Let us plot the Walkers and Iterations. Check out for convergence in this plot. If you see the convergence you are good to go.

# %%
fig, axes = plt.subplots(3, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
accepted = sampler.backend.accepted.astype(bool)   #Here accepted indicated that the lines for each parameter below have converged/moved at least one time.

labels = ["teff","logg","MH"]
for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)
axes[-1].set_xlabel("step number");

# %% [markdown]
# Let us check how good is the fitting.....

# %%
fig, ax = plt.subplots(1, figsize=(10, 7), sharex=True)
samples = sampler.flatchain
theta_max  = samples[np.argmax(sampler.flatlnprobability)]
best_fit_model = synthesize_spectrum(theta_max)
ax.plot(x,y,alpha=0.3)
ax.plot(x,best_fit_model['flux'],alpha =0.3)
ax.plot(x,y-best_fit_model['flux'],alpha =0.3)
plt.savefig('t2.pdf')                                                                                                #CHANGE HERE
print(('Theta max: ',theta_max))             # Genarating the spectrum for the Maximum likelyhood function.
#NOTE THE SPIKES IN THE PLOT BELOW. THESE ARE DUE TO THE FACT THAT END POINTS OF THE SPECTRUMS ARE EXTRAPOLATED
# Out:
# [2025-10-23 13:32:00,826] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# ('Theta max: ', array([ 5.49997491e+03,  3.92192054e+00, -1.21560347e-01]))

# %% [markdown]
# Since the first few runs the walkers are exploring the parameter space and convergence have not yet been achived. We will ignore such runs. This is also known as "BURN-IN".

# %%
new_samples = sampler.get_chain(discard=10, thin=1, flat=False)
flat_samples = sampler.get_chain(discard=10, thin=1, flat=True)
                     # WE ARE ONLY CHOOSING THE VALUES FOR WHICH THE WALKER HAVE MOVED ATLEAST ONCE DURING THE ENTIRE ITERATION. Stagnent walkers indicates that the prior function might have returned -inf.

# %%
print(new_samples.shape)
# Out:
# (190, 20, 3)

# %% [markdown]
# Checking the Convergence after the BURN-IN... If it seems to be converged then it is DONE.

# %%
fig, axes = plt.subplots(3, figsize=(10, 7), sharex=True)
for i in range(ndim):
    ax = axes[i]
    ax.plot(new_samples[:, :, i], "k", alpha=0.3)
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)
axes[-1].set_xlabel("step number")
plt.savefig('t3.pdf')                                                                                                  #CHANGE HERE
flat_samples = new_samples.reshape(-1,new_samples.shape[2])
np.savetxt("ispec_sample1.txt",flat_samples,delimiter='\t')                                                                                   #CHANGE HERE

# %% [markdown]
# # Data Visualization!

# %%
import corner
from pandas.plotting import scatter_matrix

# %%
df = pd.read_csv('/home/anjalyrose/iSpec/ispec_sample.txt', delimiter='\t')

# Verify column names and types
print(df.head())
print(df.dtypes)

# Plot histogram for numeric columns
df.hist()
# Out:
#       waveobs      flux       err
# 0  515.002041  0.996187  0.011115
# 1  515.005141  0.978510  0.010948
# 2  515.008241  0.968782  0.010833
# 3  515.011240  0.938253  0.010563
# 4  515.014340  0.899014  0.010186
# waveobs    float64
# flux       float64
# err        float64
# dtype: object
# array([[<Axes: title={'center': 'waveobs'}>,
#         <Axes: title={'center': 'flux'}>],
#        [<Axes: title={'center': 'err'}>, <Axes: >]], dtype=object)

# %%
#df = df[df.logg < 4.451 ] #REMOVE ANY OUTLIER DISTRIBUTION

# %%
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde') #PLOTTING THE SCATTER MATRIX. I HAVE USED A VERY LIGHT DATASET FOR TEST PURPOSE> YOU CAN USE A MORE WALKER X ITERATION FOR A BETTER RESULT
# Out:
# array([[<Axes: xlabel='waveobs', ylabel='waveobs'>,
#         <Axes: xlabel='flux', ylabel='waveobs'>,
#         <Axes: xlabel='err', ylabel='waveobs'>],
#        [<Axes: xlabel='waveobs', ylabel='flux'>,
#         <Axes: xlabel='flux', ylabel='flux'>,
#         <Axes: xlabel='err', ylabel='flux'>],
#        [<Axes: xlabel='waveobs', ylabel='err'>,
#         <Axes: xlabel='flux', ylabel='err'>,
#         <Axes: xlabel='err', ylabel='err'>]], dtype=object)

# %%
samples = np.vstack([df]) #IT IS NECESSARY TO STACK THE DATA VERTICALLY TO OBTAIN THE DISTRIBUTION FROM THE DATA FRAME

# %%
value2 = np.mean(samples, axis=0) 
plt.rcParams["font.size"] = "10"     #THIS CHANGES THE FONT SIZE OF THE LABELS(NOT LEGEND)

# %% [markdown]
# ## FINALLY... MAKING THE CORNER PLOT>>>>
#
#
# #fig = corner.corner(df,show_titles=True,plot_datapoints=True,quantiles=[0.16, 0.5, 0.84],color ='black',levels=(1-np.exp(-0.5),),label_kwargs=dict(fontsize=20,color = 'black'),hist_kwargs=dict(fill = True,color = 'dodgerblue'),alpha =0.2)
# fig = corner.corner(df,show_titles=True,plot_datapoints=True,quantiles=[0.16, 0.5, 0.84],color ='black',label_kwargs=dict(fontsize=20,color = 'black'),hist_kwargs=dict(fill = True,color = 'dodgerblue'),alpha =0.2)
# axes = np.array(fig.axes).reshape((3, 3))
# for i in range(3):
#     ax = axes[i, i]
#     ax.axvline(value2[i], color="r",alpha =0.8)
# for yi in range(3):
#     for xi in range(yi):
#         ax = axes[yi, xi]
#         ax.axvline(value2[xi], color="r",alpha =0.8,linestyle = 'dashed')
#         ax.axhline(value2[yi], color="r",alpha =0.8,linestyle = 'dashed')
#         ax.plot(value2[xi], value2[yi], "r")
# #         plt.tight_layout()
# #THE CORNER PLOT DONOT LOOK GREAT>> THE REASON IS FEW NUMBER OF DATA POINTS AND SHARP CONVERGENCE
