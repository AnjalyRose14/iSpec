# %% [markdown]
# # iMCSpec (iSpec+emcee)

# %% [markdown]
# iMCSpec is a tool which combines iSpec(https://www.blancocuaresma.com/s/iSpec) and emcee(https://emcee.readthedocs.io/en/stable/) into a single unit to perform Bayesian analysis of spectroscopic data to estimate stellar parameters. For more details on the individual code please refer to the links above. This code have been tested on Syntehtic dataset as well as GAIA BENCHMARK stars (https://www.blancocuaresma.com/s/benchmarkstars). The example shown here is for the grid genarated MARCS.GES_atom_hfs. If you want to use any other grid, just download it from the https://www.cfa.harvard.edu/~sblancoc/iSpec/grid/ and make the necessary changes in the line_regions.

# %% [raw]
# Dependencies :
# iSpec : iSpec v2020.10.01
# python = 3+ Branch
# numpy>=1.18.5
# scipy>=1.5.0
# matplotlib>=3.2.2
# astropy>=4.0.1.post1
# lockfile>=0.12.2
# Cython>=0.29.21
# pandas>=1.0.5
# statsmodels>=0.11.1
# dill>=0.3.2
# emcee>=3.0.2
# corner>=2.1.1

# %% [markdown]
# Let us import all the necessary packages that are required for this analysis.

# %%
import sys
sys.path.append('/home/anjalyrose/iSpec')
import ispec
# Out:
# *********************************************************************
# Not optimized version loaded!
# *********************************************************************
# *********************************************************************
# Not optimized version loaded!
# *********************************************************************
# *********************************************************************
# Not optimized version loaded!
# *********************************************************************

# %%
import os
import sys
import numpy as np
import pandas as pd
import emcee
from multiprocessing import Pool
import matplotlib.pyplot as plt

os.environ["OMP_NUM_THREADS"] = "1"
os.environ['QT_QPA_PLATFORM']='offscreen'
os.environ["NUMEXPR_MAX_THREADS"] = "8"      #CHECK NUMBER OF CORES ON YOUR MACHINE AND CHOOSE APPROPRIATELY 

ispec_dir = '/home/anjalyrose/iSpec'            #MENTION YOUR DIRECTORY WHERE iSPEC is present     
sys.path.insert(0, os.path.abspath(ispec_dir))

import ispec
#np.seterr(all="ignore")                     #FOR MCMC THE WARNING COMES FOR RED BLUE MOVES WHEN ANY PARTICULAR WALKER VALUE DONOT LIE IN THE PARAMETER SPACE

# %% [markdown]
# Let us read the input spectra. Here I have the input spectrum in .txt format for reading the spectra. You can use the .fits format also for reading the spectra using Astropy (https://docs.astropy.org/en/stable/io/fits/). Please note that my input spectra is normalized and radial velocity (RV) corrected. For normalization and RV correction you can used iSpec or iraf.

# %%
df = pd.read_csv('/home/anjalyrose/iSpec/sample_580-590.txt', sep=r'\s+')  #ENTER YOUR INPUT SPECTRA
df = df[df.flux != 0]                                                   #FOR SOME SPECTROGRAPH PARTS OF SPECTRA ARE MISSING AND THE CORRESPONDING FLUX VALUES ARE LABELLED AS ZEROS. WE WANT TO IGNORE SUCH POINTS

x = df['waveobs'].values
y = df['flux'].values
yerr = df['err'].values
df = np.array(df,dtype=[('waveobs', '<f8'), ('flux', '<f8'), ('err', '<f8')])

# %% [markdown]
# You can perform the analysis on the entire spectrum or choose specific regions/segments for which you want to perform the analysis for.

# %%
#--- Read lines with atomic data ------------------------------------------------

# line_regions = ispec.read_line_regions(ispec_dir + "/input/regions/47000_GES/grid_synth_good_for_params_all.txt") #CHANGE THIS ACCORDINGLY FOR THE INPUT GRID          
# line_regions = ispec.adjust_linemasks(df, line_regions, max_margin=0.5)
# segments = ispec.create_segments_around_lines(line_regions, margin=0.5)   


#  ### Add also regions from the wings of strong lines:
# ## H beta
# hbeta_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/wings_Hbeta_segments.txt")
# #segments = hbeta_segments
# segments = np.hstack((segments, hbeta_segments))
# ## H ALPHA
# halpha_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/wings_Halpha_segments.txt")
# segments = np.hstack((segments, halpha_segments))
# ## MG TRIPLET
# mgtriplet_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/wings_MgTriplet_segments.txt")
# segments = np.hstack((segments, mgtriplet_segments))
##IRON
# fe_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/fe_lines_segments.txt")
# segments = np.hstack((segments, fe_segments))
##CALCIUM TRIPLET
# catriplet_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/Calcium_Triplet_segments.txt")
# segments = np.hstack((segments, catriplet_segments))
##Na doublet
# NaDoublet_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/Calcium_Triplet_segments.txt")
# segments = np.hstack((segments, NaDoublet_segments_segments))

# %%
# for j in range(len(segments)):
#     segments[j][0] = segments[j][0]+0.05
#     segments[j][1] = segments[j][1]-0.05
#YOU CAN CHANGE THE STARTING AND ENDING POINTS OF THE SEGEMENT

# %% [markdown]
# I will create a mask all false values with the same dimension as my original spectra in 1D. I will keep only those values of wavelength and flux for which the value falls in the segments (i.e, Mask is True).

# %%
# mask =np.zeros(x.shape,dtype =bool)
# for i in range(len(segments)):
#     mask|= (x>segments[i][0])&(x<segments[i][1])

# %%
# x = x[mask]                         #SELECTING THOSE VALUES ONLY FOR WHICH MASK VALUE IS TRUE
# y = y[mask]
# #yerr = yerr[mask]
yerr = y*0.0015                     #IF ERROR IS NOT SPECIFIED YOU CAN CHOOSE ACCORDINGLY

# %% [markdown]
# Now let us interpolate the spectrum using iSpec. Here for simplicity I have considered only Teff, log g and [M/H] as free parameters. Vmic and Vmac are obtained from emperical relations by Jofre et al.2013 and Maria Bergemann

# %%
def synthesize_spectrum(theta):
    teff ,logg ,MH = theta
#    alpha = ispec.determine_abundance_enchancements(MH)
    alpha =0.0
    microturbulence_vel = ispec.estimate_vmic(teff, logg, MH) 
    macroturbulence = ispec.estimate_vmac(teff, logg, MH) 
    limb_darkening_coeff = 0.6
    resolution = 47000
    vsini = 1.6                                                                                                                             #CHANGE HERE
    code = "grid"
    precomputed_grid_dir = ispec_dir + "/input/grid/SPECTRUM_MARCS.GES_GESv6_atom_hfs_iso.480_680nm"
    
    

#    precomputed_grid_dir = ispec_dir + "/input/grid/SPECTRUM_MARCS.GES_GESv6_atom_hfs_iso.480_680nm_light/"
#    The light grid comes bundled with iSpec. It is just for testing purpose. Donot use it for Scientific purpose.
    grid = ispec.load_spectral_grid(precomputed_grid_dir)

    atomic_linelist = None
    isotopes = None
    modeled_layers_pack = None
    solar_abundances = None
    fixed_abundances = None
    abundances = None
    atmosphere_layers = None
    regions = None
        
    if not ispec.valid_interpolated_spectrum_target(grid, {'teff':teff, 'logg':logg, 'MH':MH, 'alpha':alpha, 'vmic': microturbulence_vel}):
        msg = "The specified effective temperature, gravity (log g) and metallicity [M/H] \
                fall out of the spectral grid limits."
        print(msg)

    # Interpolation
    synth_spectrum = ispec.create_spectrum_structure(x)
    synth_spectrum['flux'] = ispec.generate_spectrum(synth_spectrum['waveobs'], \
            atmosphere_layers, teff, logg, MH, alpha, atomic_linelist, isotopes, abundances, \
            fixed_abundances, microturbulence_vel = microturbulence_vel, \
            macroturbulence=macroturbulence, vsini=vsini, limb_darkening_coeff=limb_darkening_coeff, \
            R=resolution, regions=regions, verbose=1,
            code=code, grid=grid)
    return synth_spectrum

# %% [markdown]
# You can also synthesize the spectrum directly from various atmospheric models. A skeleton of the code taken from iSpec is shown below. For more details check example.py in iSpec.

# %%
# def synthesize_spectrum(theta,code="spectrum"):
#     teff ,logg ,MH = theta
#     resolution = 47000
#     alpha = ispec.determine_abundance_enchancements(MH)
#     microturbulence_vel = ispec.estimate_vmic(teff, logg, MH)
#     macroturbulence = ispec.estimate_vmac(teff, logg, MH)

#     limb_darkening_coeff = 0.6
#     regions = None

#     # Selected model amtosphere, linelist and solar abundances
    
#     #model = ispec_dir + "/input/atmospheres/MARCS/"
#     #model = ispec_dir + "/input/atmospheres/MARCS.GES/"
#     #model = ispec_dir + "/input/atmospheres/MARCS.APOGEE/"
#     #model = ispec_dir + "/input/atmospheres/ATLAS9.APOGEE/"
#     model = ispec_dir + "/input/atmospheres/ATLAS9.Castelli/"
#     #model = ispec_dir + "/input/atmospheres/ATLAS9.Kurucz/"
#     #model = ispec_dir + "/input/atmospheres/ATLAS9.Kirby/" 

#     #atomic_linelist_file = ispec_dir + "/input/linelists/transitions/VALD.300_1100nm/atomic_lines.tsv"
#     #atomic_linelist_file = ispec_dir + "/input/linelists/transitions/VALD.1100_2400nm/atomic_lines.tsv"
#     atomic_linelist_file = ispec_dir + "/input/linelists/transitions/GESv6_atom_hfs_iso.420_920nm/atomic_lines.tsv"
#     #atomic_linelist_file = ispec_dir + "/input/linelists/transitions/GESv6_atom_nohfs_noiso.420_920nm/atomic_lines.tsv"
    
#     isotope_file = ispec_dir + "/input/isotopes/SPECTRUM.lst"
    

#     atomic_linelist = ispec.read_atomic_linelist(atomic_linelist_file, wave_base=wave_base, wave_top=wave_top)
#     atomic_linelist = atomic_linelist[atomic_linelist['theoretical_depth'] >= 0.01]

#     isotopes = ispec.read_isotope_data(isotope_file)

#     if "ATLAS" in model:
#         solar_abundances_file = ispec_dir + "/input/abundances/Grevesse.1998/stdatom.dat"
#     else:
#         # MARCS
#         solar_abundances_file = ispec_dir + "/input/abundances/Grevesse.2007/stdatom.dat"
#     #solar_abundances_file = ispec_dir + "/input/abundances/Asplund.2005/stdatom.dat"
#     #solar_abundances_file = ispec_dir + "/input/abundances/Asplund.2009/stdatom.dat"
#     #solar_abundances_file = ispec_dir + "/input/abundances/Anders.1989/stdatom.dat"

#     modeled_layers_pack = ispec.load_modeled_layers_pack(model)
#     solar_abundances = ispec.read_solar_abundances(solar_abundances_file)
    
#     ## Custom fixed abundances
#     #fixed_abundances = ispec.create_free_abundances_structure(["C", "N", "O"], chemical_elements, solar_abundances)
#     #fixed_abundances['Abund'] = [-3.49, -3.71, -3.54] # Abundances in SPECTRUM scale (i.e., x - 12.0 - 0.036) and in the same order ["C", "N", "O"]
#     ## No fixed abundances
#     fixed_abundances = None

#     atmosphere_layers = ispec.interpolate_atmosphere_layers(modeled_layers_pack, {'teff':teff, 'logg':logg, 'MH':MH, 'alpha':alpha}, code=code)
#     synth_spectrum = ispec.create_spectrum_structure(x)
#     synth_spectrum['flux'] = ispec.generate_spectrum(synth_spectrum['waveobs'],
#             atmosphere_layers, teff, logg, MH, alpha, atomic_linelist, isotopes, solar_abundances,
#             fixed_abundances, microturbulence_vel = microturbulence_vel,
#             macroturbulence=macroturbulence, vsini=vsini, limb_darkening_coeff=limb_darkening_coeff,
#             R=resolution, regions=regions, verbose=0,
#             code=code)

#     return synth_spectrum

# %% [markdown]
# So far we have discussed about reading the input original spectra and interpolating the synthetic spectra from iSpec. Now the important part that comes into picture is to compare the original spectra and the interpolated spectra. For this we will use Montecarlo Markhov chain method to compare both the spectrums. For this we have used the emcee package by
# Dan Foreman-Mackey.

# %%
walkers = eval(input("Enter Walkers: "))    #WALKER IMPLIES THE INDEPENDENT RANDOMLY SELECTED PARAMETER SETS. NOTE IT SHOULD HAVE ATLEAST TWICE THE VALUE OF AVAILABLE FREE PARAMETERS
Iter = eval(input("Enter Iterations: "))    #ITERATION IMPLIES NUMBER OF RUNS THE PARAMETERS WILL BE CHECKED FOR CONVERGENCE. FOR MOST CASES 250-300 SHOULD DO.
# Out:
# Enter Walkers:  20
# Enter Iterations:  125

# %% [markdown]
# We will be creating four functions for this MCMC run. The first is straightforward, and is known as the model. The model function should take as an argument a list representing our θ vector, and return the model evaluated at that θ. For completion, your model function should also have your parameter array as an input. The form of this function comes from the Gaussian probability distribution P(x)dx.

# %%
def log_likelihood(theta):
    model = synthesize_spectrum(theta)    #GENARATING THE SPECTRUM FOR A GIVEN VALUE OF THETA
    sigma2 = yerr ** 2                    # FINDING THE Variance
    return -0.5 * np.sum((y - (model['flux'])) ** 2/ sigma2)     # returns the -chi^2/2 value

# %% [markdown]
# There is no unique way to set up your prior function. For the simplistic case we have choosen the log prior function returns zero if the input values genarated randomly lies wittin the specified ranges and -infinity if it doesnt(atleast one vale should satisty this criterion). You can choose your own prior function as well.

# %%
def log_prior(theta):
    teff, logg, MH = theta
    if 3200 < teff < 6900 and 1.1 < logg < 4.8 and -2.49 < MH <= 0.49 :                                                       #CHANGE HERE
        return 0.0
    return -np.inf

# %% [markdown]
# The last function we need to define is lnprob(). This function combines the steps above by running the lnprior function, and if the function returned -np.inf, passing that through as a return, and if not (if all priors are good), returning the lnlike for that model (by convention we say it’s the lnprior output + lnlike output, since lnprior’s output should be zero if the priors are good). lnprob needs to take as arguments theta,x,y,and yerr, since these get passed through to lnlike.

# %%
def log_probability(theta):
    lp = log_prior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood(theta)

# %% [markdown]
# Select input guess values and create intial set of stellar parameters RANDOMLY

# %%
initial = np.array([4800,3.8,-0.5])         #INPUT GUESS VALUES                                                         
pos = initial + np.array([100,0.1,0.1])*np.random.randn(walkers, 3)      # YOU CAN CHOOSE UNIFORM RANDOM FUNCTION OR GAUSSIAUN RANDOM NUMBER GENARATOR
nwalkers, ndim = pos.shape

# %% [markdown]
# Now we will run the EMCEE sampler to run the code. This will take some time depending on the your system. But don't worry :)

# %%
sampler = emcee.EnsembleSampler(nwalkers, ndim, log_probability)
sampler.run_mcmc(pos,Iter, progress=True)
# Out:
# [2025-11-13 08:34:37,262] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:34:52,147] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:35:05,108] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:35:17,223] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:35:29,453] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:35:42,984] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:35:54,955] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:36:10,392] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:36:22,347] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:36:34,309] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:36:46,256] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:36:58,185] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:37:10,166] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:37:22,113] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:37:34,004] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:37:46,209] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:37:58,337] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:38:10,519] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:38:22,543] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:38:34,593] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   0%|                                                   | 0/125 [00:00<?, ?it/s][2025-11-13 08:38:46,806] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:38:59,088] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:39:11,315] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:39:23,367] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:39:35,510] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:39:47,724] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:39:59,919] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:40:12,246] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:40:24,297] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:40:36,386] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:40:48,540] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:41:00,656] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:41:12,698] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:41:28,795] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:41:41,921] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:41:54,339] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:42:08,663] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:42:22,742] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:42:34,815] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:42:46,947] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   1%|▎                                       | 1/125 [04:12<8:41:31, 252.35s/it][2025-11-13 08:43:01,101] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:43:13,107] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:43:25,031] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:43:36,982] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:43:49,158] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:44:01,210] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:44:13,237] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:44:25,223] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:44:38,500] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:44:50,381] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:45:05,744] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:45:18,184] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:45:33,008] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:45:44,962] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:45:57,027] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:46:09,137] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:46:22,098] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:46:38,295] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:46:50,147] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:47:02,313] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   2%|▋                                       | 2/125 [08:27<8:40:56, 254.12s/it][2025-11-13 08:47:14,139] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:47:26,061] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:47:41,505] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:47:53,347] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:48:05,305] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:48:17,231] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:48:29,142] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:48:41,035] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:48:53,114] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:49:04,994] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:49:16,924] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:49:28,831] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:49:40,667] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:49:52,449] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:50:04,356] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:50:17,049] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:50:28,895] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:50:40,992] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:50:52,796] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:51:04,625] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   2%|▉                                       | 3/125 [12:30<8:25:44, 248.73s/it][2025-11-13 08:51:16,477] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:52:43,826] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:52:56,685] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:53:08,953] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:53:26,205] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:53:38,384] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:53:50,399] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:54:02,372] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:54:14,391] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:54:29,446] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:54:41,392] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:54:57,665] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:55:10,019] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:55:22,483] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:55:37,192] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:55:50,867] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:56:02,909] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:56:14,923] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:56:27,031] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:56:40,737] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   3%|█▎                                      | 4/125 [18:06<9:31:10, 283.23s/it][2025-11-13 08:56:52,784] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:57:04,837] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:57:16,924] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:57:29,026] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:57:41,080] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:57:53,181] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:58:05,244] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:58:17,479] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:58:29,577] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:58:41,599] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:58:53,573] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:59:05,537] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:59:17,551] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:59:31,272] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:59:46,330] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 08:59:58,376] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:00:10,542] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:00:22,615] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:00:34,630] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:00:46,653] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   4%|█▌                                      | 5/125 [22:12<8:59:32, 269.77s/it][2025-11-13 09:00:58,613] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:01:10,650] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:01:22,699] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:01:34,826] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:01:46,828] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:01:58,742] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:02:10,796] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:02:22,765] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:02:34,692] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:02:46,736] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:02:58,816] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:03:10,737] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:03:22,572] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:03:34,540] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:03:46,472] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:03:58,446] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:04:10,426] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:04:22,413] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:04:34,121] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:04:45,916] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   5%|█▉                                      | 6/125 [26:11<8:34:28, 259.40s/it][2025-11-13 09:04:57,752] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:05:10,645] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:05:22,646] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:05:34,484] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:05:50,293] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:06:02,436] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:06:14,336] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:06:29,201] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:06:41,960] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:06:53,986] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:07:06,077] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:07:18,111] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:07:30,063] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:07:44,888] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:07:57,663] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:08:09,670] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:08:21,639] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:08:34,856] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:08:46,856] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:08:58,843] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   6%|██▏                                     | 7/125 [30:24<8:25:59, 257.28s/it][2025-11-13 09:09:10,774] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:09:22,712] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:09:34,653] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:09:46,796] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:09:58,925] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:10:10,941] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:10:22,883] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:10:34,962] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:10:47,221] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:10:59,289] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:11:11,484] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:11:23,562] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:11:35,653] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:11:47,719] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:11:59,772] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:12:11,809] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:12:23,893] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:12:36,045] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:12:48,100] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:12:59,945] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   6%|██▌                                     | 8/125 [34:25<8:11:39, 252.13s/it][2025-11-13 09:13:11,767] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:13:23,628] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:13:35,521] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:13:49,967] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:14:01,843] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:14:13,703] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:14:30,004] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:14:45,035] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:15:00,023] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:15:11,985] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:15:24,002] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:15:35,977] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:15:47,862] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:15:59,898] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:16:11,968] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:16:29,525] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:16:42,331] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:16:55,640] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:17:11,202] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:17:25,300] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   7%|██▉                                     | 9/125 [38:50<8:15:26, 256.26s/it][2025-11-13 09:17:38,278] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:17:50,246] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:18:02,321] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:18:14,467] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:18:29,620] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:18:41,876] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:18:53,925] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:19:05,795] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:19:17,847] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:19:31,654] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:19:44,720] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:19:59,750] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:28:19,311] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:28:31,514] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:28:43,913] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:28:56,052] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:29:07,942] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:29:19,751] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:29:31,692] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:29:44,537] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   8%|███                                   | 10/125 [51:09<12:56:57, 405.37s/it][2025-11-13 09:29:56,721] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:30:08,797] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:30:20,831] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:30:32,733] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:30:45,200] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:30:57,061] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:31:09,197] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:31:21,099] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:31:32,864] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:31:44,655] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:31:56,430] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:32:08,248] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:32:19,970] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:32:31,759] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:32:43,538] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:32:55,267] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:33:07,187] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:33:18,969] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:33:30,783] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:33:42,593] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   9%|███▎                                  | 11/125 [55:07<11:12:54, 354.16s/it][2025-11-13 09:33:54,550] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:34:06,379] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:34:18,256] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:34:30,040] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:34:41,841] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:34:53,627] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:35:07,108] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:35:22,614] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:35:34,521] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:35:46,595] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:35:59,077] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:36:10,909] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:36:23,971] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:36:35,826] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:36:47,725] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:36:59,623] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:37:11,583] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:37:23,426] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:37:35,349] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:37:48,562] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  10%|███▋                                  | 12/125 [59:13<10:05:01, 321.25s/it][2025-11-13 09:38:00,656] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:38:12,701] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:38:24,474] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:38:37,869] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:38:49,822] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:39:01,773] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:39:14,795] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:39:27,658] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:39:39,556] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:39:51,505] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:40:03,376] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:40:15,305] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:40:27,187] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:40:39,120] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:40:51,010] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:41:03,068] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:41:14,982] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:41:26,965] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:41:39,010] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:41:50,945] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  10%|███▊                                 | 13/125 [1:03:16<9:15:04, 297.36s/it][2025-11-13 09:42:03,702] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:42:15,722] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:42:27,736] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:42:39,774] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:42:51,791] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:43:03,789] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:43:15,841] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:43:29,163] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:43:41,778] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:44:01,026] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:44:18,898] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:44:32,263] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:44:44,209] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:44:56,148] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:45:08,074] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:45:21,857] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:45:34,016] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:45:46,175] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:45:58,601] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:46:13,515] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  11%|████▏                                | 14/125 [1:07:38<8:50:40, 286.85s/it][2025-11-13 09:46:25,553] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:46:37,932] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:46:51,002] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:47:07,296] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:47:21,497] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:47:34,476] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:47:47,367] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:48:00,549] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:48:13,960] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:48:26,766] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:48:39,466] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:48:56,656] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:49:08,692] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:49:20,693] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:49:32,639] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:49:44,541] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:49:56,316] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:50:08,141] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:50:20,031] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:50:32,205] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  12%|████▍                                | 15/125 [1:11:57<8:30:19, 278.36s/it][2025-11-13 09:50:44,623] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:50:56,676] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:51:08,707] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:51:22,795] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:51:34,809] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:51:46,774] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:52:01,237] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:52:13,181] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:52:25,138] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:52:37,065] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:52:49,219] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:53:01,274] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:53:15,045] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:53:27,706] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:53:42,851] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:53:55,559] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:54:08,544] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:54:20,867] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:54:33,478] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:54:46,512] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  13%|████▋                                | 16/125 [1:16:11<8:12:32, 271.12s/it][2025-11-13 09:54:59,126] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:55:11,735] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:55:29,422] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:55:44,919] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:55:56,946] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:56:09,008] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:56:20,890] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:56:32,912] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:56:44,897] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:56:56,808] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:57:08,765] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:57:20,655] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:57:33,865] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:57:46,868] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:57:58,752] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:58:11,011] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:58:22,889] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:58:35,011] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:58:46,794] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:58:58,912] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  14%|█████                                | 17/125 [1:20:24<7:57:53, 265.49s/it][2025-11-13 09:59:10,836] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:59:22,854] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:59:34,857] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 09:59:46,925] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:00:02,360] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:00:14,187] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:00:26,400] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:00:38,417] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:00:50,418] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:01:02,468] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:01:14,493] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:01:26,644] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:01:38,863] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:01:51,233] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:02:03,085] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:02:14,906] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:02:28,750] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:02:40,758] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:02:52,941] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:03:09,846] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  14%|█████▎                               | 18/125 [1:24:35<7:45:39, 261.12s/it][2025-11-13 10:03:21,918] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:03:33,839] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:03:45,851] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:03:57,861] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:04:09,886] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:04:22,219] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:04:34,220] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:04:46,203] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:04:58,114] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:05:10,009] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:05:21,900] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:05:33,996] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:05:45,896] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:05:57,934] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:06:11,571] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:06:24,474] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:06:36,429] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:06:48,314] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:07:00,153] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:07:12,050] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  15%|█████▌                               | 19/125 [1:28:37<7:31:16, 255.44s/it][2025-11-13 10:07:23,861] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:07:35,949] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:07:47,918] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:07:59,925] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:08:11,935] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:08:23,723] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:08:38,089] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:08:50,498] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:09:02,663] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:09:14,812] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:09:26,965] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:09:39,285] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:09:51,431] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:10:07,875] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:10:21,370] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:10:33,569] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:10:45,728] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:10:57,900] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:11:10,513] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:11:23,938] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  16%|█████▉                               | 20/125 [1:32:49<7:25:09, 254.37s/it][2025-11-13 10:11:40,052] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:11:52,213] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:12:04,086] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:12:16,006] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:12:27,883] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:12:39,810] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:12:56,072] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:13:08,072] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:13:20,043] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:13:36,284] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:13:48,298] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:14:00,494] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:14:14,595] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:14:26,604] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:14:39,947] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:14:53,083] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:15:05,167] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:15:17,183] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:15:29,007] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:15:46,362] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  17%|██████▏                              | 21/125 [1:37:11<7:25:06, 256.79s/it][2025-11-13 10:16:05,260] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:16:24,370] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:16:43,528] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:17:02,415] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:17:21,287] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:17:40,532] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:17:59,438] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:18:18,278] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:18:37,134] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:18:56,233] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:19:15,188] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:19:34,331] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:19:53,260] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:20:12,244] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:20:31,135] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:20:50,287] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:21:09,310] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:21:28,193] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:21:47,428] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:22:06,329] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  18%|██████▌                              | 22/125 [1:43:31<8:24:16, 293.76s/it][2025-11-13 10:22:25,241] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:22:44,186] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:23:03,102] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:23:21,981] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:23:40,887] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:23:59,853] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:24:18,780] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:24:37,913] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:24:56,806] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:25:15,728] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:25:34,561] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:25:53,499] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:26:13,517] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:26:32,552] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:26:51,587] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:27:02,784] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:27:09,735] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:27:16,923] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:27:24,671] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:27:33,523] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  18%|██████▊                              | 23/125 [1:48:58<8:36:26, 303.79s/it][2025-11-13 10:27:44,245] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:27:54,497] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:28:04,869] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:28:15,189] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:28:26,437] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:28:36,772] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:28:47,040] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:28:57,424] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:29:07,787] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:29:18,286] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:29:28,650] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:29:39,946] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:29:50,301] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:30:00,645] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:30:12,021] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:30:22,534] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:30:33,042] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:30:45,160] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:30:55,513] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:31:06,911] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  19%|███████                              | 24/125 [1:52:32<7:45:43, 276.66s/it][2025-11-13 10:31:17,323] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:31:27,686] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:31:41,606] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:31:51,902] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:32:02,256] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:32:12,676] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:32:23,126] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:32:33,403] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:32:43,729] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:32:54,121] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:33:04,701] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:33:15,303] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:33:28,599] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:33:39,612] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:33:49,948] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:34:00,237] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:34:10,539] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:34:21,013] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:34:31,287] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 10:34:41,579] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  20%|███████▍                             | 25/125 [1:56:06<7:10:06, 258.06s/it][2025-11-13 10:34:51,863] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# ...
# [2025-11-13 16:39:13,817] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:39:24,246] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:39:34,668] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:39:45,199] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:39:55,662] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:40:05,983] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  98%|█████████████████████████████████████ | 122/125 [8:01:31<10:39, 213.30s/it][2025-11-13 16:40:16,319] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:40:26,589] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:40:37,064] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:40:47,634] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:40:57,992] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:41:08,427] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:41:18,844] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:41:29,249] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:41:39,645] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:41:50,241] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:42:00,579] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:42:10,906] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:42:21,388] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:42:31,688] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:42:42,020] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:42:55,855] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:43:09,894] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:43:20,211] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:43:30,722] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:43:41,106] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  98%|█████████████████████████████████████▍| 123/125 [8:05:06<07:07, 213.85s/it][2025-11-13 16:43:52,218] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:44:02,612] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:44:15,648] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:44:25,982] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:44:36,520] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:44:47,131] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:44:57,657] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:45:08,063] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:45:18,406] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:45:29,625] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:45:40,646] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:45:50,899] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:46:01,178] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:46:11,632] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:46:25,510] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:46:37,207] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:46:50,439] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:47:04,269] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:47:14,656] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:47:25,214] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  99%|█████████████████████████████████████▋| 124/125 [8:08:50<03:36, 216.93s/it][2025-11-13 16:47:35,595] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:47:45,994] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:47:56,404] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:48:06,871] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:48:17,394] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:48:27,810] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:48:38,350] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:48:51,363] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:49:01,640] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:49:12,506] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:49:23,023] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:49:33,655] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:49:43,997] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:49:54,336] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:50:07,007] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:50:17,892] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:50:29,850] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:50:40,272] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:50:50,657] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-11-13 16:51:01,267] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# 100%|██████████████████████████████████████| 125/125 [8:12:26<00:00, 236.37s/it]
# State([[ 4.89546044e+03  3.65032195e+00 -5.46291250e-01]
#  [ 4.89572058e+03  3.65142864e+00 -5.46307333e-01]
#  [ 4.80555911e+03  3.49765568e+00 -6.37290590e-01]
#  [ 4.80749930e+03  3.49881399e+00 -6.33015579e-01]
#  [ 4.89694244e+03  3.65267803e+00 -5.45562477e-01]
#  [ 4.89586193e+03  3.65014153e+00 -5.46080114e-01]
#  [ 4.89630759e+03  3.65254134e+00 -5.46676658e-01]
#  [ 4.89603316e+03  3.65011635e+00 -5.45523611e-01]
#  [ 4.80502218e+03  3.49640603e+00 -6.37848520e-01]
#  [ 4.89545853e+03  3.65268787e+00 -5.47720636e-01]
#  [ 4.80607351e+03  3.49899891e+00 -6.36683533e-01]
#  [ 4.80846421e+03  3.49967203e+00 -6.31843704e-01]
#  [ 4.90130863e+03  3.65815842e+00 -5.40142297e-01]
#  [ 4.89646765e+03  3.65172066e+00 -5.45189621e-01]
#  [ 4.80876860e+03  3.49934899e+00 -6.31607315e-01]
#  [ 4.89559016e+03  3.64983992e+00 -5.46191009e-01]
#  [ 4.90174772e+03  3.65717557e+00 -5.40199041e-01]
#  [ 4.88721945e+03  3.64639703e+00 -5.56842903e-01]
#  [ 4.89548979e+03  3.64977364e+00 -5.46419578e-01]
#  [ 4.80462518e+03  3.49782337e+00 -6.37712837e-01]], log_prob=[-847378.08178982 -847379.50118965 -848456.83567921 -848428.02073032
#  -847384.67573728 -847376.94772458 -847384.56854594 -847377.3027327
#  -848605.77396325 -847387.91511348 -848421.09548899 -848416.40139883
#  -847347.51793469 -847381.29669899 -848424.63067553 -847377.06875157
#  -847342.99052795 -847803.57828691 -847377.33551951 -848460.58060431], blobs=None, random_state=('MT19937', array([3827124741,   48103044, 1011456344, 3644004578, 3198285486,
#        4292514427,  827561350,  526104747, 2691167327, 2408089644,
#        2570451835, 2656623055,  155385691,  784268793, 1233024062,
#        2985261206, 2636088227, 2862839643, 3348792789, 3450622356,
#        3748489304,  750708419,   67584563, 2395565012, 1066767552,
#        3967755885,  858682455,  597598215, 2986933097, 1577414094,
#        2617644396, 1354842705,  762074392, 2764531488, 3881549062,
#        3243874514, 2521677655, 1647437258, 2517716978,  539572044,
#         497153577, 1434235438, 1212298031, 2012302729, 2286889370,
#        3978964629,  340717587, 1600159432, 3272544820,  170251422,
#        3683211126, 3388769529,  457374886, 1084785474, 2811256011,
#        3271448436, 1840396995, 1264545093,  333483341, 3827192820,
#        2211596574,   29211631, 1967241700, 3218832318, 2458715126,
#        2039283510, 1415006643, 1089155208, 3489457564, 1138979997,
#         364899592,  620540779, 2995979728,  144191106, 4273351404,
#        2891717234,  148324798, 2696050597, 4031775656,  523799918,
#         917143149,   53826359,  407815111, 3830887929, 3724865629,
#        2920039348,  971516843, 2861563254,  884155813, 2163381003,
#         193646979, 3381487849, 2391354136,  216405968, 3982921185,
#        1537237111, 2894365987, 1192585505, 4192764097, 4256307208,
#        2125832418,  556220134, 1660562779, 1275810024, 1116491765,
#         153534609, 3469680082,  921365370, 1002001435, 2243855291,
#        4218951998, 2297558018, 3949540713, 3321212094, 2493989478,
#        2059022135, 2810300541,  436986954, 1982959212, 1033731430,
#        3698056322, 2436424804, 3439869232, 3909395169,  610884136,
#        1123641960, 1675102013, 3605370357, 3137120687, 2307060120,
#         520621130, 2247003310, 2417142873,  328077048, 3381049047,
#        1814338077, 2419072232, 4061656130, 2704410858, 1425205873,
#        3481491991, 3963448731, 4043652970, 3337366082,  996771199,
#        2455832500,  389246377, 1792595267, 3773855338,  430199433,
#        3918040426, 3008165865, 1286699405,  797728175,  862147687,
#        3783923911, 3112392336,  931350267, 2272372034, 3045849311,
#        2658753749, 2424205542, 2116044750,  417839127, 3250738645,
#        2254718109, 3885738505, 2137606062, 3431439841,  627252031,
#        1850774525, 3000662490, 2359025764, 3241005983, 1698663094,
#        2627528502, 3843114953, 4024164122, 2451940940, 2074834645,
#        1519751506, 1048381033,  822770080, 2702735701, 4237162002,
#        3955093330, 1822775606, 3925158087, 3247164981, 2492030133,
#        2663526076,  803307615, 3983585944,  576651676, 2599546686,
#        1085310596, 2007404587, 3124351575,  158198693,  288312267,
#        3581814398, 3440132923, 3157280908, 2618332542, 1355194561,
#        2331331015,  279962301, 1857667133, 2832647824, 1027343192,
#        1252566035, 2036640784,  173784760, 1881657833, 3507445494,
#        2068553461, 3459585888, 1009920177, 4160409432, 3037612578,
#        3583006430, 2013927171, 3513761487, 3455617855, 1726611615,
#         479247319, 1240135365, 3717908353, 2976073945,  891983058,
#        1005986929, 2559065811, 1725131517, 1837120447, 2114075017,
#         786001247,  249997525, 1771541223,  349503806, 2713674994,
#        2994499521, 3808156539,  398817207, 2787200017, 1627372434,
#         355426808, 1837496282,  607935520, 3167119048,  937221908,
#        3426299534, 3289726907, 1679725958,   77015669,  393171037,
#        2437453557, 1688485831, 1812566293, 4248958780, 2100907582,
#        3661994961, 1318208495,  239114432, 4291268664, 4098306325,
#        1176771026, 2070380886, 3147252056, 1728659710,  851876540,
#        4007619043, 1157196835, 2731192348, 4086373710, 2359678554,
#        1203993159, 1341222717,  933932564, 1461218486, 3553885645,
#        4007005206, 2636528394, 3989967126,  570000877, 1221809522,
#        2008791253, 1245118990, 3822417105, 3966662417, 2604195072,
#        1840620531, 1675811754,   32630652, 1497132376, 3519123184,
#        2119428504, 1826745028, 2689637351, 4253001528, 1210575133,
#        3746950902, 1585523144, 3514531963,  366078041, 3124956879,
#         338152477, 3641639516,  978903597,  408092486, 1953413896,
#        2902896950, 2638518763, 1027451891,   35959648,  987234565,
#         577584824, 3293231044, 2844144139,  632088876,    4381465,
#        3775044516,  410498688, 3170664979, 2592166361,  361459959,
#         555920286,  294325182,  493225717, 3033668581, 3697241177,
#        3276023109,  981567180, 3382253423, 1722764003, 4198248858,
#        2173784733, 4207209350,  162858501, 2092505884,  852509309,
#        3941448699, 1700135518, 1880443271, 1412088217, 3306721328,
#        1313676014,  144175323, 1397653106,  715290073, 2217365578,
#        2918412576, 2384696605, 4279870629, 1536319257, 4056288743,
#         730113959, 2090977418, 2625713641, 4042917331, 1811718072,
#         540736192, 2107322302, 2880336114, 1387676986, 3490243990,
#        3849719644, 3934895843, 1412962423,  322647865, 3320304111,
#        3121645356, 1783093049, 2492034386, 2522351903, 2514615599,
#         340479012, 1237912614, 2031378324, 3871465249, 2758111159,
#        2928467585, 1533004409,  800645517,  515018262, 4195505768,
#        2032550786, 1892813224, 1345391726, 2858450629, 4169319663,
#        2431812449, 1617105539,  711576321, 2177125322,  856143171,
#        3294384224,  108368921, 1240381279, 3130902273, 1002546919,
#        1182806190, 2671661008,   14009278,  830794711, 4195056209,
#        2630883414, 2199357402, 1197408000, 4081548916, 1194324569,
#        3003254521, 3862692072, 3346534781, 3465909067, 2687362782,
#        2229335157,  755025916,  451589727, 3512582751, 1127352417,
#        2977705356, 3037704758, 1003118902, 3019592817, 3489063797,
#        4242902753, 2032082703, 4060747144, 1023246978, 3696553033,
#        2349256052,  464213909, 2572661404, 3846843793, 4071402544,
#        3402634252, 2099972919,  196353189, 1461233920,  837423214,
#        1294446311, 1463789058, 1181176692, 1982350217, 1391955171,
#         230859031, 1613133615, 3927004651, 3091150731, 3094803978,
#        1546461455, 4210945374, 1670883162, 2132456546,  531794551,
#        3683965686, 1445639227,  996052921,  225357927,   17672139,
#        1521024549, 3644243690, 3534942288, 2248607923, 1357282078,
#        2693172396, 1278118586, 1248744079, 4221490720, 1557234479,
#        2975843406,  939698929,  193625313, 1981925770, 1790964841,
#        2996572265, 2263026956,  446551963, 2600372278, 1590583796,
#        4190254674, 1644430544,  627809775, 1524520402,  380590682,
#        2216042830, 1749223819, 2932393076, 3309603778, 2689058729,
#         984284911, 2277520756, 2124156112,  621331574, 3592748621,
#        3214588236, 1596856857, 1029320339, 1108229450, 1539934227,
#         233190739, 1551266612, 3229114722, 2688603063, 1041255515,
#        1553773052, 1236141483, 1460629889, 1422325359,  525197753,
#        3197367955, 2398428528,  784722985, 3048673995, 1438531997,
#        2142863711,  303208537, 1520197888, 2545677599,  499404110,
#        1134265875, 4021338753,  239749358, 3605337791, 3612378847,
#         178989361, 3973280230,   11669879, 1325664332, 1819301344,
#        4068975505, 3686513515, 3174381140, 2401644199, 3735569283,
#        3460958157, 4102840904, 2638641667, 2953426397, 2871385031,
#        3518792545, 2967976343, 1597398741,  987701273,   48793479,
#        4221189650, 3908516717, 2479674255,  230123718, 2390567561,
#         514576705,  653468723, 1250522468,  187670450, 2654530919,
#        2335549298, 2723404179,  391246916, 1789856970, 1617004039,
#        2933506258, 1111443613,  985090516, 3826773992, 1422494192,
#        1478922676, 2326172980, 3568499739, 2284116957, 2294251216,
#         936569938, 2182853641,  422427562, 2412743937, 1669424113,
#         197304270,  949958652,  241486319, 1653429904,  672870100,
#        2181777167, 4110480007, 2005735612, 4285743159,  888955050,
#        1632338411, 3728705326, 1051253360, 3539348678, 4266986135,
#        4005373326, 1921495460,   92985461, 1493004381, 2718034357,
#         913248314, 1420052766, 3013884849, 3474989263, 3740889123,
#        2321475636, 1171601872,     381541, 3619624949, 4274647691,
#        1214241624, 3571785890, 2999357445,  339734278,  312727971,
#         134604403,  378338261, 4019003154, 2928832572,  784064614,
#        1356646993, 2366032534,  189572250, 2471322518, 4000710157,
#        3651758631, 1026396073, 1265719300, 2910028228], dtype=uint32), 83, 0, 0.0))

# %% [markdown]
# Let us plot the Walkers and Iterations. Check out for convergence in this plot. If you see the convergence you are good to go.

# %%
fig, axes = plt.subplots(3, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
accepted = sampler.backend.accepted.astype(bool)   #Here accepted indicated that the lines for each parameter below have converged/moved at least one time.

labels = ["teff","logg","MH"]
for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)
axes[-1].set_xlabel("step number");

# %% [markdown]
# Let us check how good is the fitting.....

# %%
fig, ax = plt.subplots(1, figsize=(10, 7), sharex=True)
samples = sampler.flatchain
theta_max  = samples[np.argmax(sampler.flatlnprobability)]
best_fit_model = synthesize_spectrum(theta_max)
ax.plot(x,y,alpha=0.3)
ax.plot(x,best_fit_model['flux'],alpha =0.3)
ax.plot(x,y-best_fit_model['flux'],alpha =0.3)
plt.savefig('t2.pdf')                                                                                                #CHANGE HERE
print(('Theta max: ',theta_max))             # Genarating the spectrum for the Maximum likelyhood function.
#NOTE THE SPIKES IN THE PLOT BELOW. THESE ARE DUE TO THE FACT THAT END POINTS OF THE SPECTRUMS ARE EXTRAPOLATED
# Out:
# [2025-11-13 16:51:13,235] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# ('Theta max: ', array([ 4.90166421e+03,  3.65736250e+00, -5.40188249e-01]))

# %% [markdown]
# Since the first few runs the walkers are exploring the parameter space and convergence have not yet been achived. We will ignore such runs. This is also known as "BURN-IN".

# %%
new_samples = sampler.get_chain(discard=10, thin=1, flat=False)
flat_samples = sampler.get_chain(discard=10, thin=1, flat=True)
                     # WE ARE ONLY CHOOSING THE VALUES FOR WHICH THE WALKER HAVE MOVED ATLEAST ONCE DURING THE ENTIRE ITERATION. Stagnent walkers indicates that the prior function might have returned -inf.

# %%
print(new_samples.shape)
# Out:
# (115, 20, 3)

# %% [markdown]
# Checking the Convergence after the BURN-IN... If it seems to be converged then it is DONE.

# %%
fig, axes = plt.subplots(3, figsize=(10, 7), sharex=True)
for i in range(ndim):
    ax = axes[i]
    ax.plot(new_samples[:, :, i], "k", alpha=0.3)
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)
axes[-1].set_xlabel("step number")
plt.savefig('t3.pdf')                                                                                                  #CHANGE HERE
flat_samples = new_samples.reshape(-1,new_samples.shape[2])
np.savetxt("ispecsample_580-590.txt",flat_samples,delimiter='\t')                                                                                   #CHANGE HERE

# %% [markdown]
# # Data Visualization!

# %%
import corner
from pandas.plotting import scatter_matrix

# %%
df = pd.read_csv('/home/anjalyrose/iSpec/sample_580-590.txt', delimiter='\t')

# Verify column names and types
print(df.head())
print(df.dtypes)

# Plot histogram for numeric columns
df.hist()
# Out:
#       waveobs      flux       err
# 0  580.003072  0.987998  0.005281
# 1  580.006772  0.985656  0.005271
# 2  580.010272  0.984090  0.005265
# 3  580.013772  0.983220  0.005259
# 4  580.017172  0.982885  0.005257
# waveobs    float64
# flux       float64
# err        float64
# dtype: object
# array([[<Axes: title={'center': 'waveobs'}>,
#         <Axes: title={'center': 'flux'}>],
#        [<Axes: title={'center': 'err'}>, <Axes: >]], dtype=object)

# %%
#df = df[df.logg < 4.451 ] #REMOVE ANY OUTLIER DISTRIBUTION

# %%
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde') #PLOTTING THE SCATTER MATRIX. I HAVE USED A VERY LIGHT DATASET FOR TEST PURPOSE> YOU CAN USE A MORE WALKER X ITERATION FOR A BETTER RESULT
# Out:
# array([[<Axes: xlabel='waveobs', ylabel='waveobs'>,
#         <Axes: xlabel='flux', ylabel='waveobs'>,
#         <Axes: xlabel='err', ylabel='waveobs'>],
#        [<Axes: xlabel='waveobs', ylabel='flux'>,
#         <Axes: xlabel='flux', ylabel='flux'>,
#         <Axes: xlabel='err', ylabel='flux'>],
#        [<Axes: xlabel='waveobs', ylabel='err'>,
#         <Axes: xlabel='flux', ylabel='err'>,
#         <Axes: xlabel='err', ylabel='err'>]], dtype=object)

# %%
samples = np.vstack([df]) #IT IS NECESSARY TO STACK THE DATA VERTICALLY TO OBTAIN THE DISTRIBUTION FROM THE DATA FRAME

# %%
value2 = np.mean(samples, axis=0) 
plt.rcParams["font.size"] = "10"     #THIS CHANGES THE FONT SIZE OF THE LABELS(NOT LEGEND)

# %%
## FINALLY... MAKING THE CORNER PLOT>>>>


#fig = corner.corner(df,show_titles=True,plot_datapoints=True,quantiles=[0.16, 0.5, 0.84],color ='black',levels=(1-np.exp(-0.5),),label_kwargs=dict(fontsize=20,color = 'black'),hist_kwargs=dict(fill = True,color = 'dodgerblue'),alpha =0.2)
fig = corner.corner(df,show_titles=True,plot_datapoints=True,quantiles=[0.16, 0.5, 0.84],color ='black',label_kwargs=dict(fontsize=20,color = 'black'),hist_kwargs=dict(fill = True,color = 'dodgerblue'),alpha =0.2)
axes = np.array(fig.axes).reshape((3, 3))
for i in range(3):
    ax = axes[i, i]
    ax.axvline(value2[i], color="r",alpha =0.8)
for yi in range(3):
    for xi in range(yi):
        ax = axes[yi, xi]
        ax.axvline(value2[xi], color="r",alpha =0.8,linestyle = 'dashed')
        ax.axhline(value2[yi], color="r",alpha =0.8,linestyle = 'dashed')
        ax.plot(value2[xi], value2[yi], "r")
#         plt.tight_layout()
#THE CORNER PLOT DONOT LOOK GREAT>> THE REASON IS FEW NUMBER OF DATA POINTS AND SHARP CONVERGENCE
# Out:
# [2025-11-13 16:51:14,743] [WARNING] [core:hist2d:718]: Too few points to create valid contours
