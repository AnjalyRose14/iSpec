# %% [markdown]
# # iMCSpec (iSpec+emcee)

# %% [markdown]
# iMCSpec is a tool which combines iSpec(https://www.blancocuaresma.com/s/iSpec) and emcee(https://emcee.readthedocs.io/en/stable/) into a single unit to perform Bayesian analysis of spectroscopic data to estimate stellar parameters. For more details on the individual code please refer to the links above. This code have been tested on Syntehtic dataset as well as GAIA BENCHMARK stars (https://www.blancocuaresma.com/s/benchmarkstars). The example shown here is for the grid genarated MARCS.GES_atom_hfs. If you want to use any other grid, just download it from the https://www.cfa.harvard.edu/~sblancoc/iSpec/grid/ and make the necessary changes in the line_regions.

# %% [raw]
# Dependencies :
# iSpec : iSpec v2020.10.01
# python = 3+ Branch
# numpy>=1.18.5
# scipy>=1.5.0
# matplotlib>=3.2.2
# astropy>=4.0.1.post1
# lockfile>=0.12.2
# Cython>=0.29.21
# pandas>=1.0.5
# statsmodels>=0.11.1
# dill>=0.3.2
# emcee>=3.0.2
# corner>=2.1.1

# %% [markdown]
# Let us import all the necessary packages that are required for this analysis.

# %%
import sys
sys.path.append('/home/anjalyrose/iSpec')
import ispec
# Out:
# *********************************************************************
# Not optimized version loaded!
# *********************************************************************
# *********************************************************************
# Not optimized version loaded!
# *********************************************************************
# *********************************************************************
# Not optimized version loaded!
# *********************************************************************

# %%
import os
import sys
import numpy as np
import pandas as pd
import emcee
from multiprocessing import Pool
import matplotlib.pyplot as plt

os.environ["OMP_NUM_THREADS"] = "1"
os.environ['QT_QPA_PLATFORM']='offscreen'
os.environ["NUMEXPR_MAX_THREADS"] = "8"      #CHECK NUMBER OF CORES ON YOUR MACHINE AND CHOOSE APPROPRIATELY 

ispec_dir = '/home/anjalyrose/iSpec'            #MENTION YOUR DIRECTORY WHERE iSPEC is present     
sys.path.insert(0, os.path.abspath(ispec_dir))

import ispec
#np.seterr(all="ignore")                     #FOR MCMC THE WARNING COMES FOR RED BLUE MOVES WHEN ANY PARTICULAR WALKER VALUE DONOT LIE IN THE PARAMETER SPACE

# %% [markdown]
# Let us read the input spectra. Here I have the input spectrum in .txt format for reading the spectra. You can use the .fits format also for reading the spectra using Astropy (https://docs.astropy.org/en/stable/io/fits/). Please note that my input spectra is normalized and radial velocity (RV) corrected. For normalization and RV correction you can used iSpec or iraf.

# %%
df = pd.read_csv('/home/anjalyrose/iSpec/ispec_sample.txt', sep=r'\s+')  #ENTER YOUR INPUT SPECTRA
df = df[df.flux != 0]                                                   #FOR SOME SPECTROGRAPH PARTS OF SPECTRA ARE MISSING AND THE CORRESPONDING FLUX VALUES ARE LABELLED AS ZEROS. WE WANT TO IGNORE SUCH POINTS

x = df['waveobs'].values
y = df['flux'].values
yerr = df['err'].values
df = np.array(df,dtype=[('waveobs', '<f8'), ('flux', '<f8'), ('err', '<f8')])

# %% [markdown]
# You can perform the analysis on the entire spectrum or choose specific regions/segments for which you want to perform the analysis for.

# %%
#--- Read lines with atomic data ------------------------------------------------

# line_regions = ispec.read_line_regions(ispec_dir + "/input/regions/47000_GES/grid_synth_good_for_params_all.txt") #CHANGE THIS ACCORDINGLY FOR THE INPUT GRID          
# line_regions = ispec.adjust_linemasks(df, line_regions, max_margin=0.5)
# segments = ispec.create_segments_around_lines(line_regions, margin=0.5)   


#  ### Add also regions from the wings of strong lines:
# ## H beta
# hbeta_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/wings_Hbeta_segments.txt")
# #segments = hbeta_segments
# segments = np.hstack((segments, hbeta_segments))
# ## H ALPHA
# halpha_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/wings_Halpha_segments.txt")
# segments = np.hstack((segments, halpha_segments))
# ## MG TRIPLET
# mgtriplet_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/wings_MgTriplet_segments.txt")
# segments = np.hstack((segments, mgtriplet_segments))
##IRON
# fe_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/fe_lines_segments.txt")
# segments = np.hstack((segments, fe_segments))
##CALCIUM TRIPLET
# catriplet_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/Calcium_Triplet_segments.txt")
# segments = np.hstack((segments, catriplet_segments))
##Na doublet
# NaDoublet_segments = ispec.read_segment_regions(ispec_dir + "/input/regions/Calcium_Triplet_segments.txt")
# segments = np.hstack((segments, NaDoublet_segments_segments))

# %%
# for j in range(len(segments)):
#     segments[j][0] = segments[j][0]+0.05
#     segments[j][1] = segments[j][1]-0.05
#YOU CAN CHANGE THE STARTING AND ENDING POINTS OF THE SEGEMENT

# %% [markdown]
# I will create a mask all false values with the same dimension as my original spectra in 1D. I will keep only those values of wavelength and flux for which the value falls in the segments (i.e, Mask is True).

# %%
# mask =np.zeros(x.shape,dtype =bool)
# for i in range(len(segments)):
#     mask|= (x>segments[i][0])&(x<segments[i][1])

# %%
# x = x[mask]                         #SELECTING THOSE VALUES ONLY FOR WHICH MASK VALUE IS TRUE
# y = y[mask]
# #yerr = yerr[mask]
yerr = y*0.0015                     #IF ERROR IS NOT SPECIFIED YOU CAN CHOOSE ACCORDINGLY

# %% [markdown]
# Now let us interpolate the spectrum using iSpec. Here for simplicity I have considered only Teff, log g and [M/H] as free parameters. Vmic and Vmac are obtained from emperical relations by Jofre et al.2013 and Maria Bergemann

# %%
def synthesize_spectrum(theta):
    teff ,logg ,MH = theta
#    alpha = ispec.determine_abundance_enchancements(MH)
    alpha =0.0
    microturbulence_vel = ispec.estimate_vmic(teff, logg, MH) 
    macroturbulence = ispec.estimate_vmac(teff, logg, MH) 
    limb_darkening_coeff = 0.6
    resolution = 47000
    vsini = 1.6                                                                                                                             #CHANGE HERE
    code = "grid"
    precomputed_grid_dir = ispec_dir + "/input/grid/SPECTRUM_MARCS.GES_GESv6_atom_hfs_iso.480_680nm_light/"

#    precomputed_grid_dir = ispec_dir + "/input/grid/SPECTRUM_MARCS.GES_GESv6_atom_hfs_iso.480_680nm_light/"
#    The light grid comes bundled with iSpec. It is just for testing purpose. Donot use it for Scientific purpose.
    grid = ispec.load_spectral_grid(precomputed_grid_dir)

    atomic_linelist = None
    isotopes = None
    modeled_layers_pack = None
    solar_abundances = None
    fixed_abundances = None
    abundances = None
    atmosphere_layers = None
    regions = None
        
    if not ispec.valid_interpolated_spectrum_target(grid, {'teff':teff, 'logg':logg, 'MH':MH, 'alpha':alpha, 'vmic': microturbulence_vel}):
        msg = "The specified effective temperature, gravity (log g) and metallicity [M/H] \
                fall out of the spectral grid limits."
        print(msg)

    # Interpolation
    synth_spectrum = ispec.create_spectrum_structure(x)
    synth_spectrum['flux'] = ispec.generate_spectrum(synth_spectrum['waveobs'], \
            atmosphere_layers, teff, logg, MH, alpha, atomic_linelist, isotopes, abundances, \
            fixed_abundances, microturbulence_vel = microturbulence_vel, \
            macroturbulence=macroturbulence, vsini=vsini, limb_darkening_coeff=limb_darkening_coeff, \
            R=resolution, regions=regions, verbose=1,
            code=code, grid=grid)
    return synth_spectrum

# %% [markdown]
# You can also synthesize the spectrum directly from various atmospheric models. A skeleton of the code taken from iSpec is shown below. For more details check example.py in iSpec.

# %%
# def synthesize_spectrum(theta,code="spectrum"):
#     teff ,logg ,MH = theta
#     resolution = 47000
#     alpha = ispec.determine_abundance_enchancements(MH)
#     microturbulence_vel = ispec.estimate_vmic(teff, logg, MH)
#     macroturbulence = ispec.estimate_vmac(teff, logg, MH)

#     limb_darkening_coeff = 0.6
#     regions = None

#     # Selected model amtosphere, linelist and solar abundances
    
#     #model = ispec_dir + "/input/atmospheres/MARCS/"
#     #model = ispec_dir + "/input/atmospheres/MARCS.GES/"
#     #model = ispec_dir + "/input/atmospheres/MARCS.APOGEE/"
#     #model = ispec_dir + "/input/atmospheres/ATLAS9.APOGEE/"
#     model = ispec_dir + "/input/atmospheres/ATLAS9.Castelli/"
#     #model = ispec_dir + "/input/atmospheres/ATLAS9.Kurucz/"
#     #model = ispec_dir + "/input/atmospheres/ATLAS9.Kirby/" 

#     #atomic_linelist_file = ispec_dir + "/input/linelists/transitions/VALD.300_1100nm/atomic_lines.tsv"
#     #atomic_linelist_file = ispec_dir + "/input/linelists/transitions/VALD.1100_2400nm/atomic_lines.tsv"
#     atomic_linelist_file = ispec_dir + "/input/linelists/transitions/GESv6_atom_hfs_iso.420_920nm/atomic_lines.tsv"
#     #atomic_linelist_file = ispec_dir + "/input/linelists/transitions/GESv6_atom_nohfs_noiso.420_920nm/atomic_lines.tsv"
    
#     isotope_file = ispec_dir + "/input/isotopes/SPECTRUM.lst"
    

#     atomic_linelist = ispec.read_atomic_linelist(atomic_linelist_file, wave_base=wave_base, wave_top=wave_top)
#     atomic_linelist = atomic_linelist[atomic_linelist['theoretical_depth'] >= 0.01]

#     isotopes = ispec.read_isotope_data(isotope_file)

#     if "ATLAS" in model:
#         solar_abundances_file = ispec_dir + "/input/abundances/Grevesse.1998/stdatom.dat"
#     else:
#         # MARCS
#         solar_abundances_file = ispec_dir + "/input/abundances/Grevesse.2007/stdatom.dat"
#     #solar_abundances_file = ispec_dir + "/input/abundances/Asplund.2005/stdatom.dat"
#     #solar_abundances_file = ispec_dir + "/input/abundances/Asplund.2009/stdatom.dat"
#     #solar_abundances_file = ispec_dir + "/input/abundances/Anders.1989/stdatom.dat"

#     modeled_layers_pack = ispec.load_modeled_layers_pack(model)
#     solar_abundances = ispec.read_solar_abundances(solar_abundances_file)
    
#     ## Custom fixed abundances
#     #fixed_abundances = ispec.create_free_abundances_structure(["C", "N", "O"], chemical_elements, solar_abundances)
#     #fixed_abundances['Abund'] = [-3.49, -3.71, -3.54] # Abundances in SPECTRUM scale (i.e., x - 12.0 - 0.036) and in the same order ["C", "N", "O"]
#     ## No fixed abundances
#     fixed_abundances = None

#     atmosphere_layers = ispec.interpolate_atmosphere_layers(modeled_layers_pack, {'teff':teff, 'logg':logg, 'MH':MH, 'alpha':alpha}, code=code)
#     synth_spectrum = ispec.create_spectrum_structure(x)
#     synth_spectrum['flux'] = ispec.generate_spectrum(synth_spectrum['waveobs'],
#             atmosphere_layers, teff, logg, MH, alpha, atomic_linelist, isotopes, solar_abundances,
#             fixed_abundances, microturbulence_vel = microturbulence_vel,
#             macroturbulence=macroturbulence, vsini=vsini, limb_darkening_coeff=limb_darkening_coeff,
#             R=resolution, regions=regions, verbose=0,
#             code=code)

#     return synth_spectrum

# %% [markdown]
# So far we have discussed about reading the input original spectra and interpolating the synthetic spectra from iSpec. Now the important part that comes into picture is to compare the original spectra and the interpolated spectra. For this we will use Montecarlo Markhov chain method to compare both the spectrums. For this we have used the emcee package by
# Dan Foreman-Mackey.

# %%
walkers = eval(input("Enter Walkers: "))    #WALKER IMPLIES THE INDEPENDENT RANDOMLY SELECTED PARAMETER SETS. NOTE IT SHOULD HAVE ATLEAST TWICE THE VALUE OF AVAILABLE FREE PARAMETERS
Iter = eval(input("Enter Iterations: "))    #ITERATION IMPLIES NUMBER OF RUNS THE PARAMETERS WILL BE CHECKED FOR CONVERGENCE. FOR MOST CASES 250-300 SHOULD DO.
# Out:
# Enter Walkers:  20
# Enter Iterations:  150

# %% [markdown]
# We will be creating four functions for this MCMC run. The first is straightforward, and is known as the model. The model function should take as an argument a list representing our θ vector, and return the model evaluated at that θ. For completion, your model function should also have your parameter array as an input. The form of this function comes from the Gaussian probability distribution P(x)dx.

# %%
def log_likelihood(theta):
    model = synthesize_spectrum(theta)    #GENARATING THE SPECTRUM FOR A GIVEN VALUE OF THETA
    sigma2 = yerr ** 2                    # FINDING THE Variance
    return -0.5 * np.sum((y - (model['flux'])) ** 2/ sigma2)     # returns the -chi^2/2 value

# %% [markdown]
# There is no unique way to set up your prior function. For the simplistic case we have choosen the log prior function returns zero if the input values genarated randomly lies wittin the specified ranges and -infinity if it doesnt(atleast one vale should satisty this criterion). You can choose your own prior function as well.

# %%
def log_prior(theta):
    teff, logg, MH = theta
    if 3200 < teff < 6900 and 1.1 < logg < 4.8 and -2.49 < MH <= 0.49 :                                                       #CHANGE HERE
        return 0.0
    return -np.inf

# %% [markdown]
# The last function we need to define is lnprob(). This function combines the steps above by running the lnprior function, and if the function returned -np.inf, passing that through as a return, and if not (if all priors are good), returning the lnlike for that model (by convention we say it’s the lnprior output + lnlike output, since lnprior’s output should be zero if the priors are good). lnprob needs to take as arguments theta,x,y,and yerr, since these get passed through to lnlike.

# %%
def log_probability(theta):
    lp = log_prior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood(theta)

# %% [markdown]
# Select input guess values and create intial set of stellar parameters RANDOMLY

# %%
initial = np.array([5500,4.0,-0.1])         #INPUT GUESS VALUES                                                         
pos = initial + np.array([100,0.1,0.1])*np.random.randn(walkers, 3)      # YOU CAN CHOOSE UNIFORM RANDOM FUNCTION OR GAUSSIAUN RANDOM NUMBER GENARATOR
nwalkers, ndim = pos.shape

# %% [markdown]
# Now we will run the EMCEE sampler to run the code. This will take some time depending on the your system. But don't worry :)

# %%
sampler = emcee.EnsembleSampler(nwalkers, ndim, log_probability)
sampler.run_mcmc(pos,Iter, progress=True)
# Out:
# [2025-10-23 11:44:53,558] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:44:53,963] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:44:54,373] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:44:54,784] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:44:55,184] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:44:55,598] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:44:55,987] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:44:56,373] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:44:56,764] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:44:57,151] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:44:57,541] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:44:57,935] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:44:58,323] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:44:58,712] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:44:59,101] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:44:59,512] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:44:59,916] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:00,320] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:00,712] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:01,106] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   0%|                                                   | 0/150 [00:00<?, ?it/s][2025-10-23 11:45:01,509] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:01,916] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:02,318] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:02,717] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:03,116] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:03,515] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:03,918] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:04,320] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:04,723] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:05,131] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:05,534] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:05,940] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:06,343] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:06,748] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:07,154] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:07,561] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:07,986] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:08,448] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:08,899] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:09,359] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   1%|▎                                          | 1/150 [00:08<20:29,  8.25s/it][2025-10-23 11:45:09,790] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:10,235] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:10,674] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:11,128] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:11,537] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:11,992] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:12,411] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:12,836] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:13,260] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:13,682] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:14,106] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:14,521] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:14,934] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:15,345] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:15,763] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:16,172] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:16,580] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:16,989] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:17,397] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:17,807] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   1%|▌                                          | 2/150 [00:16<20:38,  8.37s/it][2025-10-23 11:45:18,222] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:18,633] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:19,045] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:19,454] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:19,867] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:20,275] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:20,693] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:21,109] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:21,526] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:21,946] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:22,354] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:22,779] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:23,196] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:23,799] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:24,212] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:24,638] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:25,055] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:25,451] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:25,848] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:26,368] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   2%|▊                                          | 3/150 [00:25<20:42,  8.46s/it][2025-10-23 11:45:26,997] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:27,664] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:28,314] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:28,956] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:29,584] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:30,226] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:31,027] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:31,878] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:32,510] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:33,139] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:33,758] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:34,384] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:34,996] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:35,611] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:36,240] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:36,859] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:37,475] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:38,099] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:38,714] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:39,329] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   3%|█▏                                         | 4/150 [00:38<24:54, 10.23s/it][2025-10-23 11:45:39,948] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:40,565] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:41,179] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:41,787] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:42,393] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:43,002] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:43,604] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:44,455] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:45,190] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:45,863] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:46,592] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:47,298] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:48,005] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:48,706] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:49,362] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:50,085] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:50,732] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:51,432] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:52,123] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:52,805] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   3%|█▍                                         | 5/150 [00:51<27:33, 11.40s/it][2025-10-23 11:45:53,453] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:54,077] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:54,748] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:55,524] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:56,196] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:56,892] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:57,675] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:58,405] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:59,142] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:45:59,844] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:00,548] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:01,244] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:02,035] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:02,675] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:03,389] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:04,110] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:04,821] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:05,604] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:06,325] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:07,062] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   4%|█▋                                         | 6/150 [01:05<29:41, 12.37s/it][2025-10-23 11:46:07,833] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:08,475] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:09,230] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:09,909] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:10,540] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:11,203] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:11,888] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:12,542] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:13,211] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:13,913] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:14,689] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:15,367] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:16,013] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:16,855] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:17,572] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:18,289] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:18,931] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:19,648] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:20,361] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:21,063] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   5%|██                                         | 7/150 [01:19<30:45, 12.91s/it][2025-10-23 11:46:21,782] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:22,490] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:23,166] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:23,850] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:24,581] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:25,295] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:26,212] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:26,926] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:27,605] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:28,383] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:29,064] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:29,806] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:30,519] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:31,190] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:31,918] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:32,679] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:33,420] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:34,057] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:34,673] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:35,301] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   5%|██▎                                        | 8/150 [01:34<31:32, 13.33s/it][2025-10-23 11:46:35,934] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:36,579] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:37,222] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:37,860] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:38,639] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:39,265] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:39,906] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:40,543] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:41,155] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:41,762] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:42,367] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:42,969] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:43,574] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:44,179] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:44,781] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:45,402] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:46,011] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:46,620] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:47,223] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:47,858] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   6%|██▌                                        | 9/150 [01:46<30:45, 13.09s/it][2025-10-23 11:46:48,495] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:49,102] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:49,738] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:50,364] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:50,973] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:51,589] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:52,203] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:52,829] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:53,430] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:54,047] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:54,656] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:55,282] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:55,898] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:56,497] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:57,110] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:57,730] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:58,342] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:58,955] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:46:59,570] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:00,176] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   7%|██▊                                       | 10/150 [01:59<29:59, 12.85s/it][2025-10-23 11:47:00,796] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:01,411] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:02,021] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:02,634] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:03,244] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:03,858] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:04,466] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:05,082] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:05,695] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:06,325] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:06,947] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:07,554] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:08,161] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:08,775] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:09,387] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:09,995] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:10,607] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:11,225] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:11,834] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:12,443] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   7%|███                                       | 11/150 [02:11<29:21, 12.67s/it][2025-10-23 11:47:13,061] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:13,668] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:14,271] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:14,879] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:15,488] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:16,099] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:16,706] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:17,315] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:17,924] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:18,537] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:19,143] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:19,758] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:20,368] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:20,982] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:21,593] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:22,203] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:22,817] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:23,426] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:24,035] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:24,643] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   8%|███▎                                      | 12/150 [02:23<28:48, 12.53s/it][2025-10-23 11:47:25,257] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:25,865] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:26,475] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:27,084] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:27,692] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:28,300] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:28,914] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:29,523] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:30,131] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:30,739] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:31,353] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:31,964] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:32,580] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:33,190] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:33,798] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:34,406] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:35,017] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:35,631] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:36,242] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:36,853] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   9%|███▋                                      | 13/150 [02:35<28:23, 12.43s/it][2025-10-23 11:47:37,471] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:38,082] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:38,692] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:39,301] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:39,910] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:40,518] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:41,131] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:41,740] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:42,348] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:42,962] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:43,580] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:44,197] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:44,810] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:45,424] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:46,036] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:46,645] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:47,258] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:47,912] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:48,525] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:49,135] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#   9%|███▉                                      | 14/150 [02:48<28:04, 12.39s/it][2025-10-23 11:47:49,752] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:50,364] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:50,978] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:51,617] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:52,238] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:52,853] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:53,471] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:54,082] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:54,696] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:55,329] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:55,960] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:56,575] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:57,185] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:57,798] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:58,413] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:59,026] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:47:59,638] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:00,251] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:00,861] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:01,476] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  10%|████▏                                     | 15/150 [03:00<27:50, 12.37s/it][2025-10-23 11:48:02,090] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:02,923] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:03,670] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:04,275] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:04,888] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:05,501] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:06,118] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:06,730] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:07,345] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:07,961] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:08,577] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:09,192] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:09,805] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:10,414] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:11,030] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:11,651] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:12,263] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:12,871] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:13,484] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:14,097] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  11%|████▍                                     | 16/150 [03:12<27:47, 12.45s/it][2025-10-23 11:48:14,715] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:15,326] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:15,942] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:16,555] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:17,324] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:18,090] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:18,686] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:19,289] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:20,061] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:20,827] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:21,447] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:22,059] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:22,831] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:23,463] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:24,074] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:24,845] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:25,473] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:26,081] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:26,852] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:27,616] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  11%|████▊                                     | 17/150 [03:26<28:18, 12.77s/it][2025-10-23 11:48:28,218] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:28,984] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:29,603] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:30,234] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:30,837] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:31,479] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:32,108] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:32,716] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:33,315] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:33,914] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:34,511] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:35,153] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:35,781] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:36,411] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:37,024] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:37,796] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:38,567] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:39,169] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:39,785] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:40,398] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  12%|█████                                     | 18/150 [03:39<28:06, 12.77s/it][2025-10-23 11:48:41,024] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:41,643] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:42,256] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:42,865] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:43,475] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:44,090] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:44,703] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:45,320] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:45,940] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:46,556] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:47,164] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:47,779] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:48,392] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:49,008] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:49,624] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:50,243] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:50,855] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:51,475] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:52,089] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:52,703] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  13%|█████▎                                    | 19/150 [03:51<27:34, 12.63s/it][2025-10-23 11:48:53,322] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:53,937] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:54,552] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:55,173] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:55,807] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:56,430] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:57,048] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:57,779] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:58,392] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:59,002] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:48:59,615] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:00,228] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:00,847] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:01,460] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:02,084] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:02,695] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:03,333] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:03,972] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:04,609] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:05,219] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  13%|█████▌                                    | 20/150 [04:04<27:17, 12.60s/it][2025-10-23 11:49:05,833] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:06,442] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:07,050] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:07,661] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:08,269] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:08,875] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:09,483] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:10,091] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:10,699] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:11,310] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:11,922] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:12,530] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:13,139] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:13,752] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:14,361] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:14,967] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:15,579] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:16,216] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:17,053] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:17,639] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  14%|█████▉                                    | 21/150 [04:16<26:58, 12.54s/it][2025-10-23 11:49:18,255] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:18,865] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:19,474] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:20,087] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:20,695] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:21,308] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:21,922] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:22,529] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:23,139] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:23,915] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:24,515] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:25,124] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:25,734] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:26,345] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:26,949] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:27,556] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:28,163] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:28,775] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:29,378] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:29,988] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  15%|██████▏                                   | 22/150 [04:28<26:38, 12.49s/it][2025-10-23 11:49:30,601] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:31,215] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:31,830] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:32,685] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:33,425] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:34,031] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:34,644] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:35,254] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:35,865] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:36,477] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:37,094] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:37,706] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:38,311] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:38,918] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:39,527] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:40,137] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:40,746] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:41,356] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:41,968] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:42,584] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  15%|██████▍                                   | 23/150 [04:41<26:29, 12.52s/it][2025-10-23 11:49:43,300] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:44,077] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:44,681] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:45,293] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:45,903] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:46,508] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:47,113] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:47,722] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:48,325] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:48,933] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:49,579] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:50,218] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:50,831] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:51,615] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:52,216] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:52,828] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:53,436] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:54,044] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:54,652] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:55,279] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  16%|██████▋                                   | 24/150 [04:54<26:24, 12.57s/it][2025-10-23 11:49:55,898] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:56,513] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:57,122] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:57,735] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:58,345] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:58,959] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:49:59,567] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:50:00,190] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:50:00,818] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:50:01,433] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:50:02,049] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:50:02,662] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:50:03,270] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:50:03,881] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:50:04,493] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:50:05,112] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:50:05,722] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:50:06,333] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:50:06,940] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 11:50:07,551] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  17%|███████                                   | 25/150 [05:06<26:00, 12.48s/it][2025-10-23 11:50:08,172] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# ...
# [2025-10-23 12:16:57,427] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:16:58,109] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:16:58,789] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:16:59,507] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:00,183] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:00,892] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  98%|████████████████████████████████████████▏| 147/150 [31:59<00:41, 13.92s/it][2025-10-23 12:17:01,571] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:02,253] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:02,929] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:03,608] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:04,283] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:04,960] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:05,644] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:06,319] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:06,998] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:07,667] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:08,376] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:09,054] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:09,723] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:10,433] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:11,110] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:11,817] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:12,491] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:13,174] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:13,860] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:14,535] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  99%|████████████████████████████████████████▍| 148/150 [32:13<00:27, 13.83s/it][2025-10-23 12:17:15,256] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:15,937] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:16,651] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:17,332] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:18,009] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:18,727] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:19,407] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:20,088] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:20,757] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:21,440] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:22,117] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:22,806] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:23,477] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:24,157] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:24,826] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:25,498] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:26,170] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:26,841] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:27,515] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:28,198] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
#  99%|████████████████████████████████████████▋| 149/150 [32:27<00:13, 13.78s/it][2025-10-23 12:17:28,886] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:29,557] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:30,230] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:30,902] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:31,572] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:32,243] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:32,914] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:33,584] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:34,255] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:34,928] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:35,602] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:36,273] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:36,944] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:37,614] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:38,286] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:38,961] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:39,632] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:40,302] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:40,975] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# [2025-10-23 12:17:41,647] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# 100%|█████████████████████████████████████████| 150/150 [32:40<00:00, 13.07s/it]
# State([[ 5.49978229e+03  3.92246739e+00 -1.22160828e-01]
#  [ 5.49965995e+03  3.92303299e+00 -1.22674975e-01]
#  [ 5.49962113e+03  3.92180754e+00 -1.22068049e-01]
#  [ 5.49978960e+03  3.92698388e+00 -1.23798001e-01]
#  [ 5.49965656e+03  3.92418860e+00 -1.22904849e-01]
#  [ 5.49972471e+03  3.92277889e+00 -1.22460028e-01]
#  [ 5.49983766e+03  3.92175204e+00 -1.21834637e-01]
#  [ 5.49960933e+03  3.92088344e+00 -1.22125071e-01]
#  [ 5.49986750e+03  3.92694156e+00 -1.24070256e-01]
#  [ 5.49907593e+03  3.92203097e+00 -1.29340920e-01]
#  [ 5.49973313e+03  3.92406321e+00 -1.22928443e-01]
#  [ 5.49987634e+03  3.92630492e+00 -1.23442565e-01]
#  [ 5.49990110e+03  3.92668066e+00 -1.23835791e-01]
#  [ 5.49988499e+03  3.92469700e+00 -1.22551665e-01]
#  [ 5.49982448e+03  3.92167043e+00 -1.22023084e-01]
#  [ 5.49947337e+03  3.92424608e+00 -1.29850942e-01]
#  [ 5.49990892e+03  3.92386591e+00 -1.22440519e-01]
#  [ 5.49982246e+03  3.92604933e+00 -1.23600738e-01]
#  [ 5.49986812e+03  3.92170505e+00 -1.21655895e-01]
#  [ 5.49977428e+03  3.92353503e+00 -1.22418100e-01]], log_prob=[-4025713.08691275 -4025917.84730283 -4026014.17796063 -4026226.37779676
#  -4026185.08937817 -4025785.66269319 -4025525.27796959 -4025688.35368711
#  -4025811.76961637 -4028647.60678653 -4025902.07672327 -4025960.15662929
#  -4025769.92310514 -4025949.39112895 -4025404.83429338 -4028089.54407895
#  -4025652.84583452 -4025917.36839584 -4025545.40077659 -4025940.66594213], blobs=None, random_state=('MT19937', array([1315039469,  702096394, 4016261155, 4232270084, 2253711400,
#        1453443151, 3584207905, 1620859219, 2536006295, 3022288338,
#        1141496992,   69642131, 2768110154, 3818828615, 4261795333,
#         700469779,   38730016, 3851572735, 2611066665,  926413231,
#        3409425292, 3711492723, 1088769552, 2683570287, 4263581617,
#        1460735912, 2692161003,  299394814,  819785985, 1092389886,
#         709347836, 3203546289, 2003236654, 3786588960, 1890142506,
#        1082106832, 4162106052, 3735827364, 3513117274, 3719139441,
#        2959389131, 2807410890, 1604755197, 3297455307,    2039589,
#         198822750, 1212640135,  816241532, 3562050550, 1787121741,
#        2794303202,   84307810, 2916262477, 3037147078,  825509103,
#        3384326196,   30972622, 3153084900, 2493015667,   70762888,
#        1718407004, 1345742363, 1505674184, 3960222294, 2778233611,
#        1893995754, 4218966296,  882673761, 3637700703, 1736227399,
#        3971351865, 3623395564, 3602302207,  944590725, 2728172596,
#        1852802500, 4070702326,  577986451,  763840256, 2098020980,
#        3280629327, 2303057522, 4248976165, 2407614295, 2448993861,
#         830145343,  828276382, 2964292190, 2230452610, 4156163672,
#          94281183, 2563492927, 2820693544,  959039745,  334502245,
#         899149536, 2921725327, 1987262527,  610055122, 3037207528,
#        2433480039, 2116462029, 3660639487,  568352740,  423007034,
#         294794797, 3056003107, 1475654597, 1556350289, 4259046248,
#        2520431928, 2535835400, 2816532498, 3932092144, 1648688564,
#        2929036460, 3973109518, 2383382446,  562753265, 1861960384,
#         909335817, 4210095544, 2329666267,  259905132, 1159290721,
#        2324360305, 4221938684,  615328288, 2452758932, 1525271223,
#        2097916634,  589008104, 2851413186, 2919307497, 3231612557,
#        3725830694, 3018318383, 3350224959, 3912444136, 3171743956,
#         259412989, 1465768481, 3524666687, 3967501827,  292825668,
#         772110586, 2691754908, 3311551809,  294069383, 1355069834,
#         605905082, 4200017624,  925107173,  418867935, 1381845588,
#        3377445455, 1018975432,  256273518, 3846515428, 3808988659,
#        4028577742, 3371180108, 3722622452, 1499863391,  498816606,
#        2420456995, 1902524007,   37969033, 3926643339, 3552728639,
#        2843910894, 3330204782,  802530344, 2586576768, 1163637183,
#        1421239790,  128083926, 1695782382, 4211425862, 1384686949,
#           8938359, 3519389478, 2021607272, 3645969796, 2202134575,
#         228959912, 2820992853,  110156053, 4064137434,  260835509,
#        2414253565, 3141461589, 3434212180, 2512927318, 4205543467,
#        1308979191,  835252529, 2781951658, 1627876820, 3155824899,
#        1232457747, 1506868980, 2695243152,  328840275, 2242161339,
#        4179637339, 2433826998, 1863948331, 2060403722, 3496706911,
#        2031138078, 2648262990, 1995155251, 1159892451, 3725812128,
#         662529809, 1895971883, 3316244294, 2059163484, 2139625942,
#         263754247, 3775826729, 4242499776,  586293223, 2809688019,
#        2077442638,  906649420,  942956902,  225257323,  135927534,
#        4175311683, 3269642240, 1449290858,  970515384,  978539412,
#        2596470700,  491196617,  553007555, 2155304283, 3543700214,
#        3559526592, 1640665582, 3408755900,  119527880, 2840713636,
#        2544075997, 2594577660,  901129660, 2027193751,    1978793,
#        3498128075,  211605022, 2194558415, 3683038456,  102072581,
#        3650659200, 3702601148, 1062607090, 1809754852, 4026768563,
#        2457295343, 3916155449, 3085241224,  912226893, 1795133508,
#        3345317676, 2491831504, 1440668961, 2597752190, 2826984003,
#        2656097720,  927572873,  791850417, 2790943240, 1569087844,
#        4099654224,  521978512, 2996814888, 2655093043, 2863141820,
#         241202913, 3507156312, 1932998978, 1281150739, 2850398819,
#        3962347533,  777876639,  467993497,  561922656, 1815016484,
#         736005381, 3323643013, 2552200363,  332259406, 3849871496,
#        3117428520, 3431613423,  494606427, 3059838772,   29541262,
#        3216800304,  173733527,  642697476, 2632962683, 1389606804,
#         206131889, 4255343572, 4160943528, 1276037115, 1939661581,
#        1667564646, 3587259204,  944788036, 2605804096, 2986823014,
#        2918447476, 2182114527, 1486735992, 1623958381,  635684884,
#         843770991, 2957688396, 4058309169, 2416855841, 2494066678,
#        1596075727,  604376115, 1151175560, 1071914857,  607944387,
#         813030753,  735447291,  388872597,  614422777, 3185892988,
#        1830183241,  517186653, 2115351667, 2361229770, 1942055122,
#          44538664, 1234733515, 2971602008, 3687249590,  372321042,
#        2443104533,   96922198, 4042603337, 2892532962, 1466624663,
#          14190023, 3144987559,  235580373, 2179880164, 1330861552,
#        2589207545, 1080471624, 3611846435, 2418597524,  407251718,
#        3566383017, 2766106079, 1152642622, 3188374854,  956536766,
#        1488024909, 3665071409, 3843937995, 2499296673, 4060023437,
#        1403839823, 4192046102, 1925247739, 3008184530,  585226643,
#        2482028923, 2234714823, 3112825192, 1796327789, 1400723880,
#        3187681448, 2544716338, 2968652634,  382244687, 3663934160,
#        2199371667, 3823431242, 4247802417, 2861972296, 1945440542,
#         480595410, 2866148820, 4040663293,  158733310, 3316017375,
#        2265094990,  445877691,  728888905, 4204638521, 1776849138,
#        2901122798, 3165437729, 3751346137, 3172231752, 4049169605,
#        1337942925, 3947466691, 1407432219,  329285764, 2539973574,
#        3127548394,  481519940, 3339996478, 4153367415, 1669215938,
#        4272058449, 1985211548,  132243348,  684812895,  869685841,
#        3054640306, 3877237816,  932252993, 1562348538, 4238795559,
#        3688521238, 2349464594, 1703991292, 3981698051, 1078349858,
#        3724430789, 3325619433,  929906328, 3253742646,   99528946,
#         134319123, 2413359396, 2479513995, 3392608549, 3676503477,
#        2109218754,  673805607, 3092526275,  961311732, 4007126675,
#        3824128485, 3685359644, 2955366260, 2186140174, 4117618625,
#        2040948314,  341556495, 1472186962, 2768638725, 2269036049,
#         903490781,  185227447, 2255067779, 1884954569, 1197287069,
#        3384053421, 2080535025, 4012087805, 3507668335, 1273838666,
#        3495523469,  527809286, 3860172448, 1044323547, 3958398623,
#        3415232496,  802425181, 3784246432, 1258546000, 2765921112,
#        3463052021, 3858416990, 3100331550, 2147455021, 1156111421,
#        3951780070, 2827176893, 3410639733,  847519015,  857235494,
#        2783220346, 1091353461, 3540963623, 1863756553,  686844708,
#         139138229,   75165833, 1530447831, 3432712881, 1552274350,
#        3160392681, 2784514078, 3089836588, 3376086376,  300111636,
#        4281674759, 4108415922, 3142601623, 2323490928, 2372066648,
#        2187138337, 1927113927, 1409155459, 4230401412, 1160421202,
#         254842494, 1471977095, 3639102102,  835295334, 1643049612,
#        1285482133, 2004202923, 1982267561, 2217806431, 3733092848,
#        3689547593, 3909262427, 3441541951, 1014027811, 1123407226,
#        4266219009, 1317949146, 3949612156, 2357621293,   92429878,
#        2788877676, 2512261106,  485531930,  595433900, 1523297470,
#        3794582185, 3281291365, 4145591478,  646442192, 2094478198,
#         873673781, 2701726518,  692917758,  133526760, 2233291427,
#        4293694437, 3376065250,  142329361, 2488310402, 2835385099,
#        3094645254, 2609474841, 3148274809, 3250248417,  205405694,
#        1756347144, 1146528115, 3602383311, 1186223756, 2413836613,
#        2376852569, 2042529905, 2614711991, 2992069758, 1197872772,
#        3601360978,  246995865, 4130687329, 1788444636, 2994328621,
#         865443378,  612090127, 1857958834, 3099623266, 2672175856,
#        2097421743, 2112429330, 2775625853,  549885404, 1166050826,
#        3934225118,  256512914,  418911107,  495125381, 1252801658,
#        2910036419, 1622024603, 3692651763, 3994272525, 4166000730,
#        1984306927,  141485282, 3573276618, 1498211810, 1765156909,
#        1858956690, 2511223426,  332207519, 2386771398, 1299114161,
#        1569823267, 2661589720, 4188457171, 3793944890, 1580580095,
#        3017386750, 2882124739,   51106478, 4012929917, 3306011396,
#        1761377587, 1082053308, 4266022786, 3819891320, 2152386371,
#        3354557750, 2196952520,  906467752, 2486555528, 1701796200,
#        3019099768, 3306890259, 3798115401, 2762721554], dtype=uint32), 8, 0, 0.0))

# %% [markdown]
# Let us plot the Walkers and Iterations. Check out for convergence in this plot. If you see the convergence you are good to go.

# %%
fig, axes = plt.subplots(3, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
accepted = sampler.backend.accepted.astype(bool)   #Here accepted indicated that the lines for each parameter below have converged/moved at least one time.

labels = ["teff","logg","MH"]
for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)
axes[-1].set_xlabel("step number");

# %% [markdown]
# Let us check how good is the fitting.....

# %%
fig, ax = plt.subplots(1, figsize=(10, 7), sharex=True)
samples = sampler.flatchain
theta_max  = samples[np.argmax(sampler.flatlnprobability)]
best_fit_model = synthesize_spectrum(theta_max)
ax.plot(x,y,alpha=0.3)
ax.plot(x,best_fit_model['flux'],alpha =0.3)
ax.plot(x,y-best_fit_model['flux'],alpha =0.3)
plt.savefig('t2.pdf')                                                                                                #CHANGE HERE
print(('Theta max: ',theta_max))             # Genarating the spectrum for the Maximum likelyhood function.
#NOTE THE SPIKES IN THE PLOT BELOW. THESE ARE DUE TO THE FACT THAT END POINTS OF THE SPECTRUMS ARE EXTRAPOLATED
# Out:
# [2025-10-23 12:17:42,608] [INFO] [spectrum:__convolve_spectrum:789]: Spectra convolved!
# ('Theta max: ', array([ 5.49982448e+03,  3.92167043e+00, -1.22023084e-01]))

# %% [markdown]
# Since the first few runs the walkers are exploring the parameter space and convergence have not yet been achived. We will ignore such runs. This is also known as "BURN-IN".

# %%
new_samples = sampler.get_chain(discard=10, thin=1, flat=False)
flat_samples = sampler.get_chain(discard=10, thin=1, flat=True)
                     # WE ARE ONLY CHOOSING THE VALUES FOR WHICH THE WALKER HAVE MOVED ATLEAST ONCE DURING THE ENTIRE ITERATION. Stagnent walkers indicates that the prior function might have returned -inf.

# %%
print(new_samples.shape)
# Out:
# (140, 20, 3)

# %% [markdown]
# Checking the Convergence after the BURN-IN... If it seems to be converged then it is DONE.

# %%
fig, axes = plt.subplots(3, figsize=(10, 7), sharex=True)
for i in range(ndim):
    ax = axes[i]
    ax.plot(new_samples[:, :, i], "k", alpha=0.3)
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)
axes[-1].set_xlabel("step number")
plt.savefig('t3.pdf')                                                                                                  #CHANGE HERE
flat_samples = new_samples.reshape(-1,new_samples.shape[2])
np.savetxt("ispec_sample1.txt",flat_samples,delimiter='\t')                                                                                   #CHANGE HERE

# %% [markdown]
# # Data Visualization!

# %%
import corner
from pandas.plotting import scatter_matrix

# %%
df = pd.read_csv('/home/anjalyrose/iSpec/ispec_sample.txt', delimiter='\t')

# Verify column names and types
print(df.head())
print(df.dtypes)

# Plot histogram for numeric columns
df.hist()
# Out:
#       waveobs      flux       err
# 0  515.002041  0.996187  0.011115
# 1  515.005141  0.978510  0.010948
# 2  515.008241  0.968782  0.010833
# 3  515.011240  0.938253  0.010563
# 4  515.014340  0.899014  0.010186
# waveobs    float64
# flux       float64
# err        float64
# dtype: object
# array([[<Axes: title={'center': 'waveobs'}>,
#         <Axes: title={'center': 'flux'}>],
#        [<Axes: title={'center': 'err'}>, <Axes: >]], dtype=object)

# %%
#df = df[df.logg < 4.451 ] #REMOVE ANY OUTLIER DISTRIBUTION

# %%
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde') #PLOTTING THE SCATTER MATRIX. I HAVE USED A VERY LIGHT DATASET FOR TEST PURPOSE> YOU CAN USE A MORE WALKER X ITERATION FOR A BETTER RESULT
# Out:
# array([[<Axes: xlabel='waveobs', ylabel='waveobs'>,
#         <Axes: xlabel='flux', ylabel='waveobs'>,
#         <Axes: xlabel='err', ylabel='waveobs'>],
#        [<Axes: xlabel='waveobs', ylabel='flux'>,
#         <Axes: xlabel='flux', ylabel='flux'>,
#         <Axes: xlabel='err', ylabel='flux'>],
#        [<Axes: xlabel='waveobs', ylabel='err'>,
#         <Axes: xlabel='flux', ylabel='err'>,
#         <Axes: xlabel='err', ylabel='err'>]], dtype=object)

# %%
samples = np.vstack([df]) #IT IS NECESSARY TO STACK THE DATA VERTICALLY TO OBTAIN THE DISTRIBUTION FROM THE DATA FRAME

# %%
value2 = np.mean(samples, axis=0) 
plt.rcParams["font.size"] = "10"     #THIS CHANGES THE FONT SIZE OF THE LABELS(NOT LEGEND)

# %%
#FINALLY... MAKING THE CORNER PLOT>>>>


#fig = corner.corner(df,show_titles=True,plot_datapoints=True,quantiles=[0.16, 0.5, 0.84],color ='black',levels=(1-np.exp(-0.5),),label_kwargs=dict(fontsize=20,color = 'black'),hist_kwargs=dict(fill = True,color = 'dodgerblue'),alpha =0.2)
fig = corner.corner(df,show_titles=True,plot_datapoints=True,quantiles=[0.16, 0.5, 0.84],color ='black',label_kwargs=dict(fontsize=20,color = 'black'),hist_kwargs=dict(fill = True,color = 'dodgerblue'),alpha =0.2)
axes = np.array(fig.axes).reshape((3, 3))
for i in range(3):
    ax = axes[i, i]
    ax.axvline(value2[i], color="r",alpha =0.8)
for yi in range(3):
    for xi in range(yi):
        ax = axes[yi, xi]
        ax.axvline(value2[xi], color="r",alpha =0.8,linestyle = 'dashed')
        ax.axhline(value2[yi], color="r",alpha =0.8,linestyle = 'dashed')
        ax.plot(value2[xi], value2[yi], "r")
#         plt.tight_layout()
#THE CORNER PLOT DONOT LOOK GREAT>> THE REASON IS FEW NUMBER OF DATA POINTS AND SHARP CONVERGENCE
